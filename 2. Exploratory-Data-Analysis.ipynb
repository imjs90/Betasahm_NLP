# %%
# Read in the document-term matrix
import pandas as pd

data = pd.read_pickle('dtm.pkl')
data = data.transpose()
data.head()
# Out:
# hashtags   ['#NAV', '#تاصیکو']  ['#NAV', '#وسپه']  ['#NAV', '#پارسان']  \
# abs                          0                  0                    0
# absrubber                    0                  0                    0
# accenture                    0                  0                    0
# account                      0                  0                    0
# additive                     0                  0                    0
#
# hashtags   ['#آ_س_پ']  ['#آبین']  ['#آرمان']  ['#آريان']  ['#آریا']  \
# abs                 0          0           0           0          0
# absrubber           0          0           0           0          0
# accenture           0          0           0           0          0
# account             0          0           0           0          0
# additive            0          0           0           0          0
#
# hashtags   ['#آریان']  ['#آسیا']  ...  ['#کیسون']  ['#کیمیا']  ['#گتوشا']  \
# abs                 0          0  ...           0           0           0
# absrubber           0          0  ...           0           0           0
# accenture           0          0  ...           0           0           0
# account             0          0  ...           0           0           0
# additive            0          0  ...           0           0           0
#
# hashtags   ['#گوهران', '#رکیش']  ['#گوهران', '#وامید']  ['#گوهران']  \
# abs                           0                      0            0
# absrubber                     0                      0            0
# accenture                     0                      0            0
# account                       0                      0            0
# additive                      0                      0            0
#
# hashtags   ['#گپارس']  ['#گکوثر']  ['#گکیش']  ['#گگهر']
# abs                 0           0          0          0
# absrubber           0           0          0          0
# accenture           0           0          0          0
# account             0           0          0          0
# additive            0           0          0          0
#
# [5 rows x 1033 columns]

# %%
# Find the top 30 words each companies
top_dict = {}

for c in data.columns:
    top = data[c].sort_values(ascending = False).head(30)
    top_dict[c] = list(zip(top.index, top.values))

top_dict
# Out:
# {"['#NAV', '#تاصیکو']": [('سهم', 4),
#   ('تاصیکو', 3),
#   ('در', 3),
#   ('به', 3),
#   ('درصد', 2),
#   ('فولاد', 2),
#   ('از', 2),
#   ('شود', 1),
#   ('لازم', 1),
#   ('پرتفوی', 1),
#   ('دومین', 1),
#   ('nav', 1),
#   ('pnav', 1),
#   ('حاضر', 1),
#   ('بورسی', 1),
#   ('نسبت', 1),
#   ('را', 1),
#   ('حال', 1),
#   ('تحلیلی', 1),
#   ('روزرسانی', 1),
#   ('است', 1),
#   ('مالکیت', 1),
#   ('توضیح', 1),
#   ('صورت', 1),
#   ('پارسیس', 1),
#   ('بعد', 1),
#   ('استکانال', 1),
#   ('افزایش', 1),
#   ('دارد', 1),
#   ('محدوده', 1)],
#  "['#NAV', '#وسپه']": [('در', 4),
#   ('سهم', 3),
#   ('ماه', 2),
#   ('nav', 2),
#   ('رشد', 2),
#   ('ای', 2),
#   ('درصد', 2),
#   ('آذر', 2),
#   ('است', 2),
#   ('درصدی', 1),
#   ('روز', 1),
#   ('فوق', 1),
#   ('پارسیس', 1),
#   ('ان', 1),
#   ('محدوده', 1),
#   ('ارائه', 1),
#   ('تحلیلی', 1),
#   ('گزارش', 1),
#   ('حاضر', 1),
#   ('pnav', 1),
#   ('با', 1),
#   ('به', 1),
#   ('قابل', 1),
#   ('حال', 1),
#   ('بعد', 1),
#   ('روزرسانی', 1),
#   ('مشاهده', 1),
#   ('استکانال', 1),
#   ('وسپه', 1),
#   ('مقایسه', 1)],
#  "['#NAV', '#پارسان']": [('سهم', 2),
#   ('در', 2),
#   ('رسانی', 1),
#   ('استکانال', 1),
#   ('نسبت', 1),
#   ('حاضر', 1),
#   ('محدوده', 1),
#   ('پارسیس', 1),
#   ('پارسان', 1),
#   ('به', 1),
#   ('pnav', 1),
#   ('روز', 1),
#   ('تحلیلی', 1),
#   ('هر', 1),
#   ('حال', 1),
#   ('nav', 1),
#   ('درصد', 1),
#   ('خریداري', 0),
#   ('خریداقا', 0),
#   ('خرید', 0),
#   ('خریدpo', 0),
#   ('خریداری', 0),
#   ('خریدا', 0),
#   ('خریداد', 0),
#   ('خریدار', 0),
#   ('خریداران', 0),
#   ('خریختخریخت', 0),
#   ('خریدارو', 0),
#   ('ﻻزم', 0),
#   ('خریخت', 0)],
#  "['#آ_س_پ']": [('در', 31),
#   ('به', 30),
#   ('ریال', 21),
#   ('شرکت', 14),
#   ('مبلغ', 13),
#   ('از', 12),
#   ('آسپ', 12),
#   ('سرمایه', 11),
#   ('با', 11),
#   ('پروژه', 9),
#   ('قرارداد', 9),
#   ('افزایش', 9),
#   ('میلیون', 9),
#   ('ماهه', 7),
#   ('شده', 7),
#   ('میلیارد', 7),
#   ('مورخ', 7),
#   ('است', 6),
#   ('نقدی', 5),
#   ('مجمع', 5),
#   ('محل', 5),
#   ('استآسپ', 5),
#   ('آورده', 5),
#   ('مجوز', 5),
#   ('های', 5),
#   ('فروش', 5),
#   ('مطالبات', 5),
#   ('شماره', 5),
#   ('عمومی', 4),
#   ('محقق', 4)],
#  "['#آبین']": [('به', 12),
#   ('از', 8),
#   ('در', 7),
#   ('ریال', 6),
#   ('مزایده', 6),
#   ('آبین', 5),
#   ('قم', 4),
#   ('شرکت', 3),
#   ('آبشيرين', 3),
#   ('صنعت', 3),
#   ('محل', 3),
#   ('با', 3),
#   ('فروش', 2),
#   ('های', 2),
#   ('قدیم', 2),
#   ('کاشان', 2),
#   ('هیئت', 2),
#   ('کرده', 2),
#   ('میلیارد', 2),
#   ('گزارش', 2),
#   ('ثبتی', 2),
#   ('پایه', 2),
#   ('بخشی', 2),
#   ('سرمایه', 2),
#   ('فرعی', 2),
#   ('ارزیابی', 2),
#   ('منظور', 2),
#   ('شماره', 2),
#   ('پلاک', 2),
#   ('کیلومتر', 2)],
#  "['#آرمان']": [('به', 11),
#   ('آرمان', 4),
#   ('در', 4),
#   ('منظور', 3),
#   ('ریال', 3),
#   ('از', 3),
#   ('با', 3),
#   ('ریالی', 2),
#   ('سرمایه', 2),
#   ('هیئت', 2),
#   ('تعلیق', 2),
#   ('مالي', 2),
#   ('توجه', 2),
#   ('تاریخ', 2),
#   ('ماده', 2),
#   ('ماهه', 2),
#   ('بیمه', 2),
#   ('مبلغ', 2),
#   ('سود', 2),
#   ('که', 1),
#   ('خیلی', 1),
#   ('می', 1),
#   ('مدیرة', 1),
#   ('معاملاتی', 1),
#   ('معاملات', 1),
#   ('کرده', 1),
#   ('انجام', 1),
#   ('هر', 1),
#   ('نیست', 1),
#   ('ایران', 1)],
#  "['#آريان']": [('آريان', 2),
#   ('کرد', 1),
#   ('ریال', 1),
#   ('مجمع', 1),
#   ('در', 1),
#   ('پارس', 1),
#   ('با', 1),
#   ('سرمايه', 1),
#   ('نماد', 1),
#   ('تقسیم', 1),
#   ('گذاري', 1),
#   ('شرکت', 1),
#   ('خریداد', 0),
#   ('خریختخریخت', 0),
#   ('خرید', 0),
#   ('خریدpo', 0),
#   ('خریدا', 0),
#   ('ﻻزم', 0),
#   ('خریداري', 0),
#   ('خریدار', 0),
#   ('خریداران', 0),
#   ('خریدارو', 0),
#   ('خريدبخشي', 0),
#   ('خریداری', 0),
#   ('خریداقا', 0),
#   ('خریدثاخت', 0),
#   ('خریدخدمات', 0),
#   ('خریخت', 0),
#   ('خروجی', 0),
#   ('خريداري', 0)],
#  "['#آریا']": [('در', 26),
#   ('به', 23),
#   ('ریال', 23),
#   ('میلیارد', 19),
#   ('عرضه', 15),
#   ('با', 13),
#   ('آریا', 13),
#   ('فروش', 13),
#   ('شرکت', 12),
#   ('ساسول', 11),
#   ('این', 9),
#   ('است', 9),
#   ('اولیه', 9),
#   ('های', 8),
#   ('نرخ', 7),
#   ('ماهه', 7),
#   ('سهام', 7),
#   ('هم', 6),
#   ('هفته', 6),
#   ('سبک', 6),
#   ('سود', 6),
#   ('سنگین', 6),
#   ('شود', 6),
#   ('ریالی', 5),
#   ('می', 5),
#   ('شده', 5),
#   ('عدد', 5),
#   ('فردا', 5),
#   ('بود', 5),
#   ('سرمایه', 5)],
#  "['#آریان']": [('در', 11),
#   ('به', 6),
#   ('سود', 5),
#   ('آریان', 4),
#   ('سال', 4),
#   ('پارس', 4),
#   ('قبل', 3),
#   ('ریالی', 3),
#   ('شرکت', 3),
#   ('است', 3),
#   ('خيابان', 3),
#   ('ماهه', 3),
#   ('شده', 2),
#   ('عادی', 2),
#   ('داشت', 2),
#   ('مجمع', 2),
#   ('مي', 2),
#   ('با', 2),
#   ('گذاري', 2),
#   ('تحقق', 2),
#   ('را', 2),
#   ('شرکتهاي', 2),
#   ('ریال', 2),
#   ('سهام', 2),
#   ('سالیانه', 2),
#   ('عمومی', 2),
#   ('از', 2),
#   ('سامانه', 1),
#   ('روز', 1),
#   ('مالي', 1)],
#  "['#آسیا']": [('در', 26),
#   ('است', 17),
#   ('میلیارد', 13),
#   ('به', 12),
#   ('آسیا', 12),
#   ('از', 10),
#   ('با', 10),
#   ('بیمه', 10),
#   ('شرکت', 10),
#   ('ریالی', 9),
#   ('سود', 9),
#   ('ریال', 7),
#   ('را', 7),
#   ('که', 6),
#   ('ماهه', 6),
#   ('مالی', 6),
#   ('سرمایه', 5),
#   ('های', 5),
#   ('این', 5),
#   ('دارد', 4),
#   ('کرده', 4),
#   ('واحد', 4),
#   ('ارزیابی', 4),
#   ('محقق', 4),
#   ('املاک', 4),
#   ('خالص', 4),
#   ('تجدید', 4),
#   ('شماره', 4),
#   ('شده', 4),
#   ('اطلاع', 3)],
#  "['#آسیاتک']": [('از', 5),
#   ('به', 5),
#   ('سرمایه', 2),
#   ('انباشته', 2),
#   ('هیئت', 2),
#   ('ریال', 2),
#   ('سود', 2),
#   ('منظور', 2),
#   ('شده', 2),
#   ('مبلغ', 2),
#   ('در', 2),
#   ('محل', 2),
#   ('نقدينگي', 1),
#   ('نقدی', 1),
#   ('افزایش', 1),
#   ('معافيت', 1),
#   ('مالي', 1),
#   ('اصلاح', 1),
#   ('که', 1),
#   ('مزاياي', 1),
#   ('مالياتي', 1),
#   ('مطالبات', 1),
#   ('حال', 1),
#   ('جلوگيري', 1),
#   ('رسیده', 1),
#   ('آورده', 1),
#   ('مدیره', 1),
#   ('حسابرس', 1),
#   ('مدیرة', 1),
#   ('استفاده', 1)],
#  "['#آپ']": [('میلیارد', 146),
#   ('در', 141),
#   ('ریال', 136),
#   ('به', 77),
#   ('است', 60),
#   ('با', 47),
#   ('ماهه', 46),
#   ('سود', 45),
#   ('این', 41),
#   ('بوده', 39),
#   ('درامد', 27),
#   ('ریالی', 27),
#   ('آپ', 27),
#   ('سهم', 26),
#   ('رسیده', 25),
#   ('از', 23),
#   ('شرکت', 19),
#   ('عدد', 18),
#   ('شده', 18),
#   ('که', 18),
#   ('داشته', 17),
#   ('عملیاتی', 17),
#   ('فروش', 16),
#   ('های', 15),
#   ('خالص', 15),
#   ('جمع', 15),
#   ('ماه', 15),
#   ('کرد', 13),
#   ('کمی', 12),
#   ('رشد', 12)],
#  "['#آکنتور']": [('بهمن', 2),
#   ('روز', 1),
#   ('خرید', 1),
#   ('شنبه', 1),
#   ('از', 1),
#   ('قیمت', 1),
#   ('سفارش', 1),
#   ('فروش', 1),
#   ('حداکثر', 1),
#   ('است', 1),
#   ('آکنتور', 1),
#   ('میگیرد', 1),
#   ('تا', 1),
#   ('سهم', 1),
#   ('سه', 1),
#   ('خریداری', 0),
#   ('خریداري', 0),
#   ('خریداقا', 0),
#   ('خریختخریخت', 0),
#   ('خریدارو', 0),
#   ('خریداران', 0),
#   ('خریدار', 0),
#   ('خریداد', 0),
#   ('خریدا', 0),
#   ('خریدثاخت', 0),
#   ('خریدpo', 0),
#   ('خريدبخشي', 0),
#   ('خریخت', 0),
#   ('خریدسود', 0),
#   ('خردمندان', 0)],
#  "['#آینده']": [('به', 14),
#   ('در', 8),
#   ('زیان', 6),
#   ('آینده', 5),
#   ('سرمایه', 4),
#   ('ریال', 4),
#   ('صنعتي', 4),
#   ('افزایش', 4),
#   ('سازان', 4),
#   ('آينده', 4),
#   ('بهشت', 4),
#   ('پارس', 4),
#   ('با', 3),
#   ('تعلیق', 3),
#   ('نماد', 3),
#   ('تاریخ', 2),
#   ('فرابورس', 2),
#   ('ایران', 2),
#   ('دستورالعمل', 2),
#   ('بازرگاني', 2),
#   ('وضعیت', 2),
#   ('توجه', 2),
#   ('ماهه', 2),
#   ('ماده', 2),
#   ('استناد', 2),
#   ('گرددآینده', 2),
#   ('سهامداران', 2),
#   ('بند', 2),
#   ('مي', 2),
#   ('می', 2)],
#  "['#اتفاق', '#کگهر']": [('به', 3),
#   ('در', 3),
#   ('العاده', 2),
#   ('بطور', 2),
#   ('فوق', 2),
#   ('چهار', 2),
#   ('مجمع', 2),
#   ('براساس', 1),
#   ('کار', 1),
#   ('جالب', 1),
#   ('سامانه', 1),
#   ('خلاصه', 1),
#   ('خيابان', 1),
#   ('منتشره', 1),
#   ('ورزشي', 1),
#   ('سالن', 1),
#   ('امور', 1),
#   ('پارک', 1),
#   ('کدال', 1),
#   ('سهام', 1),
#   ('صاحبان', 1),
#   ('تاریخ', 1),
#   ('اجتماعي', 1),
#   ('ساعت', 1),
#   ('گردید', 1),
#   ('کگهر', 1),
#   ('وزارت', 1),
#   ('روز', 1),
#   ('حد', 1),
#   ('مجموعه', 1)],
#  "['#اتکام']": [('در', 34),
#   ('به', 34),
#   ('ریال', 22),
#   ('از', 18),
#   ('مبلغ', 16),
#   ('شرکت', 16),
#   ('سرمایه', 14),
#   ('مجمع', 13),
#   ('سود', 13),
#   ('افزایش', 11),
#   ('اتکام', 10),
#   ('مورخ', 9),
#   ('محل', 9),
#   ('عمومی', 8),
#   ('سهم', 8),
#   ('میلیون', 7),
#   ('کارمزد', 7),
#   ('ماهه', 6),
#   ('ثبت', 6),
#   ('که', 6),
#   ('است', 6),
#   ('انباشته', 6),
#   ('جلسه', 6),
#   ('این', 6),
#   ('تاریخ', 5),
#   ('منظور', 5),
#   ('ساعت', 5),
#   ('روز', 5),
#   ('اندوخته', 5),
#   ('ها', 5)],
#  "['#اتکای']": [('در', 24),
#   ('به', 22),
#   ('ریال', 18),
#   ('از', 17),
#   ('سود', 15),
#   ('افزایش', 10),
#   ('سرمایه', 10),
#   ('مبلغ', 8),
#   ('است', 8),
#   ('با', 8),
#   ('شرکت', 7),
#   ('اتکای', 7),
#   ('ماهه', 7),
#   ('میلیون', 6),
#   ('محل', 6),
#   ('میلیارد', 5),
#   ('مجمع', 5),
#   ('خيابان', 5),
#   ('جلسه', 5),
#   ('خالص', 5),
#   ('ریالی', 5),
#   ('اندوخته', 5),
#   ('که', 4),
#   ('سال', 4),
#   ('محقق', 4),
#   ('کرده', 4),
#   ('مورخ', 4),
#   ('انباشته', 4),
#   ('این', 4),
#   ('ثبت', 3)],
#  "['#اخابر']": [('در', 119),
#   ('ریال', 107),
#   ('میلیارد', 106),
#   ('به', 54),
#   ('فروش', 41),
#   ('است', 36),
#   ('ماهه', 34),
#   ('با', 33),
#   ('بوده', 31),
#   ('داشته', 31),
#   ('درامد', 26),
#   ('کمی', 23),
#   ('افت', 22),
#   ('شرکت', 22),
#   ('ریالی', 21),
#   ('اخابر', 19),
#   ('از', 19),
#   ('که', 17),
#   ('شد', 17),
#   ('این', 17),
#   ('تلفیقی', 15),
#   ('جمع', 15),
#   ('سود', 13),
#   ('مواجه', 12),
#   ('استاخابر', 12),
#   ('کرده', 12),
#   ('فروردین', 11),
#   ('را', 11),
#   ('عدد', 11),
#   ('نظر', 11)],
#  "['#اختصاصی', '#خرد']": [('خرد', 3),
#   ('معاملات', 3),
#   ('ارزش', 2),
#   ('میانگین', 2),
#   ('ابتدای', 1),
#   ('از', 1),
#   ('هفتگی', 1),
#   ('در', 1),
#   ('سال', 1),
#   ('اختصاصی', 1),
#   ('سوم', 1),
#   ('به', 1),
#   ('کار', 1),
#   ('تومان', 1),
#   ('خود', 1),
#   ('داد', 1),
#   ('با', 1),
#   ('میلیارد', 1),
#   ('هفته', 1),
#   ('دلاری', 1),
#   ('پایان', 1),
#   ('بهمن', 1),
#   ('خریداد', 0),
#   ('خريداري', 0),
#   ('خريدبخشي', 0),
#   ('خریخت', 0),
#   ('خریختخریخت', 0),
#   ('خرید', 0),
#   ('خریدpo', 0),
#   ('خریدا', 0)],
#  "['#اختصاصی', '#عربستان', '#نفت']": [('میلیارد', 19),
#   ('ریال', 15),
#   ('سال', 11),
#   ('است', 10),
#   ('بینی', 9),
#   ('در', 9),
#   ('پیش', 9),
#   ('بودجه', 8),
#   ('عربستان', 8),
#   ('درآمد', 8),
#   ('شده', 7),
#   ('دلار', 7),
#   ('تولید', 7),
#   ('نفت', 7),
#   ('از', 7),
#   ('می', 6),
#   ('برآورد', 6),
#   ('کسری', 6),
#   ('یا', 6),
#   ('با', 5),
#   ('ناخالص', 5),
#   ('به', 5),
#   ('سعودی', 5),
#   ('داخلی', 5),
#   ('شود', 4),
#   ('هزینه', 4),
#   ('کاهش', 4),
#   ('آینده', 3),
#   ('زده', 3),
#   ('که', 3)],
#  "['#ارفع', '#فملی', '#فخوز']": [('تن', 6),
#   ('عرضه', 6),
#   ('هزار', 4),
#   ('رشد', 3),
#   ('میلیارد', 3),
#   ('تقاضا', 3),
#   ('تومان', 3),
#   ('قیمت', 3),
#   ('نسبت', 3),
#   ('تا', 3),
#   ('نرخ', 3),
#   ('درصدی', 3),
#   ('رقابت', 3),
#   ('معامله', 3),
#   ('قیمتی', 3),
#   ('سقف', 3),
#   ('حدود', 3),
#   ('به', 3),
#   ('برای', 3),
#   ('ها', 3),
#   ('فولاد', 2),
#   ('شمش', 2),
#   ('بورس', 2),
#   ('پایهارزش', 2),
#   ('کالا', 1),
#   ('فملی', 1),
#   ('فخوز', 1),
#   ('مسقیمت', 1),
#   ('ارفع', 1),
#   ('آرمون', 1)],
#  "['#ارفع']": [('ریال', 162),
#   ('فروش', 124),
#   ('میلیارد', 123),
#   ('در', 117),
#   ('است', 106),
#   ('با', 87),
#   ('نرخ', 82),
#   ('ریالی', 61),
#   ('به', 52),
#   ('ماهه', 50),
#   ('تن', 42),
#   ('بوده', 41),
#   ('هزار', 39),
#   ('کرده', 36),
#   ('صادرات', 35),
#   ('سود', 33),
#   ('از', 32),
#   ('بود', 30),
#   ('شده', 29),
#   ('داخلی', 28),
#   ('مواجه', 26),
#   ('سهم', 24),
#   ('خوبی', 23),
#   ('ارفع', 23),
#   ('را', 22),
#   ('خوب', 21),
#   ('صادراتی', 20),
#   ('فروخته', 20),
#   ('که', 19),
#   ('عدد', 19)],
#  "['#اسیا']": [('به', 5),
#   ('از', 3),
#   ('منظور', 2),
#   ('ریال', 2),
#   ('هیئت', 2),
#   ('سرمایه', 2),
#   ('سود', 2),
#   ('انباشته', 2),
#   ('مبلغ', 2),
#   ('محل', 1),
#   ('گزارش', 1),
#   ('مالي', 1),
#   ('حسابرس', 1),
#   ('ساختار', 1),
#   ('بهبود', 1),
#   ('در', 1),
#   ('مدیره', 1),
#   ('مدیرة', 1),
#   ('شده', 1),
#   ('که', 1),
#   ('رسیده', 1),
#   ('بازرس', 1),
#   ('افزایش', 1),
#   ('قانونی', 1),
#   ('توجیهی', 1),
#   ('پیشنهادافزایش', 1),
#   ('اظهارنظر', 1),
#   ('جهت', 1),
#   ('تاریخ', 1),
#   ('اسیا', 1)],
#  "['#اعتلا', '#والبر']": [('از', 2),
#   ('ریال', 2),
#   ('زیر', 1),
#   ('مجموعه', 1),
#   ('تقسیم', 1),
#   ('های', 1),
#   ('والبر', 1),
#   ('کرد', 1),
#   ('اعتلا', 1),
#   ('خریدا', 0),
#   ('خريدبخشي', 0),
#   ('خریخت', 0),
#   ('خریختخریخت', 0),
#   ('خرید', 0),
#   ('خریدpo', 0),
#   ('ﻻزم', 0),
#   ('خریداد', 0),
#   ('خريداري', 0),
#   ('خریداران', 0),
#   ('خریدارو', 0),
#   ('خریداري', 0),
#   ('خریداری', 0),
#   ('خریداقا', 0),
#   ('خریدثاخت', 0),
#   ('خریدخدمات', 0),
#   ('خریدار', 0),
#   ('خريدار', 0),
#   ('خريداران', 0),
#   ('خریدش', 0),
#   ('خردادماه', 0)],
#  "['#اعتلا']": [('در', 38),
#   ('سرمایه', 30),
#   ('ریال', 30),
#   ('سود', 25),
#   ('به', 21),
#   ('از', 20),
#   ('گذاری', 16),
#   ('شرکت', 15),
#   ('میلیارد', 15),
#   ('است', 14),
#   ('ها', 14),
#   ('میلیون', 13),
#   ('فروش', 13),
#   ('استاعتلا', 12),
#   ('که', 11),
#   ('مبلغ', 11),
#   ('اعتلا', 11),
#   ('با', 11),
#   ('افزایش', 10),
#   ('محل', 8),
#   ('شده', 8),
#   ('را', 8),
#   ('مجمع', 8),
#   ('کرده', 8),
#   ('مطالبات', 7),
#   ('گزارش', 7),
#   ('داشته', 7),
#   ('آورده', 7),
#   ('ریالی', 6),
#   ('نقدی', 6)],
#  "['#افرا']": [('در', 45),
#   ('ریال', 28),
#   ('میلیارد', 26),
#   ('به', 24),
#   ('از', 22),
#   ('شرکت', 17),
#   ('درامد', 17),
#   ('است', 14),
#   ('با', 14),
#   ('که', 12),
#   ('خيابان', 10),
#   ('سود', 9),
#   ('ماهه', 9),
#   ('این', 8),
#   ('مجمع', 8),
#   ('شده', 8),
#   ('ریالی', 8),
#   ('افرا', 7),
#   ('سال', 6),
#   ('جمع', 6),
#   ('مورخ', 6),
#   ('قبل', 6),
#   ('فروش', 6),
#   ('استافرا', 6),
#   ('کرده', 6),
#   ('داشته', 5),
#   ('کل', 5),
#   ('جلسه', 5),
#   ('بوده', 5),
#   ('سهم', 5)],
#  "['#افق']": [('در', 145),
#   ('میلیارد', 136),
#   ('به', 108),
#   ('ریال', 108),
#   ('است', 83),
#   ('فروش', 54),
#   ('با', 52),
#   ('ریالی', 48),
#   ('ماهه', 46),
#   ('درامد', 45),
#   ('افق', 39),
#   ('سود', 38),
#   ('کوروش', 36),
#   ('سهم', 33),
#   ('از', 31),
#   ('شرکت', 30),
#   ('رسیده', 28),
#   ('این', 28),
#   ('های', 24),
#   ('بود', 24),
#   ('رشد', 23),
#   ('شده', 23),
#   ('سال', 22),
#   ('عدد', 22),
#   ('که', 20),
#   ('گزارش', 20),
#   ('بوده', 18),
#   ('خوب', 17),
#   ('ماه', 17),
#   ('را', 16)],
#  "['#افق)،']": [('افق', 2),
#   ('نماد', 1),
#   ('فروشگاه', 1),
#   ('امروز', 1),
#   ('معاملات', 1),
#   ('شنبه', 1),
#   ('تاييد', 1),
#   ('زنجيره', 1),
#   ('شركت', 1),
#   ('معاملاتي', 1),
#   ('نگرديد', 1),
#   ('سه', 1),
#   ('هاي', 1),
#   ('كوروش', 1),
#   ('اي', 1),
#   ('مورخ', 1),
#   ('كليه', 1),
#   ('خرید', 0),
#   ('خریخت', 0),
#   ('خریختخریخت', 0),
#   ('خريدبخشي', 0),
#   ('ﻻزم', 0),
#   ('خريداران', 0),
#   ('خریدpo', 0),
#   ('خریدا', 0),
#   ('خریداد', 0),
#   ('خریدار', 0),
#   ('خریداران', 0),
#   ('خریدارو', 0),
#   ('خريداري', 0)],
#  "['#البرز', '#اتکام']": [('بیمه', 3),
#   ('درصدی', 2),
#   ('البرز', 2),
#   ('می', 2),
#   ('شود', 2),
#   ('بلوک', 2),
#   ('در', 1),
#   ('سهام', 1),
#   ('توسط', 1),
#   ('ای', 1),
#   ('اتکایی', 1),
#   ('اتکام', 1),
#   ('عرضه', 1),
#   ('دولت', 1),
#   ('ایبنا', 1),
#   ('واگذار', 1),
#   ('شرکت', 1),
#   ('خصوصی', 1),
#   ('سازی', 1),
#   ('امین', 1),
#   ('سازمان', 1),
#   ('خریدخدمات', 0),
#   ('خریدارو', 0),
#   ('خرمشهرکوچه', 0),
#   ('خریداري', 0),
#   ('خریداری', 0),
#   ('خریداقا', 0),
#   ('خریدثاخت', 0),
#   ('خرنیگ', 0),
#   ('خرمشهر', 0)],
#  "['#البرز', '#شراز', '#شاوان']": [('ریال', 3),
#   ('شراز', 1),
#   ('البرز', 1),
#   ('شاوان', 1),
#   ('قیمت', 1),
#   ('است', 1),
#   ('بلوکی', 1),
#   ('بیمه', 1),
#   ('خریدثاخت', 0),
#   ('خریداد', 0),
#   ('خریدسود', 0),
#   ('خریخت', 0),
#   ('خریختخریخت', 0),
#   ('خرید', 0),
#   ('خریدpo', 0),
#   ('خریدا', 0),
#   ('خریدار', 0),
#   ('خریداقا', 0),
#   ('خریداران', 0),
#   ('خریدارو', 0),
#   ('خريدبخشي', 0),
#   ('خریداری', 0),
#   ('خریدخدمات', 0),
#   ('خریداري', 0),
#   ('ﻻزم', 0),
#   ('خریدش', 0),
#   ('خرمشهر', 0),
#   ('خردادماه', 0),
#   ('خردادومعادن', 0),
#   ('خردافزایش', 0)],
#  "['#البرز']": [('در', 51),
#   ('از', 37),
#   ('به', 34),
#   ('مالی', 27),
#   ('البرز', 27),
#   ('شرکت', 26),
#   ('با', 19),
#   ('است', 19),
#   ('بازار', 15),
#   ('سهم', 13),
#   ('سازی', 13),
#   ('های', 12),
#   ('بیمه', 12),
#   ('ماهه', 12),
#   ('ریال', 12),
#   ('افزايش', 11),
#   ('عرضه', 11),
#   ('گزارش', 11),
#   ('تاریخ', 11),
#   ('سود', 11),
#   ('تا', 11),
#   ('طي', 10),
#   ('که', 10),
#   ('قبلی', 10),
#   ('صورت', 10),
#   ('دوره', 9),
#   ('منتهی', 9),
#   ('سرمايه', 9),
#   ('گزارشگری', 9),
#   ('مقطع', 9)],
#  "['#امید']": [('ریال', 97),
#   ('در', 87),
#   ('میلیارد', 80),
#   ('است', 38),
#   ('به', 32),
#   ('سرمایه', 31),
#   ('امید', 27),
#   ('درامد', 26),
#   ('فروش', 25),
#   ('خوبی', 25),
#   ('از', 24),
#   ('زده', 23),
#   ('عدد', 20),
#   ('سال', 19),
#   ('شده', 16),
#   ('سود', 16),
#   ('ماه', 16),
#   ('را', 15),
#   ('ماهه', 15),
#   ('مالی', 15),
#   ('شرکت', 15),
#   ('مبلغ', 15),
#   ('کرده', 13),
#   ('این', 13),
#   ('که', 12),
#   ('اولین', 11),
#   ('با', 11),
#   ('گزارش', 11),
#   ('داشته', 11),
#   ('افزایش', 10)],
#  "['#انرژي']": [('سود', 6),
#   ('ریال', 6),
#   ('میلیارد', 5),
#   ('ریالی', 4),
#   ('در', 3),
#   ('است', 2),
#   ('ماهه', 2),
#   ('با', 2),
#   ('محقق', 2),
#   ('کرده', 2),
#   ('به', 2),
#   ('درامد', 2),
#   ('غیرعملیاتی', 2),
#   ('عملیاتی', 1),
#   ('بود', 1),
#   ('موفق', 1),
#   ('خالص', 1),
#   ('هر', 1),
#   ('را', 1),
#   ('حالا', 1),
#   ('رسیده', 1),
#   ('شده', 1),
#   ('تحقق', 1),
#   ('سهم', 1),
#   ('ايران', 1),
#   ('بورس', 1),
#   ('که', 1),
#   ('انرژي', 1),
#   ('دارد', 1),
#   ('خریداران', 0)],
#  "['#انرژی']": [('در', 27),
#   ('به', 25),
#   ('انرژی', 22),
#   ('بورس', 17),
#   ('با', 14),
#   ('اوراق', 12),
#   ('ریال', 11),
#   ('بهادار', 11),
#   ('ایران', 11),
#   ('از', 11),
#   ('است', 10),
#   ('سود', 9),
#   ('بازار', 9),
#   ('این', 9),
#   ('معاملات', 8),
#   ('های', 8),
#   ('هزار', 7),
#   ('پذیرش', 7),
#   ('می', 7),
#   ('میلیارد', 7),
#   ('بر', 6),
#   ('معاملاتی', 6),
#   ('ماهه', 6),
#   ('سازی', 6),
#   ('شرکت', 6),
#   ('ریالی', 6),
#   ('که', 6),
#   ('ماده', 5),
#   ('شد', 5),
#   ('رساند', 5)],
#  "['#اوان']": [('در', 84),
#   ('میلیارد', 65),
#   ('ریال', 57),
#   ('به', 54),
#   ('درامد', 38),
#   ('است', 33),
#   ('ماهه', 25),
#   ('شرکت', 22),
#   ('از', 21),
#   ('این', 20),
#   ('ریالی', 19),
#   ('با', 17),
#   ('که', 17),
#   ('داشته', 16),
#   ('را', 15),
#   ('سود', 15),
#   ('بوده', 13),
#   ('فروش', 13),
#   ('قبل', 13),
#   ('بود', 13),
#   ('های', 12),
#   ('سال', 12),
#   ('رسیده', 12),
#   ('اوان', 11),
#   ('سهم', 11),
#   ('عدد', 11),
#   ('محقق', 10),
#   ('ماه', 9),
#   ('استاوان', 9),
#   ('کرده', 9)],
#  "['#اوره']": [('نرخ', 3),
#   ('در', 3),
#   ('اوره', 3),
#   ('فارس', 3),
#   ('خلیج', 3),
#   ('دلاری', 2),
#   ('قرار', 2),
#   ('با', 2),
#   ('گرفت', 2),
#   ('دلار', 2),
#   ('قرارداد', 2),
#   ('به', 2),
#   ('توان', 1),
#   ('cfr', 1),
#   ('پارسیساوره', 1),
#   ('سواپ', 1),
#   ('این', 1),
#   ('را', 1),
#   ('کاهش', 1),
#   ('بررسی', 1),
#   ('متانول', 1),
#   ('چین', 1),
#   ('فوریه', 1),
#   ('رشد', 1),
#   ('تحلیلی', 1),
#   ('تن', 1),
#   ('اندکی', 1),
#   ('هر', 1),
#   ('سطح', 1),
#   ('ترین', 1)],
#  "['#اپرداز']": [('میلیارد', 138),
#   ('ریال', 131),
#   ('در', 130),
#   ('به', 51),
#   ('است', 47),
#   ('درامد', 42),
#   ('از', 35),
#   ('سود', 32),
#   ('با', 32),
#   ('بوده', 31),
#   ('ماهه', 31),
#   ('این', 27),
#   ('داشته', 24),
#   ('عدد', 22),
#   ('شده', 21),
#   ('کمی', 17),
#   ('اپرداز', 16),
#   ('مهر', 16),
#   ('سهم', 16),
#   ('فروش', 15),
#   ('ریالی', 15),
#   ('ابان', 14),
#   ('را', 13),
#   ('که', 13),
#   ('شرکت', 13),
#   ('استاپرداز', 13),
#   ('بهتر', 12),
#   ('مدت', 12),
#   ('رسیده', 11),
#   ('مشابه', 11)],
#  "['#اکتیو', '#قرن']": [('ریال', 1),
#   ('نهایی', 1),
#   ('عرضه', 1),
#   ('قرن', 1),
#   ('شد', 1),
#   ('اکتیو', 1),
#   ('اولیه', 1),
#   ('خریدا', 0),
#   ('خریخت', 0),
#   ('خریختخریخت', 0),
#   ('خرید', 0),
#   ('خریدpo', 0),
#   ('خریداد', 0),
#   ('خريداري', 0),
#   ('خریدار', 0),
#   ('خریداران', 0),
#   ('خریدارو', 0),
#   ('خریداري', 0),
#   ('خریداری', 0),
#   ('خریداقا', 0),
#   ('خریدثاخت', 0),
#   ('خریدخدمات', 0),
#   ('خریدسود', 0),
#   ('خريدبخشي', 0),
#   ('خريد', 0),
#   ('خريداران', 0),
#   ('خريدار', 0),
#   ('خردادماه', 0),
#   ('خردادومعادن', 0),
#   ('خردافزایش', 0)],
#  "['#اکتیو']": [('در', 9),
#   ('اکتیو', 8),
#   ('ریال', 7),
#   ('به', 6),
#   ('می', 5),
#   ('با', 5),
#   ('سهم', 5),
#   ('ماهه', 4),
#   ('قرن', 4),
#   ('که', 4),
#   ('میلیارد', 4),
#   ('بازار', 4),
#   ('عرضه', 4),
#   ('شود', 3),
#   ('کرده', 3),
#   ('بورس', 3),
#   ('محقق', 3),
#   ('کدال', 3),
#   ('شرکت', 3),
#   ('تهران', 3),
#   ('شیمی', 3),
#   ('سود', 3),
#   ('هفته', 3),
#   ('این', 2),
#   ('هر', 2),
#   ('است', 2),
#   ('های', 2),
#   ('آن', 2),
#   ('اولیه', 2),
#   ('حال', 2)],
#  "['#بالاس']": [('در', 56),
#   ('به', 29),
#   ('است', 24),
#   ('ماهه', 23),
#   ('مناقصه', 22),
#   ('ریال', 22),
#   ('شرکت', 19),
#   ('سود', 16),
#   ('از', 15),
#   ('راه', 13),
#   ('میلیارد', 13),
#   ('کرده', 12),
#   ('آهن', 12),
#   ('محقق', 9),
#   ('شدن', 9),
#   ('بوده', 8),
#   ('شده', 8),
#   ('ساختمان', 8),
#   ('برنده', 8),
#   ('این', 8),
#   ('بالاس', 7),
#   ('عملیاتی', 7),
#   ('بالاست', 6),
#   ('نیست', 6),
#   ('تاسیسات', 6),
#   ('بود', 6),
#   ('ریالی', 6),
#   ('پس', 6),
#   ('گزارش', 6),
#   ('اعلام', 6)],
#  "['#بالبر']": [('ریال', 149),
#   ('فروش', 116),
#   ('در', 110),
#   ('میلیارد', 100),
#   ('است', 91),
#   ('نرخ', 51),
#   ('با', 42),
#   ('ماهه', 39),
#   ('به', 30),
#   ('عدد', 23),
#   ('شده', 22),
#   ('بود', 21),
#   ('رشد', 20),
#   ('بوده', 20),
#   ('خوب', 19),
#   ('شرکت', 18),
#   ('زده', 18),
#   ('این', 18),
#   ('گزارش', 17),
#   ('بهمن', 17),
#   ('استبالبر', 17),
#   ('مالی', 17),
#   ('دی', 16),
#   ('سود', 16),
#   ('خوبی', 14),
#   ('کرده', 14),
#   ('نیز', 14),
#   ('کرد', 13),
#   ('بسیار', 13),
#   ('از', 12)],
#  "['#بایکا']": [('در', 18),
#   ('به', 12),
#   ('با', 11),
#   ('سود', 10),
#   ('مجمع', 6),
#   ('این', 6),
#   ('شرکت', 6),
#   ('سهم', 6),
#   ('است', 5),
#   ('ریال', 5),
#   ('ماهه', 5),
#   ('عمومی', 5),
#   ('خيابان', 4),
#   ('روز', 4),
#   ('برگزار', 4),
#   ('کرده', 4),
#   ('بایکا', 4),
#   ('زیان', 4),
#   ('ساعت', 4),
#   ('مورخ', 4),
#   ('توحيد', 4),
#   ('جلسه', 4),
#   ('خوش', 3),
#   ('نيايش', 3),
#   ('تاریخ', 3),
#   ('ايران', 3),
#   ('اول', 3),
#   ('شنبه', 3),
#   ('شناسایی', 3),
#   ('شرقي', 3)],
#  "['#بترانس', '#وبانک']": [('وبانک', 3),
#   ('سود', 2),
#   ('به', 2),
#   ('در', 2),
#   ('بترانس', 2),
#   ('ریال', 2),
#   ('شود', 2),
#   ('بلوک', 2),
#   ('حدود', 2),
#   ('واقع', 1),
#   ('مجموعا', 1),
#   ('فروخته', 1),
#   ('هر', 1),
#   ('از', 1),
#   ('اگر', 1),
#   ('تومان', 1),
#   ('ازای', 1),
#   ('فروش', 1),
#   ('صورتی', 1),
#   ('پکرمان', 1),
#   ('توسط', 1),
#   ('خواهد', 1),
#   ('بیش', 1),
#   ('میلیارد', 1),
#   ('رود', 1),
#   ('داشت', 1),
#   ('اضافه', 1),
#   ('می', 1),
#   ('برای', 1),
#   ('سهم', 1)],
#  "['#بترانس']": [('در', 217),
#   ('ریال', 162),
#   ('میلیارد', 143),
#   ('فروش', 132),
#   ('به', 100),
#   ('است', 91),
#   ('سود', 75),
#   ('از', 70),
#   ('با', 70),
#   ('ماهه', 60),
#   ('شرکت', 59),
#   ('ریالی', 57),
#   ('بترانس', 54),
#   ('بود', 48),
#   ('شده', 47),
#   ('نرخ', 41),
#   ('ترانسفورماتور', 37),
#   ('های', 37),
#   ('این', 35),
#   ('سال', 34),
#   ('که', 34),
#   ('بوده', 32),
#   ('را', 32),
#   ('مواجه', 31),
#   ('خالص', 30),
#   ('داشته', 27),
#   ('قبل', 26),
#   ('ترانسفو', 26),
#   ('کرده', 25),
#   ('خوب', 25)],
#  "['#بجهرم']": [('میلیارد', 32),
#   ('ریال', 28),
#   ('در', 26),
#   ('با', 15),
#   ('به', 15),
#   ('درامد', 15),
#   ('ریالی', 10),
#   ('ماهه', 10),
#   ('است', 9),
#   ('بجهرم', 9),
#   ('سهم', 8),
#   ('ها', 7),
#   ('بوده', 7),
#   ('داشته', 7),
#   ('جمع', 7),
#   ('استبجهرم', 5),
#   ('تا', 5),
#   ('کنون', 5),
#   ('بود', 5),
#   ('مواجه', 5),
#   ('رسید', 5),
#   ('سود', 5),
#   ('مرداد', 5),
#   ('شرکت', 4),
#   ('شهریور', 4),
#   ('مدت', 4),
#   ('زده', 4),
#   ('را', 4),
#   ('گزارش', 4),
#   ('رشد', 4)],
#  "['#بخاور']": [('در', 15),
#   ('به', 12),
#   ('ریال', 10),
#   ('فرابورس', 8),
#   ('شرکت', 8),
#   ('است', 8),
#   ('ماهه', 7),
#   ('پذیرش', 6),
#   ('محقق', 6),
#   ('سود', 5),
#   ('شده', 5),
#   ('یا', 5),
#   ('بیمه', 5),
#   ('بخاور', 4),
#   ('با', 4),
#   ('خاور', 4),
#   ('کرده', 4),
#   ('میانه', 4),
#   ('قبل', 4),
#   ('سهم', 3),
#   ('که', 3),
#   ('می', 3),
#   ('هر', 3),
#   ('سال', 3),
#   ('از', 3),
#   ('ازای', 3),
#   ('این', 3),
#   ('سرمایه', 3),
#   ('مورخ', 2),
#   ('کل', 2)],
#  "['#برکت']": [('به', 17),
#   ('در', 16),
#   ('شرکت', 10),
#   ('از', 9),
#   ('ریال', 9),
#   ('سرمایه', 8),
#   ('برکت', 7),
#   ('با', 7),
#   ('شماره', 6),
#   ('فروش', 6),
#   ('میلیارد', 5),
#   ('دارویی', 5),
#   ('مجمع', 5),
#   ('شده', 4),
#   ('تا', 4),
#   ('سالن', 4),
#   ('مورخ', 4),
#   ('شهرک', 4),
#   ('بازار', 4),
#   ('سود', 4),
#   ('چارسو', 4),
#   ('را', 4),
#   ('استبرکت', 4),
#   ('این', 4),
#   ('افزایش', 4),
#   ('می', 4),
#   ('تهران', 3),
#   ('مطالبات', 3),
#   ('ماه', 3),
#   ('ثبت', 3)],
#  "['#بزاگرس']": [('در', 58),
#   ('میلیارد', 52),
#   ('ریال', 41),
#   ('به', 36),
#   ('درامد', 22),
#   ('ریالی', 21),
#   ('فروش', 19),
#   ('با', 17),
#   ('سود', 16),
#   ('ماه', 15),
#   ('است', 13),
#   ('ماهه', 11),
#   ('استبزاگرس', 10),
#   ('داشته', 10),
#   ('از', 9),
#   ('سهم', 8),
#   ('مجموع', 8),
#   ('نیروگاه', 8),
#   ('مناقصه', 7),
#   ('هر', 7),
#   ('بوده', 7),
#   ('که', 7),
#   ('بود', 7),
#   ('های', 7),
#   ('بزاگرس', 7),
#   ('قبل', 7),
#   ('کرده', 6),
#   ('را', 6),
#   ('مواجه', 6),
#   ('داشت', 6)],
#  "['#بساما', '#سامان']": [('سهم', 2),
#   ('خبر', 1),
#   ('زده', 1),
#   ('اعلام', 1),
#   ('بساما', 1),
#   ('سامان', 1),
#   ('است', 1),
#   ('شفاف', 1),
#   ('تعداد', 1),
#   ('بانک', 1),
#   ('جالب', 1),
#   ('این', 1),
#   ('خرید', 1),
#   ('سهام', 1),
#   ('از', 1),
#   ('کرده', 1),
#   ('را', 1),
#   ('برای', 1),
#   ('سازی', 1),
#   ('خرسی', 0),
#   ('خرمشهر', 0),
#   ('خرمدره', 0),
#   ('خریدارو', 0),
#   ('خرم', 0),
#   ('خریداري', 0),
#   ('خریدار', 0),
#   ('خریداری', 0),
#   ('خرده', 0),
#   ('خردمندان', 0),
#   ('خردافزایش', 0)],
#  "['#بساما']": [('به', 29),
#   ('در', 25),
#   ('از', 22),
#   ('ریال', 21),
#   ('سود', 17),
#   ('شرکت', 14),
#   ('میلیارد', 13),
#   ('مبلغ', 11),
#   ('است', 10),
#   ('ماهه', 9),
#   ('بساما', 9),
#   ('با', 8),
#   ('های', 7),
#   ('مجمع', 7),
#   ('خالص', 7),
#   ('سرمایه', 7),
#   ('مورخ', 6),
#   ('سامان', 6),
#   ('شده', 6),
#   ('استبساما', 6),
#   ('میلیون', 5),
#   ('افزایش', 5),
#   ('ريال', 5),
#   ('ميليون', 5),
#   ('اندوخته', 5),
#   ('سهم', 5),
#   ('منظور', 4),
#   ('کرده', 4),
#   ('محقق', 4),
#   ('سال', 4)],
#  "['#بسویچ']": [('در', 158),
#   ('ریال', 147),
#   ('میلیارد', 118),
#   ('فروش', 79),
#   ('است', 66),
#   ('ماهه', 60),
#   ('با', 57),
#   ('به', 47),
#   ('بود', 37),
#   ('داشته', 36),
#   ('این', 35),
#   ('ریالی', 33),
#   ('نرخ', 30),
#   ('خوبی', 29),
#   ('شده', 27),
#   ('از', 24),
#   ('عدد', 23),
#   ('کمی', 22),
#   ('سود', 22),
#   ('رشد', 19),
#   ('صورت', 18),
#   ('سهم', 18),
#   ('شرکت', 17),
#   ('را', 17),
#   ('هر', 16),
#   ('بسویچ', 16),
#   ('درامد', 13),
#   ('مواجه', 13),
#   ('بوده', 13),
#   ('سال', 13)],
#  "['#بشهاب', '#بترانس']": [('به', 4),
#   ('اوراق', 3),
#   ('بهادار', 3),
#   ('رعایت', 3),
#   ('ماده', 2),
#   ('تهران', 2),
#   ('بورس', 2),
#   ('عدم', 2),
#   ('دستورالعمل', 1),
#   ('فرصت', 1),
#   ('اعطای', 1),
#   ('اجرایی', 1),
#   ('الزامات', 1),
#   ('های', 1),
#   ('موارد', 1),
#   ('در', 1),
#   ('افشای', 1),
#   ('شده', 1),
#   ('فوق', 1),
#   ('ثبت', 1),
#   ('ماهه', 1),
#   ('است', 1),
#   ('مي', 1),
#   ('توجه', 1),
#   ('با', 1),
#   ('رساند', 1),
#   ('پذیرش', 1),
#   ('سازمان', 1),
#   ('اطلاع', 1),
#   ('اطلاعات', 1)],
#  "['#بشهاب']": [('ریال', 137),
#   ('میلیارد', 125),
#   ('در', 104),
#   ('فروش', 103),
#   ('است', 80),
#   ('سود', 43),
#   ('ماهه', 39),
#   ('ریالی', 32),
#   ('بوده', 32),
#   ('با', 29),
#   ('این', 29),
#   ('لامپ', 27),
#   ('نرخ', 27),
#   ('کرده', 26),
#   ('روشن', 25),
#   ('بود', 23),
#   ('بشهاب', 21),
#   ('به', 20),
#   ('عدد', 20),
#   ('را', 19),
#   ('سهم', 19),
#   ('شده', 19),
#   ('عملیاتی', 15),
#   ('داشت', 15),
#   ('مهر', 14),
#   ('زده', 14),
#   ('داشته', 14),
#   ('افت', 14),
#   ('خوب', 13),
#   ('جمع', 12)],
#  "['#بعايق']": [('بعايق', 1),
#   ('عايق', 1),
#   ('شد', 1),
#   ('برگزار', 1),
#   ('پارس', 1),
#   ('الکتريکي', 1),
#   ('مجمع', 1),
#   ('هاي', 1),
#   ('تقسیم', 1),
#   ('شرکت', 1),
#   ('سود', 1),
#   ('شده', 1),
#   ('ریال', 1),
#   ('خریدpo', 0),
#   ('خریخت', 0),
#   ('خریختخریخت', 0),
#   ('خرید', 0),
#   ('ﻻزم', 0),
#   ('خریدا', 0),
#   ('خریداد', 0),
#   ('خریدار', 0),
#   ('خريداري', 0),
#   ('خریداران', 0),
#   ('خریدارو', 0),
#   ('خریداري', 0),
#   ('خریداری', 0),
#   ('خریداقا', 0),
#   ('خریدثاخت', 0),
#   ('خريدبخشي', 0),
#   ('خروجی', 0)],
#  "['#بعایق']": [('های', 2),
#   ('است', 2),
#   ('ریال', 2),
#   ('یا', 1),
#   ('کرده', 1),
#   ('در', 1),
#   ('عایق', 1),
#   ('سود', 1),
#   ('پارس', 1),
#   ('الکتریکی', 1),
#   ('تقریبا', 1),
#   ('با', 1),
#   ('مجموعه', 1),
#   ('بترانس', 1),
#   ('از', 1),
#   ('زیر', 1),
#   ('مجمع', 1),
#   ('تقسیم', 1),
#   ('که', 1),
#   ('بعایق', 1),
#   ('نماد', 1),
#   ('خریخت', 0),
#   ('خريدار', 0),
#   ('خریداري', 0),
#   ('خريداران', 0),
#   ('خريداري', 0),
#   ('خريدبخشي', 0),
#   ('خریدا', 0),
#   ('خریداد', 0),
#   ('خریختخریخت', 0)],
#  "['#بفجر', '#مبین']": [('به', 5),
#   ('شرکت', 4),
#   ('تمدید', 2),
#   ('توجه', 2),
#   ('نامه', 2),
#   ('با', 2),
#   ('های', 2),
#   ('روز', 2),
#   ('مهلت', 2),
#   ('رعایت', 2),
#   ('نظر', 1),
#   ('مذکور', 1),
#   ('ظرف', 1),
#   ('اوراق', 1),
#   ('شماره', 1),
#   ('طی', 1),
#   ('ثبت', 1),
#   ('تهران', 1),
#   ('صورت', 1),
#   ('اجرایی', 1),
#   ('بهادار', 1),
#   ('شده', 1),
#   ('برای', 1),
#   ('را', 1),
#   ('فوق', 1),
#   ('دیگر', 1),
#   ('گردد', 1),
#   ('بفجر', 1),
#   ('مورخ', 1),
#   ('عدم', 1)],
#  "['#بفجر']": [('در', 107),
#   ('ریال', 93),
#   ('میلیارد', 89),
#   ('است', 80),
#   ('به', 75),
#   ('شرکت', 43),
#   ('بوده', 36),
#   ('ماهه', 36),
#   ('فروش', 35),
#   ('که', 34),
#   ('این', 33),
#   ('شده', 29),
#   ('از', 28),
#   ('با', 27),
#   ('نرخ', 24),
#   ('سود', 23),
#   ('سال', 21),
#   ('بفجر', 19),
#   ('هم', 18),
#   ('درامد', 17),
#   ('داشته', 17),
#   ('گزارش', 16),
#   ('کرده', 15),
#   ('را', 15),
#   ('عدد', 13),
#   ('براي', 12),
#   ('مورخ', 12),
#   ('دستورالعمل', 12),
#   ('اين', 12),
#   ('ها', 11)],
#  "['#بموتو']": [('ریال', 166),
#   ('فروش', 159),
#   ('در', 140),
#   ('میلیارد', 128),
#   ('است', 93),
#   ('نرخ', 86),
#   ('با', 75),
#   ('به', 48),
#   ('ریالی', 47),
#   ('را', 37),
#   ('شده', 33),
#   ('سود', 33),
#   ('بود', 32),
#   ('خوب', 29),
#   ('بوده', 27),
#   ('از', 22),
#   ('کولری', 22),
#   ('یک', 22),
#   ('این', 21),
#   ('سال', 20),
#   ('ماهه', 20),
#   ('ماه', 19),
#   ('کرده', 19),
#   ('خوبی', 18),
#   ('محصولات', 18),
#   ('استبموتو', 16),
#   ('مواجه', 16),
#   ('که', 16),
#   ('رشد', 15),
#   ('زده', 15)],
#  "['#بمپنا']": [('در', 103),
#   ('ریال', 86),
#   ('میلیارد', 81),
#   ('به', 50),
#   ('است', 45),
#   ('درامد', 41),
#   ('با', 35),
#   ('ماهه', 32),
#   ('داشته', 26),
#   ('را', 26),
#   ('سود', 26),
#   ('این', 25),
#   ('شرکت', 19),
#   ('سهم', 19),
#   ('از', 18),
#   ('بوده', 18),
#   ('شده', 16),
#   ('رسیده', 16),
#   ('بمپنا', 16),
#   ('عدد', 15),
#   ('ریالی', 15),
#   ('که', 14),
#   ('فروش', 14),
#   ('جمع', 12),
#   ('کرده', 12),
#   ('خالص', 11),
#   ('خوبی', 10),
#   ('خوب', 10),
#   ('هر', 10),
#   ('افت', 10)],
#  "['#بمیلا']": [('ریال', 19),
#   ('در', 17),
#   ('سود', 16),
#   ('است', 11),
#   ('بمیلا', 9),
#   ('کرده', 8),
#   ('محقق', 7),
#   ('به', 7),
#   ('ماهه', 6),
#   ('میلیارد', 6),
#   ('سازی', 6),
#   ('از', 6),
#   ('شرکت', 5),
#   ('سال', 5),
#   ('داشته', 5),
#   ('رشد', 4),
#   ('با', 4),
#   ('بخش', 4),
#   ('قبل', 4),
#   ('را', 4),
#   ('فروش', 4),
#   ('گزارش', 4),
#   ('تومانی', 3),
#   ('که', 3),
#   ('درصد', 3),
#   ('میلیون', 3),
#   ('مدت', 3),
#   ('مشابه', 3),
#   ('نیز', 3),
#   ('استبمیلا', 3)],
#  "['#بنو']": [('به', 16),
#   ('ریال', 14),
#   ('در', 11),
#   ('سود', 9),
#   ('از', 7),
#   ('میلیارد', 7),
#   ('سرمایه', 7),
#   ('است', 6),
#   ('شرکت', 6),
#   ('مبلغ', 5),
#   ('نو', 5),
#   ('تجارت', 5),
#   ('مورخ', 4),
#   ('کرده', 4),
#   ('ریالی', 4),
#   ('محقق', 4),
#   ('بیمه', 4),
#   ('فرابورس', 4),
#   ('سهم', 4),
#   ('خالص', 4),
#   ('با', 4),
#   ('پذیرش', 3),
#   ('ثبت', 3),
#   ('افزایش', 3),
#   ('شده', 3),
#   ('رسیده', 3),
#   ('می', 3),
#   ('میلیون', 3),
#   ('یا', 3),
#   ('دارد', 2)],
#  "['#بنیرو']": [('در', 115),
#   ('فروش', 109),
#   ('میلیارد', 98),
#   ('ریال', 81),
#   ('است', 64),
#   ('با', 59),
#   ('ریالی', 52),
#   ('سود', 38),
#   ('را', 36),
#   ('ماهه', 33),
#   ('نرخ', 30),
#   ('داشته', 26),
#   ('بوده', 21),
#   ('کرده', 21),
#   ('به', 21),
#   ('بنیرو', 21),
#   ('بود', 20),
#   ('شده', 20),
#   ('رشد', 19),
#   ('مواجه', 19),
#   ('خوبی', 18),
#   ('این', 18),
#   ('از', 18),
#   ('gis', 17),
#   ('bay', 16),
#   ('نیز', 15),
#   ('ها', 14),
#   ('کمی', 14),
#   ('محقق', 13),
#   ('گزارش', 13)],
#  "['#بهپاک']": [('میلیارد', 116),
#   ('ریال', 107),
#   ('در', 106),
#   ('فروش', 77),
#   ('است', 62),
#   ('به', 44),
#   ('سود', 39),
#   ('ماهه', 38),
#   ('ریالی', 36),
#   ('با', 34),
#   ('از', 30),
#   ('کرده', 23),
#   ('را', 23),
#   ('سال', 22),
#   ('ماه', 22),
#   ('بوده', 21),
#   ('شده', 21),
#   ('افزایش', 20),
#   ('عدد', 19),
#   ('این', 19),
#   ('نرخ', 19),
#   ('خوبی', 18),
#   ('داشته', 18),
#   ('قبل', 16),
#   ('مالی', 16),
#   ('زده', 16),
#   ('شرکت', 16),
#   ('استبهپاک', 14),
#   ('عملیاتی', 13),
#   ('کمی', 13)],
#  "['#بودجه']": [('در', 34),
#   ('بودجه', 30),
#   ('از', 25),
#   ('به', 24),
#   ('تومان', 17),
#   ('میلیارد', 16),
#   ('شده', 16),
#   ('است', 15),
#   ('این', 14),
#   ('می', 14),
#   ('هزار', 14),
#   ('سال', 14),
#   ('برای', 13),
#   ('که', 12),
#   ('ها', 12),
#   ('با', 12),
#   ('دولت', 11),
#   ('افزایش', 10),
#   ('های', 9),
#   ('حدود', 7),
#   ('بنزین', 7),
#   ('لایحه', 7),
#   ('نرخ', 7),
#   ('تغییر', 7),
#   ('یارانه', 6),
#   ('شود', 6),
#   ('را', 6),
#   ('خواهد', 6),
#   ('قیمت', 6),
#   ('نشان', 5)],
#  "['#بورس']": [('در', 39),
#   ('به', 38),
#   ('ریال', 35),
#   ('بورس', 33),
#   ('میلیارد', 27),
#   ('درامد', 22),
#   ('شرکت', 21),
#   ('با', 15),
#   ('از', 14),
#   ('شده', 13),
#   ('است', 13),
#   ('هم', 11),
#   ('های', 10),
#   ('داشته', 9),
#   ('ماهه', 9),
#   ('این', 9),
#   ('می', 8),
#   ('سود', 8),
#   ('سال', 7),
#   ('رسیده', 7),
#   ('سرمایه', 6),
#   ('جمع', 6),
#   ('کل', 6),
#   ('مبلغ', 6),
#   ('قبل', 6),
#   ('ریالی', 5),
#   ('که', 5),
#   ('عالیجناب', 5),
#   ('ثبت', 5),
#   ('تاریخ', 5)],
#  "['#بوعلی', '#فارس']": [('است', 4),
#   ('که', 4),
#   ('در', 4),
#   ('ریال', 3),
#   ('را', 2),
#   ('سود', 2),
#   ('کرده', 2),
#   ('به', 2),
#   ('عرضه', 2),
#   ('اولیه', 2),
#   ('فارس', 2),
#   ('از', 2),
#   ('بوعلی', 2),
#   ('بسیار', 1),
#   ('هر', 1),
#   ('شود', 1),
#   ('مجموعه', 1),
#   ('سهمی', 1),
#   ('سينابا', 1),
#   ('سهم', 1),
#   ('خالص', 1),
#   ('بازار', 1),
#   ('ماهه', 1),
#   ('خوبی', 1),
#   ('طی', 1),
#   ('های', 1),
#   ('مشابه', 1),
#   ('نظر', 1),
#   ('مسیر', 1),
#   ('پتروشيمي', 1)],
#  "['#بوعلی']": [('شرکت', 2),
#   ('زند', 1),
#   ('شنبه', 1),
#   ('ساختمان', 1),
#   ('در', 1),
#   ('میگردد', 1),
#   ('ساعت', 1),
#   ('طبقه', 1),
#   ('ميدان', 1),
#   ('جلسه', 1),
#   ('فارس', 1),
#   ('تير', 1),
#   ('تهران', 1),
#   ('بلوار', 1),
#   ('نرسيده', 1),
#   ('کنفرانس', 1),
#   ('يازده', 1),
#   ('سالن', 1),
#   ('پتروشيمي', 1),
#   ('خليج', 1),
#   ('بوعلی', 1),
#   ('روز', 1),
#   ('به', 1),
#   ('خان', 1),
#   ('این', 1),
#   ('مجمع', 1),
#   ('عمومی', 1),
#   ('کريم', 1),
#   ('پلاک', 1),
#   ('برگزار', 1)],
#  "['#بپاس', '#وپاسار']": [('پاسارگاد', 10),
#   ('بانک', 8),
#   ('بیمه', 8),
#   ('این', 7),
#   ('به', 5),
#   ('سهام', 5),
#   ('را', 5),
#   ('با', 4),
#   ('ها', 4),
#   ('های', 4),
#   ('شرکت', 3),
#   ('برخی', 2),
#   ('بنگاهداری', 2),
#   ('بنابراین', 2),
#   ('برای', 2),
#   ('قانون', 2),
#   ('قیمت', 2),
#   ('توسط', 2),
#   ('وپاسار', 2),
#   ('که', 2),
#   ('درصد', 2),
#   ('شد', 2),
#   ('از', 2),
#   ('است', 2),
#   ('در', 2),
#   ('اسفند', 1),
#   ('کاهش', 1),
#   ('براساس', 1),
#   ('هایی', 1),
#   ('ارتباطی', 1)],
#  "['#بپاس']": [('ریال', 28),
#   ('سود', 20),
#   ('در', 18),
#   ('به', 15),
#   ('از', 15),
#   ('میلیارد', 14),
#   ('مبلغ', 13),
#   ('است', 11),
#   ('سرمایه', 11),
#   ('محل', 9),
#   ('میلیون', 8),
#   ('افزایش', 8),
#   ('انباشته', 7),
#   ('بپاس', 7),
#   ('ماهه', 6),
#   ('کرده', 6),
#   ('مورخ', 6),
#   ('اندوخته', 6),
#   ('ها', 6),
#   ('خالص', 6),
#   ('مجمع', 5),
#   ('استبپاس', 5),
#   ('داشته', 5),
#   ('العاده', 4),
#   ('مدیره', 4),
#   ('فوق', 4),
#   ('ریالی', 4),
#   ('می', 4),
#   ('هیئت', 4),
#   ('محقق', 4)],
#  "['#بکاب']": [('ریال', 74),
#   ('در', 73),
#   ('میلیارد', 54),
#   ('به', 46),
#   ('فروش', 45),
#   ('است', 28),
#   ('ماهه', 27),
#   ('از', 24),
#   ('سود', 21),
#   ('با', 18),
#   ('ماه', 16),
#   ('سال', 15),
#   ('این', 14),
#   ('نیز', 14),
#   ('مالی', 13),
#   ('نرخ', 13),
#   ('میلیون', 13),
#   ('شرکت', 13),
#   ('بود', 13),
#   ('استبکاب', 13),
#   ('که', 11),
#   ('مدت', 11),
#   ('بکاب', 11),
#   ('داشته', 11),
#   ('کرده', 10),
#   ('مشابه', 10),
#   ('ریالی', 10),
#   ('سهم', 10),
#   ('عدد', 9),
#   ('زده', 9)],
#  "['#بکام']": [('در', 82),
#   ('ریال', 64),
#   ('میلیارد', 62),
#   ('به', 53),
#   ('با', 51),
#   ('فروش', 43),
#   ('درامد', 35),
#   ('است', 34),
#   ('ریالی', 29),
#   ('ماهه', 25),
#   ('از', 25),
#   ('بکام', 24),
#   ('که', 23),
#   ('این', 23),
#   ('بود', 22),
#   ('داشته', 19),
#   ('بوده', 19),
#   ('کرده', 19),
#   ('خوبی', 18),
#   ('مواجه', 18),
#   ('را', 17),
#   ('زیان', 17),
#   ('ولی', 17),
#   ('شرکت', 16),
#   ('سود', 16),
#   ('زده', 15),
#   ('غیرعملیاتی', 13),
#   ('عدد', 13),
#   ('برای', 13),
#   ('اذر', 13)],
#  "['#بکهنوج']": [('در', 150),
#   ('به', 91),
#   ('میلیارد', 78),
#   ('فروش', 68),
#   ('ریال', 56),
#   ('است', 52),
#   ('از', 44),
#   ('با', 40),
#   ('برق', 37),
#   ('سال', 36),
#   ('درامد', 33),
#   ('ریالی', 31),
#   ('که', 31),
#   ('ماه', 29),
#   ('شده', 27),
#   ('ماهه', 26),
#   ('شرکت', 24),
#   ('رسیده', 23),
#   ('داشته', 22),
#   ('نرخ', 20),
#   ('این', 19),
#   ('بکهنوج', 18),
#   ('بود', 18),
#   ('مالی', 17),
#   ('شوباد', 17),
#   ('واحد', 16),
#   ('عدد', 15),
#   ('قرارداد', 14),
#   ('تضميني', 14),
#   ('گذشته', 13)],
#  "['#بکهنوح']": [('زیان', 2),
#   ('با', 2),
#   ('هزینه', 2),
#   ('ریال', 2),
#   ('ماهه', 2),
#   ('ازای', 1),
#   ('نیست', 1),
#   ('است', 1),
#   ('رشد', 1),
#   ('شناسایی', 1),
#   ('کرده', 1),
#   ('عملیاتی', 1),
#   ('نداشته', 1),
#   ('بکهنوح', 1),
#   ('عملکرد', 1),
#   ('مالی', 1),
#   ('خوبی', 1),
#   ('به', 1),
#   ('گزارش', 1),
#   ('های', 1),
#   ('قوی', 1),
#   ('هر', 1),
#   ('میلیارد', 1),
#   ('سهم', 1),
#   ('ها', 1),
#   ('خرمشهرکوچه', 0),
#   ('خريدار', 0),
#   ('خريداران', 0),
#   ('خردادفاذر', 0),
#   ('خريداري', 0)],
#  "['#بگیلان']": [('در', 18),
#   ('ریال', 14),
#   ('میلیارد', 10),
#   ('است', 9),
#   ('کرده', 7),
#   ('بگیلان', 6),
#   ('محقق', 6),
#   ('ماهه', 6),
#   ('درامد', 5),
#   ('با', 5),
#   ('سود', 5),
#   ('گيلان', 5),
#   ('به', 4),
#   ('برق', 4),
#   ('سهم', 4),
#   ('داشته', 4),
#   ('مسير', 4),
#   ('فروش', 4),
#   ('شرکت', 3),
#   ('هر', 3),
#   ('سال', 3),
#   ('مدت', 3),
#   ('ریالی', 3),
#   ('بوده', 3),
#   ('مشابه', 3),
#   ('از', 3),
#   ('استتوسعه', 3),
#   ('نماد', 2),
#   ('ولی', 2),
#   ('عرضه', 2)],
#  "['#بیلت', '#اسلب']": [('بیلت', 4),
#   ('اسلب', 4),
#   ('در', 4),
#   ('ایران', 3),
#   ('شد', 3),
#   ('صادراتی', 3),
#   ('دامنه', 3),
#   ('معامله', 3),
#   ('دلار', 3),
#   ('تا', 2),
#   ('cis', 2),
#   ('هفته', 1),
#   ('گذشته', 1),
#   ('با', 1),
#   ('قیمت', 1),
#   ('نرخ', 1),
#   ('ثبات', 1),
#   ('خريداري', 0),
#   ('خریخت', 0),
#   ('خریختخریخت', 0),
#   ('خرید', 0),
#   ('خریدpo', 0),
#   ('خریدا', 0),
#   ('خریداد', 0),
#   ('خریدار', 0),
#   ('خریداران', 0),
#   ('خریدارو', 0),
#   ('خریداري', 0),
#   ('خریداری', 0),
#   ('خریداقا', 0)],
#  "['#تابا']": [('به', 22),
#   ('در', 21),
#   ('ریال', 12),
#   ('از', 12),
#   ('زیان', 10),
#   ('شرکت', 9),
#   ('مبلغ', 8),
#   ('سرمایه', 8),
#   ('است', 7),
#   ('منظور', 6),
#   ('اصفهان', 6),
#   ('هیئت', 6),
#   ('رسیده', 6),
#   ('که', 5),
#   ('نقدی', 5),
#   ('گزارش', 5),
#   ('ماهه', 5),
#   ('تاریخ', 5),
#   ('سهامداران', 5),
#   ('شده', 5),
#   ('آورده', 5),
#   ('مجمع', 4),
#   ('قانونی', 4),
#   ('تابا', 4),
#   ('عمومی', 4),
#   ('کرده', 4),
#   ('طرح', 3),
#   ('تصویب', 3),
#   ('شرقي', 3),
#   ('ارسال', 3)],
#  "['#تاصيکو']": [('است', 2),
#   ('ماهه', 2),
#   ('که', 1),
#   ('صورت', 1),
#   ('سال', 1),
#   ('بود', 1),
#   ('منتظر', 1),
#   ('صدر', 1),
#   ('داده', 1),
#   ('تامین', 1),
#   ('های', 1),
#   ('سود', 1),
#   ('تاصيکو', 1),
#   ('محقق', 1),
#   ('سهم', 1),
#   ('ریال', 1),
#   ('تحقق', 1),
#   ('بوده', 1),
#   ('کرده', 1),
#   ('مالی', 1),
#   ('نماد', 1),
#   ('باید', 1),
#   ('قبل', 1),
#   ('خریدا', 0),
#   ('خريداران', 0),
#   ('خروجي', 0),
#   ('خریداد', 0),
#   ('خروجی', 0),
#   ('خسته', 0),
#   ('خريد', 0)],
#  "['#تاصیکو', '#تاپیکو']": [('سود', 2),
#   ('به', 1),
#   ('حدود', 1),
#   ('می', 1),
#   ('ریال', 1),
#   ('اضافه', 1),
#   ('میلیارد', 1),
#   ('تاپیکو', 1),
#   ('تقسیم', 1),
#   ('تاصیکو', 1),
#   ('شود', 1),
#   ('با', 1),
#   ('ﻻزم', 0),
#   ('خریدpo', 0),
#   ('خریدا', 0),
#   ('خریختخریخت', 0),
#   ('خرید', 0),
#   ('خریداران', 0),
#   ('خریداد', 0),
#   ('خریدار', 0),
#   ('خریدارو', 0),
#   ('خریداري', 0),
#   ('خریداری', 0),
#   ('خریداقا', 0),
#   ('خریدثاخت', 0),
#   ('خریدخدمات', 0),
#   ('خریدسود', 0),
#   ('خریخت', 0),
#   ('خريدار', 0),
#   ('خريدبخشي', 0)],
#  "['#تاصیکو']": [('در', 84),
#   ('به', 41),
#   ('تاصیکو', 36),
#   ('سهم', 33),
#   ('گذاری', 26),
#   ('شرکت', 25),
#   ('سرمایه', 24),
#   ('ریال', 24),
#   ('از', 23),
#   ('است', 23),
#   ('این', 23),
#   ('با', 22),
#   ('عرضه', 21),
#   ('سود', 20),
#   ('را', 19),
#   ('میلیارد', 17),
#   ('تامین', 15),
#   ('هر', 14),
#   ('درصد', 14),
#   ('ارزش', 14),
#   ('فروش', 14),
#   ('ها', 14),
#   ('روز', 14),
#   ('سهام', 14),
#   ('گزارش', 13),
#   ('که', 13),
#   ('حال', 12),
#   ('ماه', 12),
#   ('می', 11),
#   ('اولیه', 11)],
#  "['#تاصیکو)،']": [('درصد', 7),
#   ('میلیارد', 4),
#   ('تومان', 3),
#   ('در', 3),
#   ('ارزش', 3),
#   ('پرتفوی', 3),
#   ('دارد', 2),
#   ('آن', 2),
#   ('تمام', 2),
#   ('شده', 2),
#   ('است', 2),
#   ('بهای', 2),
#   ('بورسی', 2),
#   ('غیر', 1),
#   ('شاملا', 1),
#   ('خود', 1),
#   ('مالکیت', 1),
#   ('سهم', 1),
#   ('صدر', 1),
#   ('خالص', 1),
#   ('را', 1),
#   ('برآوردی', 1),
#   ('ومعادن', 1),
#   ('قابل', 1),
#   ('nav', 1),
#   ('روز', 1),
#   ('مشاهده', 1),
#   ('سرمایه', 1),
#   ('فباهنر', 1),
#   ('استهمچنین', 1)],
#  "['#تاصیکو،', '#رمپنا،', '#تیپیکو', '#تاپیکو']": [('برگزاری', 2),
#   ('مجمع', 2),
#   ('نقدی', 2),
#   ('سالیانه', 2),
#   ('عادی', 2),
#   ('بر', 2),
#   ('عمومی', 2),
#   ('سود', 2),
#   ('پس', 2),
#   ('از', 2),
#   ('تقسیم', 2),
#   ('مبنی', 2),
#   ('معاملات', 1),
#   ('تاپیکو', 1),
#   ('به', 1),
#   ('تیپیکو', 1),
#   ('تاصیکو', 1),
#   ('داریم', 1),
#   ('رمپنا', 1),
#   ('مهمان', 1),
#   ('گردونه', 1),
#   ('بازمیگردند', 1),
#   ('نمادهای', 1),
#   ('خرید', 0),
#   ('خریداران', 0),
#   ('خریدارو', 0),
#   ('خریداري', 0),
#   ('خریداری', 0),
#   ('خریدار', 0),
#   ('خریداقا', 0)],
#  "['#تاپکیش', '#رتاپ']": [('قرارداد', 3),
#   ('مالی', 2),
#   ('با', 2),
#   ('که', 2),
#   ('رتاپ', 2),
#   ('به', 2),
#   ('تاپکیش', 1),
#   ('بسته', 1),
#   ('منتهی', 1),
#   ('این', 1),
#   ('در', 1),
#   ('است', 1),
#   ('سال', 1),
#   ('بود', 1),
#   ('های', 1),
#   ('بخش', 1),
#   ('دلیل', 1),
#   ('آینده', 1),
#   ('البته', 1),
#   ('فروش', 1),
#   ('بخشی', 1),
#   ('دستگاه', 1),
#   ('را', 1),
#   ('محرمانه', 1),
#   ('خواهد', 1),
#   ('آثار', 1),
#   ('از', 1),
#   ('بودن', 1),
#   ('کارتخوان', 1),
#   ('حذف', 1)],
#  "['#تاپکیش']": [('میلیارد', 109),
#   ('ریال', 83),
#   ('در', 80),
#   ('فروش', 71),
#   ('با', 62),
#   ('سود', 46),
#   ('است', 46),
#   ('درامد', 42),
#   ('ریالی', 41),
#   ('ماهه', 34),
#   ('به', 32),
#   ('این', 22),
#   ('بود', 21),
#   ('قبل', 20),
#   ('سال', 20),
#   ('شده', 20),
#   ('اسفند', 17),
#   ('مواجه', 17),
#   ('کرده', 17),
#   ('را', 16),
#   ('سهم', 16),
#   ('داشته', 16),
#   ('زده', 16),
#   ('عملیاتی', 14),
#   ('تاپکیش', 13),
#   ('بوده', 13),
#   ('محقق', 12),
#   ('خالص', 12),
#   ('نیز', 11),
#   ('ماه', 11)],
#  "['#تاپیکو', '#تاصیکو']": [('سهام', 23),
#   ('به', 23),
#   ('در', 22),
#   ('از', 19),
#   ('تاپیکو', 17),
#   ('شرکت', 15),
#   ('تاصیکو', 14),
#   ('درصد', 11),
#   ('است', 10),
#   ('میلیارد', 9),
#   ('گروه', 9),
#   ('تامین', 9),
#   ('های', 9),
#   ('هلدینگ', 9),
#   ('با', 9),
#   ('بر', 8),
#   ('نوین', 8),
#   ('این', 8),
#   ('گستر', 8),
#   ('صنعت', 8),
#   ('سلولزی', 8),
#   ('شده', 7),
#   ('ریال', 6),
#   ('بلوک', 6),
#   ('دیگر', 5),
#   ('حدود', 5),
#   ('فروش', 5),
#   ('خواهد', 4),
#   ('بیش', 4),
#   ('کلیه', 4)],
#  "['#تاپیکو', '#شستا']": [('در', 26),
#   ('تاپیکو', 20),
#   ('به', 19),
#   ('سهام', 16),
#   ('این', 15),
#   ('رشد', 13),
#   ('را', 12),
#   ('از', 12),
#   ('شرکت', 11),
#   ('نفت', 11),
#   ('بر', 10),
#   ('پرتفوی', 9),
#   ('ستاره', 8),
#   ('که', 8),
#   ('سهم', 8),
#   ('با', 8),
#   ('دیگر', 7),
#   ('های', 6),
#   ('است', 6),
#   ('پتروشیمی', 6),
#   ('مالی', 6),
#   ('سال', 6),
#   ('باشد', 5),
#   ('داشته', 5),
#   ('ارزش', 5),
#   ('درصد', 5),
#   ('بازار', 5),
#   ('روز', 5),
#   ('دلیل', 4),
#   ('ورود', 4)],
#  "['#تاپیکو', '#شفن']": [('به', 4),
#   ('از', 3),
#   ('مرجان', 3),
#   ('سهام', 3),
#   ('آن', 2),
#   ('عدم', 2),
#   ('میلیارد', 2),
#   ('تومان', 2),
#   ('طی', 2),
#   ('در', 2),
#   ('گزارش', 2),
#   ('آوران', 2),
#   ('واگذاری', 2),
#   ('پتروشیمی', 2),
#   ('فن', 2),
#   ('شفن', 2),
#   ('مورد', 2),
#   ('درصد', 2),
#   ('حدود', 2),
#   ('پذیرد', 1),
#   ('مذکور', 1),
#   ('شده', 1),
#   ('صورت', 1),
#   ('دریافت', 1),
#   ('كه', 1),
#   ('انتقال', 1),
#   ('فروش', 1),
#   ('را', 1),
#   ('مراحل', 1),
#   ('فوق', 1)],
#  "['#تاپیکو', '#وپترو']": [('در', 10),
#   ('به', 6),
#   ('درصد', 5),
#   ('وپترو', 5),
#   ('با', 5),
#   ('سـهام', 4),
#   ('پتروشیمی', 3),
#   ('سرمایه', 3),
#   ('خریداري', 3),
#   ('این', 3),
#   ('صنایع', 3),
#   ('نماد', 3),
#   ('ناخالص', 2),
#   ('شرکت', 2),
#   ('تعداد', 2),
#   ('می', 2),
#   ('شده', 2),
#   ('هر', 2),
#   ('گذاری', 2),
#   ('قیمت', 2),
#   ('سهم', 2),
#   ('گذاري', 2),
#   ('تاریخ', 2),
#   ('هلدینگ', 2),
#   ('مالکیت', 2),
#   ('افزایش', 2),
#   ('بورس', 2),
#   ('ها', 2),
#   ('صورت', 2),
#   ('شـرکت', 2)],
#  "['#تاپیکو', '#پارسان']": [('در', 6),
#   ('از', 6),
#   ('به', 4),
#   ('سرمایه', 3),
#   ('این', 3),
#   ('گذاری', 3),
#   ('شرکت', 3),
#   ('نقد', 2),
#   ('واگذار', 2),
#   ('نفت', 2),
#   ('باشد', 2),
#   ('صورت', 2),
#   ('ریال', 2),
#   ('میلیون', 2),
#   ('هیات', 2),
#   ('آریا', 2),
#   ('تاپیکو', 2),
#   ('می', 2),
#   ('گازی', 2),
#   ('توسعه', 2),
#   ('سهام', 2),
#   ('گاز', 2),
#   ('گردید', 2),
#   ('پالایشگاه', 2),
#   ('مبلغ', 2),
#   ('معامله', 2),
#   ('مدیره', 2),
#   ('فوق', 1),
#   ('هزار', 1),
#   ('بابت', 1)],
#  "['#تاپیکو']": [('در', 130),
#   ('از', 70),
#   ('به', 69),
#   ('تاپیکو', 55),
#   ('شرکت', 50),
#   ('سال', 45),
#   ('سود', 41),
#   ('ریال', 36),
#   ('میلیارد', 33),
#   ('این', 29),
#   ('های', 26),
#   ('با', 25),
#   ('می', 23),
#   ('را', 20),
#   ('است', 19),
#   ('درصد', 18),
#   ('سرمایه', 18),
#   ('نفت', 17),
#   ('سهام', 17),
#   ('شده', 16),
#   ('ماهه', 16),
#   ('فروش', 16),
#   ('مجموعه', 15),
#   ('گذاری', 14),
#   ('پتروشیمی', 14),
#   ('داشته', 13),
#   ('قبل', 12),
#   ('هلدینگ', 12),
#   ('افزایش', 12),
#   ('تولید', 12)],
#  "['#تایرا', '#خبهمن']": [('سود', 2),
#   ('تایرا', 1),
#   ('کرد', 1),
#   ('میلیارد', 1),
#   ('دریافت', 1),
#   ('محل', 1),
#   ('از', 1),
#   ('خبهمن', 1),
#   ('که', 1),
#   ('خواهد', 1),
#   ('خبرخوبی', 1),
#   ('تقسیم', 1),
#   ('است', 1),
#   ('ریال', 1),
#   ('برای', 1),
#   ('این', 1),
#   ('خریدا', 0),
#   ('خرید', 0),
#   ('خریختخریخت', 0),
#   ('خریدpo', 0),
#   ('ﻻزم', 0),
#   ('خریداد', 0),
#   ('خریدار', 0),
#   ('خريدبخشي', 0),
#   ('خریداران', 0),
#   ('خریدارو', 0),
#   ('خریداري', 0),
#   ('خریداری', 0),
#   ('خریداقا', 0),
#   ('خریخت', 0)],
#  "['#تایرا']": [('در', 156),
#   ('ریال', 140),
#   ('میلیارد', 134),
#   ('فروش', 94),
#   ('ماهه', 83),
#   ('است', 72),
#   ('داشته', 48),
#   ('تایرا', 47),
#   ('سود', 40),
#   ('بوده', 37),
#   ('که', 37),
#   ('با', 36),
#   ('از', 35),
#   ('ریالی', 35),
#   ('به', 32),
#   ('عدد', 31),
#   ('را', 30),
#   ('خوبی', 29),
#   ('بود', 28),
#   ('خوب', 27),
#   ('این', 26),
#   ('کرده', 24),
#   ('مواجه', 24),
#   ('سهم', 24),
#   ('محقق', 23),
#   ('شده', 23),
#   ('تلفیقی', 23),
#   ('ماه', 18),
#   ('های', 18),
#   ('عملیاتی', 17)],
#  "['#تبرک', '#غشهداب']": [('فروش', 1),
#   ('است', 1),
#   ('محل', 1),
#   ('میلیارد', 1),
#   ('در', 1),
#   ('از', 1),
#   ('تبرک', 1),
#   ('شناسایی', 1),
#   ('کرده', 1),
#   ('غشهداب', 1),
#   ('فروردین', 1),
#   ('ریال', 1),
#   ('سود', 1),
#   ('خریختخریخت', 0),
#   ('خرید', 0),
#   ('خریدpo', 0),
#   ('خریخت', 0),
#   ('ﻻزم', 0),
#   ('خریداد', 0),
#   ('خریدا', 0),
#   ('خريداري', 0),
#   ('خریدار', 0),
#   ('خریداران', 0),
#   ('خریدارو', 0),
#   ('خریداري', 0),
#   ('خریداری', 0),
#   ('خریداقا', 0),
#   ('خریدثاخت', 0),
#   ('خريدبخشي', 0),
#   ('خروجی', 0)],
#  "['#تبرک']": [('در', 12),
#   ('تبرک', 9),
#   ('سود', 8),
#   ('به', 7),
#   ('از', 6),
#   ('فروش', 6),
#   ('با', 6),
#   ('میلیارد', 5),
#   ('سرمایه', 4),
#   ('ها', 4),
#   ('ریالی', 4),
#   ('ریال', 4),
#   ('گذاری', 4),
#   ('کارخانجات', 3),
#   ('صدا', 3),
#   ('های', 3),
#   ('سیما', 3),
#   ('سازی', 2),
#   ('است', 2),
#   ('قرارداد', 2),
#   ('شرکت', 2),
#   ('را', 2),
#   ('کرده', 2),
#   ('صنعتي', 2),
#   ('تبلیغ', 2),
#   ('تبلیغات', 2),
#   ('مجموعه', 2),
#   ('محل', 2),
#   ('سال', 2),
#   ('خالص', 2)],
#  "['#تجار']": [('در', 21),
#   ('به', 17),
#   ('سهام', 12),
#   ('اين', 11),
#   ('با', 11),
#   ('از', 10),
#   ('سرمايه', 7),
#   ('شركت', 7),
#   ('موضوع', 6),
#   ('فروش', 6),
#   ('كه', 5),
#   ('سهم', 5),
#   ('شرکت', 5),
#   ('را', 5),
#   ('تغییر', 4),
#   ('است', 4),
#   ('بوده', 4),
#   ('بازار', 4),
#   ('قيمت', 4),
#   ('آن', 4),
#   ('تجار', 4),
#   ('مجمع', 4),
#   ('گذاري', 4),
#   ('ریال', 3),
#   ('هر', 3),
#   ('بتواند', 3),
#   ('ليزينگ', 3),
#   ('بهاي', 3),
#   ('ايرانيان', 3),
#   ('توجه', 3)],
#  "['#تحمرکه']": [('شرکت', 2),
#   ('بلوار', 2),
#   ('مورخ', 1),
#   ('نيرومحرکه', 1),
#   ('عمومی', 1),
#   ('ساعت', 1),
#   ('در', 1),
#   ('این', 1),
#   ('البرز', 1),
#   ('شهر', 1),
#   ('روز', 1),
#   ('درمحل', 1),
#   ('تحمرکه', 1),
#   ('شنبه', 1),
#   ('صنعتي', 1),
#   ('صنعت', 1),
#   ('جلسه', 1),
#   ('قزوين', 1),
#   ('میگردد', 1),
#   ('ابتداي', 1),
#   ('مجمع', 1),
#   ('سازي', 1),
#   ('برگزار', 1),
#   ('ماشين', 1),
#   ('خرید', 0),
#   ('خريداران', 0),
#   ('خريداري', 0),
#   ('خسرو', 0),
#   ('خريدبخشي', 0),
#   ('خریخت', 0)],
#  "['#تدیزل']": [('در', 6),
#   ('ماهه', 4),
#   ('ریال', 3),
#   ('است', 3),
#   ('زیان', 3),
#   ('تدیزل', 3),
#   ('که', 3),
#   ('این', 2),
#   ('گزارش', 2),
#   ('عملیاتی', 2),
#   ('ماده', 2),
#   ('کرده', 2),
#   ('جلسه', 2),
#   ('جاده', 2),
#   ('محقق', 2),
#   ('سود', 2),
#   ('همین', 1),
#   ('استدوست', 1),
#   ('میگردد', 1),
#   ('با', 1),
#   ('روز', 1),
#   ('به', 1),
#   ('داده', 1),
#   ('خوب', 1),
#   ('آذرشهر', 1),
#   ('داشت', 1),
#   ('شنبه', 1),
#   ('آذربايجان', 1),
#   ('شرقي', 1),
#   ('داشته', 1)],
#  "['#تشتاد']": [('به', 26),
#   ('در', 15),
#   ('ریال', 9),
#   ('شرکت', 8),
#   ('از', 6),
#   ('است', 6),
#   ('قرارداد', 6),
#   ('مربوط', 5),
#   ('ماهه', 5),
#   ('تولید', 5),
#   ('با', 5),
#   ('هر', 5),
#   ('زیان', 5),
#   ('سال', 4),
#   ('تشتاد', 4),
#   ('تاریخ', 4),
#   ('چرخ', 4),
#   ('قیمت', 4),
#   ('برای', 3),
#   ('دیسک', 3),
#   ('سرمایه', 3),
#   ('افزایش', 3),
#   ('استتشتاد', 3),
#   ('نرخ', 3),
#   ('کرده', 3),
#   ('گردیده', 3),
#   ('مورخ', 3),
#   ('مبلغ', 3),
#   ('ازای', 3),
#   ('شده', 3)],
#  "['#تلیسه', '#تلیسه']": [('میلیارد', 8),
#   ('ریالی', 7),
#   ('سود', 6),
#   ('ماهه', 4),
#   ('کرد', 3),
#   ('در', 3),
#   ('تلیسه', 3),
#   ('عملیاتی', 2),
#   ('ریال', 2),
#   ('غیرعملیاتی', 2),
#   ('خوبی', 2),
#   ('ثبت', 2),
#   ('را', 2),
#   ('بود', 2),
#   ('عملکرد', 2),
#   ('خالص', 2),
#   ('محقق', 1),
#   ('خوب', 1),
#   ('مواجه', 1),
#   ('با', 1),
#   ('است', 1),
#   ('هم', 1),
#   ('گزارش', 1),
#   ('فروش', 1),
#   ('به', 1),
#   ('کمی', 1),
#   ('رسیده', 1),
#   ('سهم', 1),
#   ('بافروش', 1),
#   ('دوم', 1)],
#  "['#تلیسه']": [('میلیارد', 109),
#   ('ریال', 106),
#   ('در', 85),
#   ('فروش', 61),
#   ('به', 46),
#   ('با', 45),
#   ('است', 44),
#   ('ماهه', 40),
#   ('ریالی', 39),
#   ('این', 27),
#   ('مواجه', 24),
#   ('بود', 22),
#   ('از', 20),
#   ('سود', 19),
#   ('نرخ', 19),
#   ('شده', 19),
#   ('مبلغ', 18),
#   ('افزایش', 15),
#   ('داشت', 15),
#   ('شرکت', 15),
#   ('رشد', 14),
#   ('درامد', 14),
#   ('تلیسه', 13),
#   ('کرده', 12),
#   ('داشته', 12),
#   ('عدد', 12),
#   ('مهر', 11),
#   ('نیز', 11),
#   ('نسبت', 11),
# ...
#   ('شده', 1),
#   ('سود', 1),
#   ('این', 1),
#   ('بهای', 1),
#   ('فروش', 1),
#   ('توسط', 1),
#   ('با', 1),
#   ('از', 1),
#   ('نظر', 1),
#   ('میلیارد', 1),
#   ('میلیون', 1),
#   ('سهم', 1),
#   ('شرکت', 1),
#   ('ریال', 1),
#   ('توجه', 1),
#   ('هر', 1),
#   ('بیش', 1),
#   ('دارد', 1),
#   ('کرمان', 1),
#   ('ریالی', 1),
#   ('خریداد', 0),
#   ('خريداري', 0),
#   ('خروجي', 0),
#   ('خروجی', 0),
#   ('خريد', 0),
#   ('خريدار', 0)],
#  "['#کرمان']": [('در', 53),
#   ('به', 52),
#   ('از', 38),
#   ('کرمان', 37),
#   ('شرکت', 31),
#   ('سرمایه', 21),
#   ('با', 19),
#   ('ریال', 15),
#   ('سود', 15),
#   ('است', 14),
#   ('سازی', 11),
#   ('گذاری', 11),
#   ('این', 10),
#   ('میلیارد', 9),
#   ('که', 9),
#   ('فروش', 9),
#   ('می', 8),
#   ('ماهه', 7),
#   ('توسعه', 7),
#   ('سال', 7),
#   ('نماد', 7),
#   ('عام', 7),
#   ('های', 7),
#   ('روز', 6),
#   ('استان', 6),
#   ('مبلغ', 6),
#   ('عمران', 6),
#   ('افزایش', 6),
#   ('رینگ', 6),
#   ('مدیره', 6)],
#  "['#کرونا', '#گکوثر']": [('به', 3),
#   ('کرونا', 2),
#   ('حفظ', 2),
#   ('در', 2),
#   ('خواهد', 2),
#   ('ویروس', 2),
#   ('بین', 1),
#   ('شرکت', 1),
#   ('شهروندی', 1),
#   ('مقرر', 1),
#   ('است', 1),
#   ('ثانوی', 1),
#   ('کوثر', 1),
#   ('منتشر', 1),
#   ('از', 1),
#   ('منظور', 1),
#   ('زنجیره', 1),
#   ('توجه', 1),
#   ('کلیه', 1),
#   ('موعد', 1),
#   ('بهادار', 1),
#   ('سازمان', 1),
#   ('بود', 1),
#   ('تعطیل', 1),
#   ('میهمانان', 1),
#   ('شد', 1),
#   ('گکوثر', 1),
#   ('بورس', 1),
#   ('کمک', 1),
#   ('های', 1)],
#  "['#کرونا']": [('را', 1),
#   ('نکنید', 1),
#   ('فراموش', 1),
#   ('کرونا', 1),
#   ('خريداران', 0),
#   ('خريداري', 0),
#   ('خريدبخشي', 0),
#   ('خریخت', 0),
#   ('خریختخریخت', 0),
#   ('خرید', 0),
#   ('خریدpo', 0),
#   ('خریدا', 0),
#   ('خریداد', 0),
#   ('خردادعدد', 0),
#   ('خریداران', 0),
#   ('خریدارو', 0),
#   ('خریداري', 0),
#   ('خریداری', 0),
#   ('خریداقا', 0),
#   ('خریدثاخت', 0),
#   ('خریدخدمات', 0),
#   ('خریدسود', 0),
#   ('خریدار', 0),
#   ('خريدار', 0),
#   ('خردادفاذر', 0),
#   ('خرمدره', 0),
#   ('خردادماه', 0),
#   ('خردادومعادن', 0),
#   ('خردافزایش', 0),
#   ('خردمندان', 0)],
#  "['#کرونا،']": [('از', 2),
#   ('کرد', 2),
#   ('کشور', 2),
#   ('این', 2),
#   ('چین', 2),
#   ('ویروس', 1),
#   ('فعال', 1),
#   ('خواهد', 1),
#   ('صندوق', 1),
#   ('بهبود', 1),
#   ('بانک', 1),
#   ('عملیات', 1),
#   ('های', 1),
#   ('repo', 1),
#   ('توسعه', 1),
#   ('بازار', 1),
#   ('طریق', 1),
#   ('ظهور', 1),
#   ('اعلام', 1),
#   ('شرایط', 1),
#   ('بعد', 1),
#   ('نقدینگی', 1),
#   ('به', 1),
#   ('شد', 1),
#   ('اقتصادی', 1),
#   ('reverse', 1),
#   ('که', 1),
#   ('دلار', 1),
#   ('کرونا', 1),
#   ('برای', 1)],
#  "['#کروی']": [('در', 34),
#   ('کروی', 21),
#   ('ریال', 19),
#   ('سود', 16),
#   ('به', 13),
#   ('است', 13),
#   ('از', 13),
#   ('میلیارد', 12),
#   ('سال', 10),
#   ('سهم', 9),
#   ('این', 9),
#   ('بخش', 9),
#   ('تا', 8),
#   ('های', 8),
#   ('ماهه', 7),
#   ('شرکت', 7),
#   ('کرده', 7),
#   ('ارزش', 6),
#   ('ذاتی', 6),
#   ('سازی', 6),
#   ('شده', 6),
#   ('زیر', 6),
#   ('محوران', 6),
#   ('مجموعه', 6),
#   ('داشته', 6),
#   ('انديشه', 5),
#   ('محقق', 5),
#   ('استکروی', 5),
#   ('روز', 5),
#   ('گزارش', 5)],
#  "['#کساوه']": [('ریال', 150),
#   ('فروش', 140),
#   ('در', 110),
#   ('میلیارد', 104),
#   ('به', 57),
#   ('نرخ', 55),
#   ('با', 51),
#   ('است', 48),
#   ('بود', 46),
#   ('ریالی', 43),
#   ('بوده', 37),
#   ('ماهه', 33),
#   ('سود', 31),
#   ('زده', 30),
#   ('مواجه', 28),
#   ('شده', 23),
#   ('مهر', 17),
#   ('داشته', 16),
#   ('شرکت', 14),
#   ('خوبی', 14),
#   ('عدد', 14),
#   ('سهم', 14),
#   ('فروردین', 13),
#   ('از', 13),
#   ('کرده', 12),
#   ('را', 12),
#   ('خوب', 12),
#   ('اذر', 12),
#   ('استکساوه', 12),
#   ('مدت', 12)],
#  "['#کساپا', '#خساپا']": [('توسط', 2),
#   ('فروش', 2),
#   ('به', 2),
#   ('مجموعه', 1),
#   ('خودروسازی', 1),
#   ('میرسد', 1),
#   ('های', 1),
#   ('آغا', 1),
#   ('کساپا', 1),
#   ('بلوک', 1),
#   ('نظر', 1),
#   ('شده', 1),
#   ('سهام', 1),
#   ('زیر', 1),
#   ('فرایند', 1),
#   ('قیمت', 1),
#   ('خساپا', 1),
#   ('شرکت', 1),
#   ('ها', 1),
#   ('ریال', 1),
#   ('است', 1),
#   ('خریدار', 0),
#   ('خريداري', 0),
#   ('خریداران', 0),
#   ('خريدبخشي', 0),
#   ('خریدpo', 0),
#   ('خریخت', 0),
#   ('خريداران', 0),
#   ('خریختخریخت', 0),
#   ('خریدا', 0)],
#  "['#کساپا']": [('در', 91),
#   ('میلیارد', 83),
#   ('ریال', 73),
#   ('فروش', 54),
#   ('به', 46),
#   ('ریالی', 37),
#   ('است', 33),
#   ('ماهه', 28),
#   ('نرخ', 24),
#   ('رسیده', 24),
#   ('با', 21),
#   ('زیان', 19),
#   ('بوده', 17),
#   ('رشد', 17),
#   ('داشته', 17),
#   ('درامد', 15),
#   ('داشت', 14),
#   ('رسید', 13),
#   ('هزار', 13),
#   ('از', 13),
#   ('استکساپا', 12),
#   ('این', 11),
#   ('عدد', 11),
#   ('که', 11),
#   ('سود', 10),
#   ('قبل', 10),
#   ('را', 10),
#   ('مشابه', 9),
#   ('شده', 9),
#   ('مدت', 9)],
#  "['#کسرا', '#ولغدر']": [('ولغدر', 1),
#   ('های', 1),
#   ('بازار', 1),
#   ('کسرا', 1),
#   ('فردا', 1),
#   ('توقف', 1),
#   ('ﻻزم', 0),
#   ('خریدار', 0),
#   ('خریختخریخت', 0),
#   ('خرید', 0),
#   ('خریدpo', 0),
#   ('خریدا', 0),
#   ('خریداد', 0),
#   ('خریدارو', 0),
#   ('خریداران', 0),
#   ('خريدبخشي', 0),
#   ('خریداري', 0),
#   ('خریداری', 0),
#   ('خریداقا', 0),
#   ('خریدثاخت', 0),
#   ('خریدخدمات', 0),
#   ('خریدسود', 0),
#   ('خریدش', 0),
#   ('خریخت', 0),
#   ('خريدار', 0),
#   ('خريداري', 0),
#   ('خريداران', 0),
#   ('خردادومعادن', 0),
#   ('خردافزایش', 0),
#   ('خردمندان', 0)],
#  "['#کسرا']": [('ریال', 165),
#   ('فروش', 144),
#   ('در', 125),
#   ('میلیارد', 124),
#   ('است', 91),
#   ('نرخ', 63),
#   ('با', 49),
#   ('ماهه', 48),
#   ('بود', 43),
#   ('ریالی', 41),
#   ('سود', 39),
#   ('به', 38),
#   ('زده', 37),
#   ('بوده', 30),
#   ('ماه', 27),
#   ('مواجه', 25),
#   ('را', 24),
#   ('سهم', 22),
#   ('کسرا', 21),
#   ('کرده', 20),
#   ('که', 20),
#   ('شده', 19),
#   ('شرکت', 19),
#   ('های', 18),
#   ('قبل', 16),
#   ('مهر', 16),
#   ('نیز', 16),
#   ('داشت', 15),
#   ('از', 15),
#   ('رشد', 14)],
#  "['#کسرام']": [('فروش', 92),
#   ('ریال', 83),
#   ('در', 65),
#   ('میلیارد', 64),
#   ('است', 53),
#   ('نرخ', 31),
#   ('با', 26),
#   ('بوده', 24),
#   ('ریالی', 23),
#   ('ماهه', 23),
#   ('به', 22),
#   ('زیان', 20),
#   ('شده', 18),
#   ('قبل', 16),
#   ('زده', 16),
#   ('ماه', 15),
#   ('داشته', 15),
#   ('نیز', 14),
#   ('شرکت', 14),
#   ('مواجه', 14),
#   ('بود', 14),
#   ('کسرام', 13),
#   ('این', 12),
#   ('مشابه', 10),
#   ('مدت', 10),
#   ('عدد', 10),
#   ('اسفند', 10),
#   ('نسبت', 9),
#   ('بهبود', 9),
#   ('سازی', 7)],
#  "['#کسعدی']": [('ریال', 86),
#   ('میلیارد', 80),
#   ('در', 74),
#   ('با', 37),
#   ('است', 28),
#   ('ماهه', 26),
#   ('درامد', 26),
#   ('سود', 25),
#   ('فروش', 22),
#   ('به', 21),
#   ('بوده', 20),
#   ('کرده', 15),
#   ('شده', 15),
#   ('ریالی', 14),
#   ('این', 12),
#   ('را', 12),
#   ('کسعدی', 12),
#   ('بود', 12),
#   ('مواجه', 12),
#   ('کسب', 11),
#   ('کمی', 11),
#   ('عدد', 10),
#   ('داشته', 10),
#   ('سهم', 9),
#   ('داشت', 8),
#   ('افت', 8),
#   ('هم', 8),
#   ('زد', 7),
#   ('بهتر', 7),
#   ('عملیاتی', 7)],
#  "['#کشرق']": [('فروش', 119),
#   ('ریال', 113),
#   ('در', 109),
#   ('است', 85),
#   ('میلیارد', 84),
#   ('به', 64),
#   ('شده', 48),
#   ('نرخ', 44),
#   ('با', 40),
#   ('داشته', 33),
#   ('بوده', 32),
#   ('ریالی', 32),
#   ('از', 30),
#   ('مواجه', 27),
#   ('سود', 26),
#   ('که', 23),
#   ('تن', 23),
#   ('بود', 23),
#   ('این', 22),
#   ('مقدار', 21),
#   ('سهم', 19),
#   ('ماهه', 18),
#   ('شو', 18),
#   ('شرکت', 18),
#   ('زغالسنگ', 17),
#   ('کک', 17),
#   ('خوب', 16),
#   ('ماه', 16),
#   ('کشرق', 15),
#   ('سال', 14)],
#  "['#کصدف']": [('با', 9),
#   ('به', 6),
#   ('این', 5),
#   ('می', 5),
#   ('شرکت', 4),
#   ('در', 4),
#   ('باشد', 4),
#   ('قیمت', 3),
#   ('از', 3),
#   ('تا', 2),
#   ('یا', 2),
#   ('است', 2),
#   ('بر', 2),
#   ('کصدف', 2),
#   ('سهم', 2),
#   ('صورت', 2),
#   ('هر', 2),
#   ('زیان', 2),
#   ('مالی', 2),
#   ('افزایش', 2),
#   ('سهامداران', 2),
#   ('استحضار', 2),
#   ('نظر', 2),
#   ('که', 2),
#   ('را', 2),
#   ('عضو', 1),
#   ('فرابورسی', 1),
#   ('مدیر', 1),
#   ('احمدرضا', 1),
#   ('رویدادهای', 1)],
#  "['#کطبس', '#کپرور', '#کشرق']": [('قیمت', 6),
#   ('فولاد', 6),
#   ('در', 5),
#   ('شمش', 4),
#   ('سنگ', 3),
#   ('معادن', 3),
#   ('زغال', 3),
#   ('با', 3),
#   ('به', 3),
#   ('پایه', 3),
#   ('تعیین', 3),
#   ('شود', 2),
#   ('بورس', 2),
#   ('این', 2),
#   ('مشکل', 2),
#   ('درصد', 1),
#   ('کشرق', 1),
#   ('بررسی', 1),
#   ('مرتفع', 1),
#   ('کاهش', 1),
#   ('کنسانتره', 1),
#   ('چند', 1),
#   ('لازم', 1),
#   ('کرده', 1),
#   ('کالا', 1),
#   ('های', 1),
#   ('است', 1),
#   ('سایر', 1),
#   ('برمبنای', 1),
#   ('را', 1)],
#  "['#کطبس', '#کپرور']": [('است', 2),
#   ('سازی', 1),
#   ('میلیارد', 1),
#   ('شفاف', 1),
#   ('حل', 1),
#   ('فروش', 1),
#   ('سود', 1),
#   ('زده', 1),
#   ('کرده', 1),
#   ('شناسایی', 1),
#   ('کطبس', 1),
#   ('از', 1),
#   ('کپرور', 1),
#   ('ریال', 1),
#   ('خریدا', 0),
#   ('خريداري', 0),
#   ('خريدبخشي', 0),
#   ('خریخت', 0),
#   ('خریختخریخت', 0),
#   ('خرید', 0),
#   ('خریدpo', 0),
#   ('خرم', 0),
#   ('خرسی', 0),
#   ('خریداد', 0),
#   ('خریدار', 0),
#   ('خردادفاذر', 0),
#   ('خردادعدد', 0),
#   ('خریداران', 0),
#   ('خریدارو', 0),
#   ('خريداران', 0)],
#  "['#کطبس']": [('ریال', 144),
#   ('فروش', 122),
#   ('در', 106),
#   ('میلیارد', 106),
#   ('است', 88),
#   ('نرخ', 75),
#   ('با', 43),
#   ('ریالی', 36),
#   ('به', 32),
#   ('داشته', 30),
#   ('ماهه', 28),
#   ('سود', 28),
#   ('شده', 26),
#   ('بوده', 26),
#   ('این', 22),
#   ('بود', 20),
#   ('سهم', 18),
#   ('رشد', 18),
#   ('مواجه', 18),
#   ('عدد', 16),
#   ('عملیاتی', 15),
#   ('رسیده', 14),
#   ('کطبس', 13),
#   ('استکطبس', 13),
#   ('از', 13),
#   ('بهتر', 12),
#   ('سال', 12),
#   ('مهر', 12),
#   ('شرکت', 12),
#   ('هم', 11)],
#  "['#کفرآور']": [('زیان', 12),
#   ('در', 10),
#   ('ریال', 6),
#   ('از', 5),
#   ('کرده', 4),
#   ('ماهه', 4),
#   ('است', 4),
#   ('به', 4),
#   ('فروش', 3),
#   ('کفرآور', 3),
#   ('سود', 3),
#   ('سهم', 3),
#   ('را', 3),
#   ('شده', 3),
#   ('که', 3),
#   ('میلیارد', 2),
#   ('مورد', 2),
#   ('داشت', 2),
#   ('چهارم', 2),
#   ('اشخاص', 2),
#   ('سال', 2),
#   ('ارائه', 2),
#   ('محقق', 2),
#   ('پیشنهاد', 2),
#   ('قبل', 2),
#   ('حقیقی', 2),
#   ('ایی', 2),
#   ('حقوقی', 2),
#   ('شرکت', 2),
#   ('عملیاتی', 2)],
#  "['#کفرا']": [('ریال', 138),
#   ('در', 123),
#   ('میلیارد', 114),
#   ('فروش', 75),
#   ('است', 55),
#   ('به', 49),
#   ('با', 40),
#   ('ماهه', 40),
#   ('بود', 39),
#   ('سهم', 39),
#   ('خوب', 28),
#   ('عدد', 28),
#   ('ریالی', 24),
#   ('این', 22),
#   ('سود', 22),
#   ('نرخ', 22),
#   ('که', 20),
#   ('شده', 18),
#   ('رسیده', 18),
#   ('رشد', 17),
#   ('کرده', 17),
#   ('بوده', 16),
#   ('کفرا', 16),
#   ('محقق', 15),
#   ('را', 14),
#   ('از', 14),
#   ('جمع', 14),
#   ('سال', 13),
#   ('فروردین', 13),
#   ('خوبی', 13)],
#  "['#کفراور']": [('در', 3),
#   ('شرکت', 2),
#   ('سود', 2),
#   ('ریال', 2),
#   ('جاده', 2),
#   ('رسیده', 2),
#   ('کلات', 1),
#   ('بالاخره', 1),
#   ('استکفراور', 1),
#   ('ساعت', 1),
#   ('میگردد', 1),
#   ('یکشنبه', 1),
#   ('جلسه', 1),
#   ('فرآورده', 1),
#   ('درمحل', 1),
#   ('زیان', 1),
#   ('صنعتي', 1),
#   ('شرق', 1),
#   ('اختصاصي', 1),
#   ('هاي', 1),
#   ('به', 1),
#   ('روز', 1),
#   ('بعد', 1),
#   ('که', 1),
#   ('ماهه', 1),
#   ('حالی', 1),
#   ('کيلومتر', 1),
#   ('سيمان', 1),
#   ('مورخ', 1),
#   ('مجمع', 1)],
#  "['#کفپارس']": [('در', 112),
#   ('ریال', 88),
#   ('میلیارد', 82),
#   ('فروش', 69),
#   ('به', 45),
#   ('است', 44),
#   ('با', 27),
#   ('از', 26),
#   ('بوده', 26),
#   ('داشته', 22),
#   ('که', 22),
#   ('شرکت', 21),
#   ('این', 21),
#   ('های', 21),
#   ('شده', 19),
#   ('سهم', 18),
#   ('نرخ', 17),
#   ('رشد', 16),
#   ('ماهه', 16),
#   ('ماه', 14),
#   ('کفپارس', 14),
#   ('عدد', 14),
#   ('کرده', 14),
#   ('ریالی', 14),
#   ('رسیده', 13),
#   ('بود', 13),
#   ('مالی', 13),
#   ('را', 12),
#   ('مشابه', 11),
#   ('بازار', 11)],
#  "['#کقزوی']": [('در', 13),
#   ('از', 6),
#   ('فروش', 5),
#   ('به', 5),
#   ('زیان', 5),
#   ('استکقزوی', 5),
#   ('افزایش', 5),
#   ('سال', 5),
#   ('ریال', 4),
#   ('نرخ', 4),
#   ('شرکت', 3),
#   ('بود', 3),
#   ('محصولات', 3),
#   ('می', 3),
#   ('ماهه', 3),
#   ('نسبت', 3),
#   ('مزایده', 3),
#   ('این', 3),
#   ('کقزوی', 3),
#   ('است', 3),
#   ('باشد', 2),
#   ('الی', 2),
#   ('مورد', 2),
#   ('محقق', 2),
#   ('باب', 2),
#   ('شده', 2),
#   ('سهم', 2),
#   ('رسیده', 2),
#   ('دو', 2),
#   ('کرده', 2)],
#  "['#کلر']": [('در', 22),
#   ('کلر', 12),
#   ('ریال', 12),
#   ('به', 10),
#   ('با', 9),
#   ('فروش', 9),
#   ('میلیارد', 9),
#   ('پارس', 8),
#   ('از', 7),
#   ('است', 6),
#   ('شرکت', 5),
#   ('که', 5),
#   ('سازی', 5),
#   ('شود', 4),
#   ('سود', 4),
#   ('می', 4),
#   ('سرمایه', 4),
#   ('داشته', 4),
#   ('محصول', 4),
#   ('حسابرس', 4),
#   ('بخش', 4),
#   ('بازار', 4),
#   ('توليد', 4),
#   ('برای', 3),
#   ('عرضه', 3),
#   ('تیپیکو', 3),
#   ('روز', 3),
#   ('مواجه', 3),
#   ('بهمن', 3),
#   ('افزایش', 3)],
#  "['#کلوند']": [('میلیارد', 133),
#   ('ریال', 116),
#   ('در', 109),
#   ('فروش', 90),
#   ('است', 60),
#   ('به', 49),
#   ('ماهه', 49),
#   ('با', 45),
#   ('ریالی', 33),
#   ('بوده', 30),
#   ('سود', 26),
#   ('مواجه', 25),
#   ('داشته', 24),
#   ('خوبی', 22),
#   ('این', 18),
#   ('خوب', 18),
#   ('هم', 17),
#   ('از', 17),
#   ('را', 15),
#   ('شده', 15),
#   ('جمع', 15),
#   ('سهم', 15),
#   ('مالی', 15),
#   ('شرکت', 15),
#   ('شد', 14),
#   ('کلوند', 14),
#   ('بود', 13),
#   ('گزارش', 13),
#   ('عدد', 13),
#   ('استکلوند', 13)],
#  "['#کماسه']": [('در', 106),
#   ('ریال', 90),
#   ('فروش', 78),
#   ('است', 67),
#   ('به', 61),
#   ('میلیارد', 54),
#   ('با', 51),
#   ('شرکت', 39),
#   ('نرخ', 38),
#   ('از', 36),
#   ('این', 31),
#   ('ماهه', 27),
#   ('بود', 22),
#   ('ریالی', 20),
#   ('شده', 19),
#   ('را', 18),
#   ('که', 17),
#   ('سود', 16),
#   ('رسیده', 15),
#   ('گزارش', 14),
#   ('نیز', 14),
#   ('بوده', 14),
#   ('کماسه', 13),
#   ('ها', 12),
#   ('داشته', 12),
#   ('مورخ', 11),
#   ('مواجه', 11),
#   ('های', 11),
#   ('مالی', 11),
#   ('سهم', 10)],
#  "['#کمرجان']": [('ریال', 71),
#   ('در', 71),
#   ('فروش', 43),
#   ('میلیارد', 38),
#   ('به', 34),
#   ('است', 32),
#   ('میلیون', 29),
#   ('ماهه', 27),
#   ('از', 23),
#   ('تومان', 23),
#   ('شده', 21),
#   ('این', 19),
#   ('عدد', 16),
#   ('بوده', 14),
#   ('سود', 14),
#   ('مالی', 13),
#   ('با', 13),
#   ('مبلغ', 13),
#   ('شرکت', 11),
#   ('افزایش', 11),
#   ('بهمن', 10),
#   ('استکمرجان', 10),
#   ('نرخ', 10),
#   ('گزارش', 10),
#   ('ماه', 10),
#   ('داشته', 9),
#   ('مورخ', 9),
#   ('مدت', 9),
#   ('سال', 9),
#   ('سرمایه', 9)],
#  "['#کمنگنز']": [('ریال', 170),
#   ('فروش', 153),
#   ('در', 128),
#   ('است', 117),
#   ('میلیارد', 117),
#   ('نرخ', 79),
#   ('به', 65),
#   ('ماهه', 57),
#   ('با', 55),
#   ('ریالی', 39),
#   ('شده', 37),
#   ('سود', 35),
#   ('سهم', 33),
#   ('بود', 32),
#   ('این', 31),
#   ('بوده', 27),
#   ('عدد', 27),
#   ('از', 24),
#   ('را', 23),
#   ('نیز', 23),
#   ('رشد', 22),
#   ('رسیده', 22),
#   ('خوب', 21),
#   ('ماه', 21),
#   ('گزارش', 20),
#   ('که', 20),
#   ('خوبی', 18),
#   ('کرده', 15),
#   ('شرکت', 15),
#   ('عملیاتی', 14)],
#  "['#کنور', '#ومعادن', '#فزرین']": [('در', 8),
#   ('سرب', 5),
#   ('تولید', 3),
#   ('وروی', 3),
#   ('معدنی', 3),
#   ('سرمایه', 3),
#   ('شمش', 2),
#   ('آن', 2),
#   ('شرکت', 2),
#   ('گذاری', 2),
#   ('شود', 2),
#   ('روی', 2),
#   ('سه', 2),
#   ('تن', 2),
#   ('همچنین', 2),
#   ('صنعتی', 2),
#   ('تاسیس', 2),
#   ('است', 2),
#   ('این', 2),
#   ('مجتمع', 1),
#   ('پیشی', 1),
#   ('ایران', 1),
#   ('معادن', 1),
#   ('تقاضای', 1),
#   ('شده', 1),
#   ('میزان', 1),
#   ('صبانور', 1),
#   ('ذخایر', 1),
#   ('حوزه', 1),
#   ('فاز', 1)],
#  "['#کنور']": [('ریال', 177),
#   ('در', 135),
#   ('میلیارد', 125),
#   ('فروش', 125),
#   ('است', 97),
#   ('به', 72),
#   ('گندله', 71),
#   ('نرخ', 71),
#   ('کنسانتره', 62),
#   ('ماهه', 60),
#   ('بوده', 46),
#   ('با', 44),
#   ('سود', 31),
#   ('ریالی', 30),
#   ('شرکت', 27),
#   ('بود', 27),
#   ('کرده', 25),
#   ('رسیده', 24),
#   ('را', 24),
#   ('خوب', 24),
#   ('که', 22),
#   ('داشته', 21),
#   ('خوبی', 21),
#   ('ماه', 20),
#   ('از', 20),
#   ('زده', 18),
#   ('سهم', 18),
#   ('سال', 18),
#   ('هم', 17),
#   ('جمع', 17)],
#  "['#کنگین']": [('ریال', 2),
#   ('را', 1),
#   ('کرد', 1),
#   ('کنگین', 1),
#   ('از', 1),
#   ('تقسیم', 1),
#   ('خریدخدمات', 0),
#   ('خریداد', 0),
#   ('خريدبخشي', 0),
#   ('خریخت', 0),
#   ('خریختخریخت', 0),
#   ('خرید', 0),
#   ('خریدpo', 0),
#   ('خریدا', 0),
#   ('خریدار', 0),
#   ('خریدثاخت', 0),
#   ('خریداران', 0),
#   ('خريداري', 0),
#   ('خریداري', 0),
#   ('خریداری', 0),
#   ('خریداقا', 0),
#   ('خریدسود', 0),
#   ('خریدارو', 0),
#   ('خريدار', 0),
#   ('خريداران', 0),
#   ('خریدفروش', 0),
#   ('خردادماه', 0),
#   ('خردادومعادن', 0),
#   ('خردافزایش', 0),
#   ('خردمندان', 0)],
#  "['#کهرام']": [('در', 17),
#   ('زیان', 15),
#   ('ماهه', 14),
#   ('ریال', 13),
#   ('به', 12),
#   ('کرده', 9),
#   ('سود', 8),
#   ('است', 8),
#   ('شده', 6),
#   ('رسیده', 5),
#   ('سرعت', 4),
#   ('عملیاتی', 4),
#   ('دهی', 4),
#   ('کهرام', 4),
#   ('محقق', 4),
#   ('از', 4),
#   ('ازای', 4),
#   ('این', 4),
#   ('را', 3),
#   ('سهم', 3),
#   ('شناسایی', 3),
#   ('فروش', 3),
#   ('هر', 3),
#   ('بود', 3),
#   ('که', 3),
#   ('کم', 3),
#   ('دارایی', 2),
#   ('مثبت', 2),
#   ('کمی', 2),
#   ('رسید', 2)],
#  "['#کهمدا']": [('فروش', 175),
#   ('ریال', 169),
#   ('میلیارد', 128),
#   ('در', 125),
#   ('است', 72),
#   ('نرخ', 71),
#   ('با', 61),
#   ('ریالی', 46),
#   ('ماهه', 40),
#   ('بوده', 35),
#   ('بود', 33),
#   ('تن', 31),
#   ('سود', 24),
#   ('داشته', 23),
#   ('به', 23),
#   ('خوب', 23),
#   ('ماه', 22),
#   ('عدد', 22),
#   ('سال', 22),
#   ('گزارش', 21),
#   ('کرده', 20),
#   ('این', 19),
#   ('خوبی', 19),
#   ('سهم', 18),
#   ('زده', 18),
#   ('محقق', 18),
#   ('قبل', 16),
#   ('فروخته', 16),
#   ('استکهمدا', 15),
#   ('عملیاتی', 15)],
#  ...}

# %%
# Print the top 15 words said by each companies
for companies, top_words in top_dict.items():
    print(companies)
    print(','.join([word for word, count in top_words[0:14]]))
    print('---')
# Out:
# ['#NAV', '#تاصیکو']
# سهم,تاصیکو,در,به,درصد,فولاد,از,شود,لازم,پرتفوی,دومین,nav,pnav,حاضر
# ---
# ['#NAV', '#وسپه']
# در,سهم,ماه,nav,رشد,ای,درصد,آذر,است,درصدی,روز,فوق,پارسیس,ان
# ---
# ['#NAV', '#پارسان']
# سهم,در,رسانی,استکانال,نسبت,حاضر,محدوده,پارسیس,پارسان,به,pnav,روز,تحلیلی,هر
# ---
# ['#آ_س_پ']
# در,به,ریال,شرکت,مبلغ,از,آسپ,سرمایه,با,پروژه,قرارداد,افزایش,میلیون,ماهه
# ---
# ['#آبین']
# به,از,در,ریال,مزایده,آبین,قم,شرکت,آبشيرين,صنعت,محل,با,فروش,های
# ---
# ['#آرمان']
# به,آرمان,در,منظور,ریال,از,با,ریالی,سرمایه,هیئت,تعلیق,مالي,توجه,تاریخ
# ---
# ['#آريان']
# آريان,کرد,ریال,مجمع,در,پارس,با,سرمايه,نماد,تقسیم,گذاري,شرکت,خریداد,خریختخریخت
# ---
# ['#آریا']
# در,به,ریال,میلیارد,عرضه,با,آریا,فروش,شرکت,ساسول,این,است,اولیه,های
# ---
# ['#آریان']
# در,به,سود,آریان,سال,پارس,قبل,ریالی,شرکت,است,خيابان,ماهه,شده,عادی
# ---
# ['#آسیا']
# در,است,میلیارد,به,آسیا,از,با,بیمه,شرکت,ریالی,سود,ریال,را,که
# ---
# ['#آسیاتک']
# از,به,سرمایه,انباشته,هیئت,ریال,سود,منظور,شده,مبلغ,در,محل,نقدينگي,نقدی
# ---
# ['#آپ']
# میلیارد,در,ریال,به,است,با,ماهه,سود,این,بوده,درامد,ریالی,آپ,سهم
# ---
# ['#آکنتور']
# بهمن,روز,خرید,شنبه,از,قیمت,سفارش,فروش,حداکثر,است,آکنتور,میگیرد,تا,سهم
# ---
# ['#آینده']
# به,در,زیان,آینده,سرمایه,ریال,صنعتي,افزایش,سازان,آينده,بهشت,پارس,با,تعلیق
# ---
# ['#اتفاق', '#کگهر']
# به,در,العاده,بطور,فوق,چهار,مجمع,براساس,کار,جالب,سامانه,خلاصه,خيابان,منتشره
# ---
# ['#اتکام']
# در,به,ریال,از,مبلغ,شرکت,سرمایه,مجمع,سود,افزایش,اتکام,مورخ,محل,عمومی
# ---
# ['#اتکای']
# در,به,ریال,از,سود,افزایش,سرمایه,مبلغ,است,با,شرکت,اتکای,ماهه,میلیون
# ---
# ['#اخابر']
# در,ریال,میلیارد,به,فروش,است,ماهه,با,بوده,داشته,درامد,کمی,افت,شرکت
# ---
# ['#اختصاصی', '#خرد']
# خرد,معاملات,ارزش,میانگین,ابتدای,از,هفتگی,در,سال,اختصاصی,سوم,به,کار,تومان
# ---
# ['#اختصاصی', '#عربستان', '#نفت']
# میلیارد,ریال,سال,است,بینی,در,پیش,بودجه,عربستان,درآمد,شده,دلار,تولید,نفت
# ---
# ['#ارفع', '#فملی', '#فخوز']
# تن,عرضه,هزار,رشد,میلیارد,تقاضا,تومان,قیمت,نسبت,تا,نرخ,درصدی,رقابت,معامله
# ---
# ['#ارفع']
# ریال,فروش,میلیارد,در,است,با,نرخ,ریالی,به,ماهه,تن,بوده,هزار,کرده
# ---
# ['#اسیا']
# به,از,منظور,ریال,هیئت,سرمایه,سود,انباشته,مبلغ,محل,گزارش,مالي,حسابرس,ساختار
# ---
# ['#اعتلا', '#والبر']
# از,ریال,زیر,مجموعه,تقسیم,های,والبر,کرد,اعتلا,خریدا,خريدبخشي,خریخت,خریختخریخت,خرید
# ---
# ['#اعتلا']
# در,سرمایه,ریال,سود,به,از,گذاری,شرکت,میلیارد,است,ها,میلیون,فروش,استاعتلا
# ---
# ['#افرا']
# در,ریال,میلیارد,به,از,شرکت,درامد,است,با,که,خيابان,سود,ماهه,این
# ---
# ['#افق']
# در,میلیارد,به,ریال,است,فروش,با,ریالی,ماهه,درامد,افق,سود,کوروش,سهم
# ---
# ['#افق)،']
# افق,نماد,فروشگاه,امروز,معاملات,شنبه,تاييد,زنجيره,شركت,معاملاتي,نگرديد,سه,هاي,كوروش
# ---
# ['#البرز', '#اتکام']
# بیمه,درصدی,البرز,می,شود,بلوک,در,سهام,توسط,ای,اتکایی,اتکام,عرضه,دولت
# ---
# ['#البرز', '#شراز', '#شاوان']
# ریال,شراز,البرز,شاوان,قیمت,است,بلوکی,بیمه,خریدثاخت,خریداد,خریدسود,خریخت,خریختخریخت,خرید
# ---
# ['#البرز']
# در,از,به,مالی,البرز,شرکت,با,است,بازار,سهم,سازی,های,بیمه,ماهه
# ---
# ['#امید']
# ریال,در,میلیارد,است,به,سرمایه,امید,درامد,فروش,خوبی,از,زده,عدد,سال
# ---
# ['#انرژي']
# سود,ریال,میلیارد,ریالی,در,است,ماهه,با,محقق,کرده,به,درامد,غیرعملیاتی,عملیاتی
# ---
# ['#انرژی']
# در,به,انرژی,بورس,با,اوراق,ریال,بهادار,ایران,از,است,سود,بازار,این
# ---
# ['#اوان']
# در,میلیارد,ریال,به,درامد,است,ماهه,شرکت,از,این,ریالی,با,که,داشته
# ---
# ['#اوره']
# نرخ,در,اوره,فارس,خلیج,دلاری,قرار,با,گرفت,دلار,قرارداد,به,توان,cfr
# ---
# ['#اپرداز']
# میلیارد,ریال,در,به,است,درامد,از,سود,با,بوده,ماهه,این,داشته,عدد
# ---
# ['#اکتیو', '#قرن']
# ریال,نهایی,عرضه,قرن,شد,اکتیو,اولیه,خریدا,خریخت,خریختخریخت,خرید,خریدpo,خریداد,خريداري
# ---
# ['#اکتیو']
# در,اکتیو,ریال,به,می,با,سهم,ماهه,قرن,که,میلیارد,بازار,عرضه,شود
# ---
# ['#بالاس']
# در,به,است,ماهه,مناقصه,ریال,شرکت,سود,از,راه,میلیارد,کرده,آهن,محقق
# ---
# ['#بالبر']
# ریال,فروش,در,میلیارد,است,نرخ,با,ماهه,به,عدد,شده,بود,رشد,بوده
# ---
# ['#بایکا']
# در,به,با,سود,مجمع,این,شرکت,سهم,است,ریال,ماهه,عمومی,خيابان,روز
# ---
# ['#بترانس', '#وبانک']
# وبانک,سود,به,در,بترانس,ریال,شود,بلوک,حدود,واقع,مجموعا,فروخته,هر,از
# ---
# ['#بترانس']
# در,ریال,میلیارد,فروش,به,است,سود,از,با,ماهه,شرکت,ریالی,بترانس,بود
# ---
# ['#بجهرم']
# میلیارد,ریال,در,با,به,درامد,ریالی,ماهه,است,بجهرم,سهم,ها,بوده,داشته
# ---
# ['#بخاور']
# در,به,ریال,فرابورس,شرکت,است,ماهه,پذیرش,محقق,سود,شده,یا,بیمه,بخاور
# ---
# ['#برکت']
# به,در,شرکت,از,ریال,سرمایه,برکت,با,شماره,فروش,میلیارد,دارویی,مجمع,شده
# ---
# ['#بزاگرس']
# در,میلیارد,ریال,به,درامد,ریالی,فروش,با,سود,ماه,است,ماهه,استبزاگرس,داشته
# ---
# ['#بساما', '#سامان']
# سهم,خبر,زده,اعلام,بساما,سامان,است,شفاف,تعداد,بانک,جالب,این,خرید,سهام
# ---
# ['#بساما']
# به,در,از,ریال,سود,شرکت,میلیارد,مبلغ,است,ماهه,بساما,با,های,مجمع
# ---
# ['#بسویچ']
# در,ریال,میلیارد,فروش,است,ماهه,با,به,بود,داشته,این,ریالی,نرخ,خوبی
# ---
# ['#بشهاب', '#بترانس']
# به,اوراق,بهادار,رعایت,ماده,تهران,بورس,عدم,دستورالعمل,فرصت,اعطای,اجرایی,الزامات,های
# ---
# ['#بشهاب']
# ریال,میلیارد,در,فروش,است,سود,ماهه,ریالی,بوده,با,این,لامپ,نرخ,کرده
# ---
# ['#بعايق']
# بعايق,عايق,شد,برگزار,پارس,الکتريکي,مجمع,هاي,تقسیم,شرکت,سود,شده,ریال,خریدpo
# ---
# ['#بعایق']
# های,است,ریال,یا,کرده,در,عایق,سود,پارس,الکتریکی,تقریبا,با,مجموعه,بترانس
# ---
# ['#بفجر', '#مبین']
# به,شرکت,تمدید,توجه,نامه,با,های,روز,مهلت,رعایت,نظر,مذکور,ظرف,اوراق
# ---
# ['#بفجر']
# در,ریال,میلیارد,است,به,شرکت,بوده,ماهه,فروش,که,این,شده,از,با
# ---
# ['#بموتو']
# ریال,فروش,در,میلیارد,است,نرخ,با,به,ریالی,را,شده,سود,بود,خوب
# ---
# ['#بمپنا']
# در,ریال,میلیارد,به,است,درامد,با,ماهه,داشته,را,سود,این,شرکت,سهم
# ---
# ['#بمیلا']
# ریال,در,سود,است,بمیلا,کرده,محقق,به,ماهه,میلیارد,سازی,از,شرکت,سال
# ---
# ['#بنو']
# به,ریال,در,سود,از,میلیارد,سرمایه,است,شرکت,مبلغ,نو,تجارت,مورخ,کرده
# ---
# ['#بنیرو']
# در,فروش,میلیارد,ریال,است,با,ریالی,سود,را,ماهه,نرخ,داشته,بوده,کرده
# ---
# ['#بهپاک']
# میلیارد,ریال,در,فروش,است,به,سود,ماهه,ریالی,با,از,کرده,را,سال
# ---
# ['#بودجه']
# در,بودجه,از,به,تومان,میلیارد,شده,است,این,می,هزار,سال,برای,که
# ---
# ['#بورس']
# در,به,ریال,بورس,میلیارد,درامد,شرکت,با,از,شده,است,هم,های,داشته
# ---
# ['#بوعلی', '#فارس']
# است,که,در,ریال,را,سود,کرده,به,عرضه,اولیه,فارس,از,بوعلی,بسیار
# ---
# ['#بوعلی']
# شرکت,زند,شنبه,ساختمان,در,میگردد,ساعت,طبقه,ميدان,جلسه,فارس,تير,تهران,بلوار
# ---
# ['#بپاس', '#وپاسار']
# پاسارگاد,بانک,بیمه,این,به,سهام,را,با,ها,های,شرکت,برخی,بنگاهداری,بنابراین
# ---
# ['#بپاس']
# ریال,سود,در,به,از,میلیارد,مبلغ,است,سرمایه,محل,میلیون,افزایش,انباشته,بپاس
# ---
# ['#بکاب']
# ریال,در,میلیارد,به,فروش,است,ماهه,از,سود,با,ماه,سال,این,نیز
# ---
# ['#بکام']
# در,ریال,میلیارد,به,با,فروش,درامد,است,ریالی,ماهه,از,بکام,که,این
# ---
# ['#بکهنوج']
# در,به,میلیارد,فروش,ریال,است,از,با,برق,سال,درامد,ریالی,که,ماه
# ---
# ['#بکهنوح']
# زیان,با,هزینه,ریال,ماهه,ازای,نیست,است,رشد,شناسایی,کرده,عملیاتی,نداشته,بکهنوح
# ---
# ['#بگیلان']
# در,ریال,میلیارد,است,کرده,بگیلان,محقق,ماهه,درامد,با,سود,گيلان,به,برق
# ---
# ['#بیلت', '#اسلب']
# بیلت,اسلب,در,ایران,شد,صادراتی,دامنه,معامله,دلار,تا,cis,هفته,گذشته,با
# ---
# ['#تابا']
# به,در,ریال,از,زیان,شرکت,مبلغ,سرمایه,است,منظور,اصفهان,هیئت,رسیده,که
# ---
# ['#تاصيکو']
# است,ماهه,که,صورت,سال,بود,منتظر,صدر,داده,تامین,های,سود,تاصيکو,محقق
# ---
# ['#تاصیکو', '#تاپیکو']
# سود,به,حدود,می,ریال,اضافه,میلیارد,تاپیکو,تقسیم,تاصیکو,شود,با,ﻻزم,خریدpo
# ---
# ['#تاصیکو']
# در,به,تاصیکو,سهم,گذاری,شرکت,سرمایه,ریال,از,است,این,با,عرضه,سود
# ---
# ['#تاصیکو)،']
# درصد,میلیارد,تومان,در,ارزش,پرتفوی,دارد,آن,تمام,شده,است,بهای,بورسی,غیر
# ---
# ['#تاصیکو،', '#رمپنا،', '#تیپیکو', '#تاپیکو']
# برگزاری,مجمع,نقدی,سالیانه,عادی,بر,عمومی,سود,پس,از,تقسیم,مبنی,معاملات,تاپیکو
# ---
# ['#تاپکیش', '#رتاپ']
# قرارداد,مالی,با,که,رتاپ,به,تاپکیش,بسته,منتهی,این,در,است,سال,بود
# ---
# ['#تاپکیش']
# میلیارد,ریال,در,فروش,با,سود,است,درامد,ریالی,ماهه,به,این,بود,قبل
# ---
# ['#تاپیکو', '#تاصیکو']
# سهام,به,در,از,تاپیکو,شرکت,تاصیکو,درصد,است,میلیارد,گروه,تامین,های,هلدینگ
# ---
# ['#تاپیکو', '#شستا']
# در,تاپیکو,به,سهام,این,رشد,را,از,شرکت,نفت,بر,پرتفوی,ستاره,که
# ---
# ['#تاپیکو', '#شفن']
# به,از,مرجان,سهام,آن,عدم,میلیارد,تومان,طی,در,گزارش,آوران,واگذاری,پتروشیمی
# ---
# ['#تاپیکو', '#وپترو']
# در,به,درصد,وپترو,با,سـهام,پتروشیمی,سرمایه,خریداري,این,صنایع,نماد,ناخالص,شرکت
# ---
# ['#تاپیکو', '#پارسان']
# در,از,به,سرمایه,این,گذاری,شرکت,نقد,واگذار,نفت,باشد,صورت,ریال,میلیون
# ---
# ['#تاپیکو']
# در,از,به,تاپیکو,شرکت,سال,سود,ریال,میلیارد,این,های,با,می,را
# ---
# ['#تایرا', '#خبهمن']
# سود,تایرا,کرد,میلیارد,دریافت,محل,از,خبهمن,که,خواهد,خبرخوبی,تقسیم,است,ریال
# ---
# ['#تایرا']
# در,ریال,میلیارد,فروش,ماهه,است,داشته,تایرا,سود,بوده,که,با,از,ریالی
# ---
# ['#تبرک', '#غشهداب']
# فروش,است,محل,میلیارد,در,از,تبرک,شناسایی,کرده,غشهداب,فروردین,ریال,سود,خریختخریخت
# ---
# ['#تبرک']
# در,تبرک,سود,به,از,فروش,با,میلیارد,سرمایه,ها,ریالی,ریال,گذاری,کارخانجات
# ---
# ['#تجار']
# در,به,سهام,اين,با,از,سرمايه,شركت,موضوع,فروش,كه,سهم,شرکت,را
# ---
# ['#تحمرکه']
# شرکت,بلوار,مورخ,نيرومحرکه,عمومی,ساعت,در,این,البرز,شهر,روز,درمحل,تحمرکه,شنبه
# ---
# ['#تدیزل']
# در,ماهه,ریال,است,زیان,تدیزل,که,این,گزارش,عملیاتی,ماده,کرده,جلسه,جاده
# ---
# ['#تشتاد']
# به,در,ریال,شرکت,از,است,قرارداد,مربوط,ماهه,تولید,با,هر,زیان,سال
# ---
# ['#تلیسه', '#تلیسه']
# میلیارد,ریالی,سود,ماهه,کرد,در,تلیسه,عملیاتی,ریال,غیرعملیاتی,خوبی,ثبت,را,بود
# ---
# ['#تلیسه']
# میلیارد,ریال,در,فروش,به,با,است,ماهه,ریالی,این,مواجه,بود,از,سود
# ---
# ['#تماوند']
# در,سهم,می,شرکت,عرضه,دماوند,تماوند,سرمایه,بازار,معاملات,به,نماد,اسفندماه,تامین
# ---
# ['#تمحرکه']
# زیان,در,به,است,ماهه,بهادار,اوراق,ریال,داشته,رعایت,عملیاتی,های,تهران,کانتینر
# ---
# ['#تملت']
# در,شرکت,به,های,از,با,اوراق,تملت,بورس,سهام,سرمایه,تعهد,بهادار,شده
# ---
# ['#تنوین', '#خکرمان']
# واگذار,تنوین,ریال,کرد,خودرو,است,خکرمان,این,محل,از,کرده,شناسایی,شده,سود
# ---
# ['#تنوین', '#نوین']
# نوین,در,بیمه,به,سهامی,شرکت,عام,بازار,دارد,نسیت,واگذاری,عرضه,مالی,بذکر
# ---
# ['#تنوین', '#وغدیر']
# عرضه,توسط,دماوند,در,شود,تنوین,میشود,احتمالی,وغدیر,تسریع,تامین,تا,سرمایه,خریدسود
# ---
# ['#تنوین']
# ریال,میلیارد,در,درامد,به,است,از,بوده,ماهه,این,سود,که,بود,ریالی
# ---
# ['#توریل']
# میلیارد,ریال,در,است,به,سود,ریالی,درامد,داشته,با,ماهه,فروش,این,بوده
# ---
# ['#توسعه']
# به,ناشر,استناد,ایران,توسعه,بررسی,تا,شفافیت,انجام,رساند,نحوه,اجرایی,تعلیق,در
# ---
# ['#تپمپی']
# در,به,ماهه,از,تپمپی,ریال,سود,زیر,سال,مجموعه,های,میلیارد,خالص,سرمايه
# ---
# ['#تپولا']
# به,از,ریال,منظور,مبلغ,مالي,هیئت,در,تجدید,سرمایه,محل,شرکت,مدیره,تاریخ
# ---
# ['#تپکو', '#فاذر']
# در,استاندار,راه,اخبار,فاذر,خوشی,استتسنیم,آذرآب,مرکزی,برای,هپکو,تپکو,خریدpo,خریدا
# ---
# ['#تپکو']
# به,در,شرکت,از,است,ریال,های,سال,با,هپکو,می,سرمایه,این,سازی
# ---
# ['#تکشا']
# ریال,میلیارد,در,فروش,است,به,داشته,ماهه,سود,سهم,زده,این,با,استتکشا
# ---
# ['#تکمبا']
# میلیارد,فروش,در,ریال,است,با,از,ریالی,سود,به,زده,قبل,ماهه,بود
# ---
# ['#تکمیلی']
# به,که,گفت,با,وزیر,فرانسه,ایران,منوشین,در,است,بلومبرگ,برای,دارایی,نجات
# ---
# ['#تکنار']
# به,در,زیان,شرکت,خيابان,جلسه,نداشته,سورينيستان,ریال,پاسداران,ساعت,شناسایی,عملکرد,سهم
# ---
# ['#تکنو']
# در,به,فروش,ریال,شرکت,میلیون,تار,با,استتکنو,زیان,از,است,شده,ماهه
# ---
# ['#تکنوتار']
# به,زیان,که,ماهه,ریال,است,را,تنها,کاری,حال,های,دهی,زمانی,هر
# ---
# ['#تیپیکو', '#دابور']
# از,افزایش,سرمایه,تجدید,های,دستور,تامین,ارزیابی,شرکت,نقدی,محل,وآورده,به,صورت
# ---
# ['#تیپیکو', '#کلر']
# سازی,کلر,شفاف,هم,است,فروش,داده,تیپیکو,گذاری,سود,را,دارد,ریال,سرمایه
# ---
# ['#تیپیکو']
# در,از,ریال,به,سود,است,سرمایه,این,تیپیکو,شرکت,میلیارد,سهم,گذاری,که
# ---
# ['#ثاباد']
# در,ماهه,ریال,این,کرده,محقق,است,میگرددثاباد,پروژه,سازی,توريستي,شهيد,ساعت,حدفاصل
# ---
# ['#ثاخت']
# در,به,میلیارد,ریال,شرکت,فروش,از,ماهه,شده,با,که,استثاخت,ثاخت,داشته
# ---
# ['#ثاصفا']
# در,به,اصفهان,با,یا,سود,است,مورخ,سهم,ریال,ثاصفا,مجمع,که,این
# ---
# ['#ثاصفها']
# در,شرکت,عادی,سالیانه,عمومی,مجمع,دانشگاه,اصفهان,به,برزويه,روز,شيراز,درب,منتشره
# ---
# ['#ثالوند']
# در,ریال,میلیارد,به,فروش,ماهه,شرکت,است,می,استثالوند,که,با,پروژه,جمع
# ---
# ['#ثامان']
# در,به,ریال,شرکت,اوراق,بهادار,مجمع,داشت,رعایت,اصفهان,عمومی,بازرگاني,اتاق,با
# ---
# ['#ثاژن']
# در,به,شرکت,مزایده,تاریخ,ریال,از,آگهی,با,مجمع,ثاژن,است,روز,این
# ---
# ['#ثباغ']
# ریال,در,میلیارد,فروش,ماهه,ثباغ,سود,داشته,استثباغ,ریالی,درامد,است,به,سازی
# ---
# ['#ثتران', '#کیسون']
# داد,پروژه,مسکونی,تهیه,اجرای,با,کیسون,قرار,شهر,واگذاری,به,ثتران,مصالح,میلیارد
# ---
# ['#ثتران']
# به,در,از,مبلغ,ریال,فروش,پروژه,است,ثتران,میلیارد,شرکت,با,شده,ريال
# ---
# ['#ثتوسا']
# در,شرکت,به,با,مجمع,از,خصوص,قانون,مفاد,ماده,تجارت,جلسه,تصمیم,را
# ---
# ['#ثجوان', '#ثنوسا', '#ونوین']
# به,بانک,از,فروش,تاریخ,سهام,شرکت,ريال,می,تسویه,مبلغ,اقتصاد,نوین,ساختمان
# ---
# ['#ثجوان', '#ونوین']
# بانک,فروش,به,سهام,از,در,است,نوین,اقتصاد,می,ونوین,با,ها,تسویه
# ---
# ['#ثجوان']
# به,در,با,از,شرکت,مبلغ,فروش,است,چک,بانک,صورت,می,مورخ,سود
# ---
# ['#ثرود']
# در,ریال,فروش,میلیارد,استثرود,ماهه,است,کرده,جمع,ریالی,به,داشته,شده,که
# ---
# ['#ثزاگرس']
# از,به,در,شرکت,که,را,ابطال,رای,قرارداد,داور,کیانی,آقای,طریق,نمود
# ---
# ['#ثشاهد', '#ثعمرا']
# شرکت,این,اولیه,در,سرمایه,گذاری,است,عرضه,های,پاداد,شاهد,خوبی,ثعمرا,محمد
# ---
# ['#ثشاهد']
# در,ریال,به,از,سود,ماهه,میلیارد,شرکت,ثشاهد,استثشاهد,است,سرمایه,کرده,ها
# ---
# ['#ثشرق']
# در,ریال,میلیارد,ماهه,درامد,استثشرق,است,رسیده,فروش,کرده,داشته,به,جمع,که
# ---
# ['#ثعتما', '#غاذر']
# است,غاذر,گستر,فروخته,کرده,ساختماني,این,اعتماد,گذاري,شناسایی,از,محل,با,ثعتما
# ---
# ['#ثعتما']
# به,در,ریال,سود,است,مبلغ,سهامداران,نقدی,با,از,آورده,فروش,مشابه,محقق
# ---
# ['#ثعمرا', '#ثشاهد']
# به,بهدشت,نسبت,از,شرکت,چمستان,براساس,پس,خواهد,برنده,اراضی,پنج,قرارداد,عقد
# ---
# ['#ثعمرا']
# در,به,شرکت,از,که,مي,سال,سود,فروش,با,سرمايه,است,ریال,های
# ---
# ['#ثغرب']
# در,ریال,میلیارد,به,است,ماهه,از,فروش,ثغرب,داشته,شرکت,درامد,جمع,استثغرب
# ---
# ['#ثفارس']
# در,به,ریال,میلیارد,فروش,از,است,ماهه,شرکت,ثفارس,با,این,شده,سود
# ---
# ['#ثقزوی']
# به,از,در,شرکت,است,سرمايه,توسط,سهام,نيروگاه,بادي,احداث,را,سرمایه,آن
# ---
# ['#ثمسکن', '#ختوقا']
# رفتند,برای,ختوقا,ثمسکن,کنفرانس,خریدار,خريدبخشي,خریخت,خریختخریخت,خرید,خریدpo,خریدا,خریداد,ﻻزم
# ---
# ['#ثمسکن']
# در,ریال,سود,از,سرمایه,به,ثمسکن,گذاری,شرکت,میلیارد,فروش,ها,ماهه,های
# ---
# ['#ثنظام']
# به,ریال,از,شرکت,مبلغ,هیئت,شده,منظور,جهت,سرمایه,تاریخ,صنعتی,رساند,متعلق
# ---
# ['#ثنور']
# در,به,شرکت,مزایده,از,این,جهت,روز,سرمايه,مشهد,ریال,های,مورخ,که
# ---
# ['#ثنوسا', '#وساخت']
# شده,به,وساخت,بانک,سهام,از,های,ثنوسا,توثیق,رفع,کارآفرین,می,وثیقه,تعداد
# ---
# ['#ثنوسا', '#ونوین', '#']
# از,به,فروش,اقتصادنوین,سهم,بانک,میلیارد,این,دریافتی,ریال,سهام,مذکور,تسهیلات,مستقیم
# ---
# ['#ثنوسا', '#ونوین']
# ونوین,ثنوسا,نامه,تکمیلی,ﻻزم,خریداد,خریخت,خریختخریخت,خرید,خریدpo,خریدا,خریدار,خريداري,خریداران
# ---
# ['#ثنوسا']
# به,در,از,شرکت,با,پروژه,فروش,است,سهم,بانک,که,تسهیلات,ریال,زیان
# ---
# ['#ثپردیس']
# در,ریال,میلیارد,به,سود,ماهه,فروش,کرده,استثپردیس,با,شرکت,محقق,است,از
# ---
# ['#جم']
# ریال,فروش,در,میلیارد,است,نرخ,اتیلن,سود,ماهه,با,پلی,سنگین,جم,شده
# ---
# ['#جم_پيلن']
# به,در,سرمایه,جم,پرو,انجام,پلی,کرده,حاضر,از,پیلن,ما,حال,شرکت
# ---
# ['#جم_پیلن']
# در,فروش,ریال,میلیارد,است,با,بوده,نرخ,به,ریالی,سود,ماهه,مواجه,بود
# ---
# ['#جهرم']
# ماهه,جهرم,ریال,سود,متفرقه,است,های,از,کرده,محقق,درامد,در,خريدبخشي,خریخت
# ---
# ['#جوين']
# در,سود,کشت,صنعت,تلفیقی,کرده,جوين,محقق,ریال,اصلی,است,خریدارو,خرید,خریدخدمات
# ---
# ['#جوین']
# به,ریال,از,در,سود,جوين,شرکت,جلسه,ریالی,میلیارد,مجمع,ازای,استان,تقسیم
# ---
# ['#حاریا']
# در,ریال,زیان,به,کرده,است,بمبلغ,ماهه,میلیون,محقق,سال,های,شرکت,هزینه
# ---
# ['#حاسا']
# به,ریال,سود,میلیارد,در,شرکت,از,کرده,ماهه,فولاد,که,ریالی,است,حق
# ---
# ['#حبندر']
# در,به,سود,ریالی,ماهه,ریال,میلیارد,شرکت,با,است,یک,زیان,عملیاتی,گزارش
# ---
# ['#حتاید', '#حسینا', '#حکشتی']
# سال,اساسی,میلیون,از,تن,تا,به,در,بنادر,است,بوده,واردات,کالاهای,ابتدای
# ---
# ['#حتاید']
# ریال,میلیارد,در,به,درامد,سود,است,ماهه,داشته,از,این,شرکت,های,هم
# ---
# ['#حتوکا']
# میلیارد,در,ریال,است,با,به,فروش,ریالی,درامد,بوده,شرکت,مواجه,ماهه,که
# ---
# ['#حخزر']
# میلیارد,در,ریال,با,ریالی,فروش,است,به,ماهه,درامد,حخزر,سود,را,مواجه
# ---
# ['#حرهشا']
# به,در,است,تاریخ,از,با,معاملاتی,تا,می,نماد,شرکت,ماهه,که,تعلیق
# ---
# ['#حریل']
# میلیارد,ریال,در,به,است,سود,با,ماهه,درامد,این,ریالی,حریل,بود,از
# ---
# ['#حسیر']
# در,به,شرکت,ریال,با,میلیارد,از,درامد,است,این,های,افزایش,که,شده
# ---
# ['#حسینا']
# ریال,میلیارد,در,است,داشته,درامد,ماهه,سود,بوده,با,فروش,این,به,عدد
# ---
# ['#حفارس']
# در,میلیارد,ریال,به,درامد,است,ماهه,زیان,این,با,که,از,را,شرکت
# ---
# ['#حفاری', '#ثعمرا']
# به,با,در,ناشر,اطلاعات,شده,می,اهمیت,ابهامات,منتشر,موجود,موظف,روز,کاری
# ---
# ['#حفاری']
# در,میلیارد,ریال,به,درامد,است,ماهه,با,از,این,بوده,عدد,شده,بود
# ---
# ['#حپارسا']
# در,به,میلیارد,ریال,با,است,شرکت,درامد,افزایش,نرخ,ریالی,این,از,شده
# ---
# ['#حپترو']
# میلیارد,ریال,در,به,است,درامد,داشته,با,عدد,ماهه,کرده,فروش,که,بوده
# ---
# ['#حکشتی']
# حکشتی,در,به,از,ریال,سود,بخش,ماهه,سازی,شده,شرکت,میلیارد,سرمایه,است
# ---
# ['#حکمت']
# در,بانک,به,حکمت,ریال,گزارش,که,ادغام,مجمع,ايرانيان,شرکت,از,میلیون,سپه
# ---
# ['#خاذین']
# میلیارد,ریال,در,فروش,است,به,ماهه,با,ریالی,این,بوده,زیان,عدد,از
# ---
# ['#خاهن']
# در,ریال,میلیارد,به,فروش,است,با,بوده,از,سود,ماهه,ریالی,نرخ,این
# ---
# ['#خاور']
# در,زیان,ریال,از,به,میلیارد,شرکت,خاور,است,محقق,ماهه,کرده,ايران,سهم
# ---
# ['#خبازرس']
# در,به,های,با,بازرسی,انجام,ریال,است,سود,شرکت,خبازرس,این,کشور,کلیه
# ---
# ['#خبرهای_موثر']
# به,آزاد,نفتکش,الطارق,می,جبل,خبر,نقل,ایران,خبرهایموثر,در,انگلیسی,نزدیک,از
# ---
# ['#خبهمن', '#خریخت']
# سود,فروش,خریخت,از,شناسایی,میلیون,است,خبهمن,دوباره,کرده,ریال,اعلام,شده,میلیارد
# ---
# ['#خبهمن']
# در,ریال,سود,میلیارد,از,فروش,های,خبهمن,مجموعه,زیر,است,ماهه,کرده,گذاری
# ---
# ['#ختراک']
# ریال,فروش,میلیارد,در,با,است,نرخ,به,ریالی,ماهه,بوده,سود,سهم,خوب
# ---
# ['#ختور']
# در,ریال,میلیارد,فروش,است,به,ماهه,با,سود,ریالی,نرخ,شده,کمی,رسیده
# ---
# ['#ختوقا']
# در,به,از,ریال,ختوقا,افزایش,شرکت,سرمایه,مجمع,جلسه,خودرو,را,مبلغ,عمومی
# ---
# ['#خدیزل']
# در,میلیارد,ریال,فروش,است,ماهه,سود,به,خوبی,داشته,سهم,این,خدیزل,ریالی
# ---
# ['#خراسان', '#شیراز', '#کرماشا', '#شپدیس']
# به,فروش,در,های,ماه,بود,قبلی,نسبت,متوسط,میانگین,نرخ,از,درآمد,تا
# ---
# ['#خراسان']
# در,فروش,ریال,میلیارد,نرخ,است,با,به,ماهه,ریالی,کرده,بود,سود,تن
# ---
# ['#خرنیگ']
# در,میلیارد,است,ریال,ماه,خرنیگ,مدت,فروش,فروردین,مشابه,قبل,داشته,بهمن,سهم
# ---
# ['#خریخت']
# در,ریال,میلیارد,فروش,به,سهم,ماهه,است,از,درامد,این,شرکت,بود,با
# ---
# ['#خرینگ']
# فروش,میلیارد,در,ریال,است,با,بوده,به,ماهه,ریالی,سود,نرخ,داشته,عملیاتی
# ---
# ['#خزامیا']
# در,فروش,میلیارد,ریال,است,با,ماهه,زده,به,سهم,بود,ریالی,بوده,داشته
# ---
# ['#خزر']
# ریال,در,میلیارد,فروش,به,داشته,با,ماهه,است,سود,از,عدد,بوده,این
# ---
# ['#خساپا', '#خزامیا']
# از,در,خساپا,خزامیا,های,مجموعه,نوبت,فروردین,عرضه,زیر,میفروشد,یکجا,ندارد,میگیرد
# ---
# ['#خساپا', '#خودرو']
# خودرو,کردند,محل,شده,در,ارزیابی,دو,از,آن,خساپا,تجدید,زمان,مهر,را
# ---
# ['#خساپا', '#خپارس', '#وساپا', '#ولساپا', '#ورنا', '#خزامیا']
# تومان,ارزش,میلیارد,است,خپارس,وساپا,گذاری,در,فایل,خزامیا,شده,خساپا,ورنا,گزارش
# ---
# ['#خساپا', '#خپارس']
# تولید,محصولات,از,با,رنو,خودرو,مدیرعامل,تعداد,گفت,خودروسازی,کرد,ترخیص,قطعه,به
# ---
# ['#خساپا', '#ورنا']
# می,بلوک,توسط,است,خریداری,شنیده,ورنا,شود,خساپا,شده,خرندکماسه,خرسی,خریداد,خریدار
# ---
# ['#خساپا', '#کساپا']
# کساپا,را,در,کرده,بلوک,قیمت,میکند,فروشد,اسفند,خساپا,نرخ,اردیبهشت,اگهی,با
# ---
# ['#خساپا']
# در,است,فروش,به,میلیارد,ریال,هزار,از,دستگاه,تولید,با,را,ماهه,خساپا
# ---
# ['#خشرق']
# ریال,در,میلیارد,فروش,است,با,سود,نرخ,ماهه,بود,بوده,زده,به,شرکت
# ---
# ['#خصدرا']
# در,به,از,شرکت,است,سود,ریال,ارزیابی,با,می,این,ها,دارایی,که
# ---
# ['#خعمرا']
# در,به,با,شده,از,نائين,شرکت,است,سهم,نماد,ریال,خعمرا,معاملاتی,می
# ---
# ['#خفناور']
# در,میلیارد,فروش,ریال,با,به,ریالی,است,درامد,ماهه,از,سود,شده,بود
# ---
# ['#خفنر']
# در,میلیارد,فروش,ریال,ماهه,ریالی,با,سود,به,است,داشته,ماه,بود,عدد
# ---
# ['#خفولا']
# از,ریال,در,مبلغ,به,میلیون,افزایش,محل,شرکت,مورخ,آورده,سرمایه,مجمع,مطالبات
# ---
# ['#خلنت']
# میلیارد,ریال,در,فروش,است,ماهه,داشته,با,ریالی,به,سهم,زده,بود,بوده
# ---
# ['#خلیبل']
# افزایش,از,نرخ,مطابق,یافته,تغییر,به,سایپا,اول,های,گروه,که,مهر,تعدیل
# ---
# ['#خمحرکه']
# میلیارد,در,ریال,فروش,به,ریالی,ماهه,است,با,بود,زیان,از,سهم,این
# ---
# ['#خمحور']
# میلیارد,در,فروش,ریال,است,ماهه,با,ریالی,بوده,مواجه,زیان,داشته,بود,به
# ---
# ['#خمهر']
# ریال,میلیارد,در,فروش,به,است,ماهه,با,بوده,زیان,این,عدد,از,شده
# ---
# ['#خموتور']
# در,میلیارد,ریال,فروش,است,به,ماهه,با,سود,ریالی,بوده,از,سهم,زده
# ---
# ['#خنصیر']
# میلیارد,ریال,در,فروش,است,با,به,داشته,ریالی,بوده,ماهه,بود,سود,هم
# ---
# ['#خودرو', '#خساپا']
# ها,به,شرکت,در,ثبت,با,سرمایه,اداره,مجوز,سازمان,از,سازی,نماد,خودرو
# ---
# ['#خودرو', '#خودرو']
# در,ریال,فروش,هزار,میلیارد,است,دستگاه,با,مرداد,به,بود,رشد,تیر,نرخ
# ---
# ['#خودرو', '#خگستر']
# های,خودرو,شركت,بلوک,خگستر,را,سمند,ایران,گذاري,نگارنصر,دو,فروخته,به,این
# ---
# ['#خودرو', '#وپارس']
# به,شفاف,يكن,تلقي,نداشت,مشتری,خريد,با,موضوع,بلوک,منتشره,كان,ميگردد,عدم
# ---
# ['#خودرو']
# در,خودرو,به,فروش,از,ریال,است,میلیارد,با,این,های,ایران,ماهه,زیان
# ---
# ['#خودکفا']
# در,به,از,سود,ریال,شرکت,سرمایه,خودکفا,میلیارد,استخودکفا,افزایش,رسیده,محل,که
# ---
# ['#خوساز']
# میلیارد,فروش,در,ریال,با,است,ریالی,ماهه,بوده,مواجه,به,زیان,داشته,از
# ---
# ['#خپارس', '#وساپا', '#ولساپا', '#ورنا']
# است,شده,کارشناسی,ارزش,تومان,معادل,لحاظ,سرمایه,گذاری,خپارس,ورنا,طبق,های,وساپا
# ---
# ['#خپارس']
# در,فروش,میلیارد,ریال,به,است,از,دستگاه,زیان,ماهه,تولید,با,شرکت,بود
# ---
# ['#خپویش']
# میلیارد,در,ریال,فروش,است,به,ماهه,با,بوده,سود,سهم,نرخ,ریالی,این
# ---
# ['#خچرخش']
# ریال,میلیارد,در,است,فروش,به,ماهه,سهم,با,بود,رسیده,شده,را,ریالی
# ---
# ['#خکار']
# میلیارد,در,ریال,فروش,به,ریالی,است,با,سود,رسیده,بود,از,بوده,ماهه
# ---
# ['#خکاوه']
# در,میلیارد,ریال,فروش,است,ماهه,به,داشته,زیان,با,بوده,سهم,ریالی,خکاوه
# ---
# ['#خکرمان', '#کرمان']
# شفاف,بلوک,سازی,کرمان,خکرمان,خریداران,خریخت,خریختخریخت,خرید,خریدpo,خریدا,خریداد,خریدار,خریداري
# ---
# ['#خکرمان']
# به,در,ریال,از,سود,با,تعلیق,کرمان,شرکت,خکرمان,میلیون,معاملاتی,نماد,می
# ---
# ['#خکمک']
# میلیارد,در,ریال,فروش,است,به,با,بوده,ماهه,ریالی,عدد,بود,مواجه,این
# ---
# ['#خگستر']
# در,به,از,شرکت,ریال,سرمایه,خگستر,مبلغ,سود,هاي,خودرو,افزایش,ايران,با
# ---
# ['#دابور']
# میلیارد,ریال,در,فروش,به,است,با,ریالی,ماهه,داشته,بوده,سود,از,را
# ---
# ['#دارو']
# میلیارد,در,ریال,است,فروش,با,ریالی,ماهه,سود,بوده,به,از,مواجه,را
# ---
# ['#داسوه']
# میلیارد,در,ریال,فروش,به,است,ماهه,با,شرکت,سود,ریالی,را,بود,داشته
# ---
# ['#دالبر']
# میلیارد,در,ریال,فروش,است,به,با,ماهه,ریالی,از,زده,بوده,سهم,بود
# ---
# ['#دامین']
# میلیارد,ریال,در,فروش,است,ماهه,به,سود,را,ریالی,بود,با,داشته,رسیده
# ---
# ['#دانا']
# در,دانا,از,به,ریال,سود,ماهه,است,میلیارد,سرمایه,افزایش,خالص,مجمع,ریالی
# ---
# ['#داوه']
# در,میلیارد,فروش,به,ریال,ریالی,داوه,است,رسیده,با,ماهه,سود,سازی,که
# ---
# ['#دبالک']
# در,میلیارد,فروش,ریال,با,به,ریالی,است,سال,بوده,بود,مواجه,سود,را
# ---
# ['#دتماد']
# میلیارد,فروش,ریال,در,است,ماهه,به,ریالی,سود,با,بود,داشته,شرکت,از
# ---
# ['#دتهران']
# به,در,از,شرکت,ریال,مبلغ,افزایش,انباشته,کاهش,که,سرمایه,سود,تهران,منظور
# ---
# ['#دتوزیع']
# در,میلیارد,به,ریال,ماهه,است,درامد,شرکت,دتوزیع,ریالی,بوده,از,با,این
# ---
# ['#دتولید']
# میلیارد,در,ریال,فروش,به,ریالی,ماهه,با,سود,است,از,بود,رسیده,این
# ---
# ['#دتویع']
# اوراق,با,از,صورت,آثار,در,هرگونه,توافقات,اهميت,مزبور,گرديد,فروش,وزارت,معاملاتي
# ---
# ['#دجابر']
# در,ریال,میلیارد,فروش,به,است,ماهه,با,بود,بوده,سود,این,داشت,ریالی
# ---
# ['#دحاوی']
# در,سود,ریال,به,ماهه,از,رسیده,استدحاوی,ریالی,محقق,منظور,کرده,است,که
# ---
# ['#ددام']
# در,ریال,میلیارد,فروش,ماهه,است,سود,به,این,بوده,از,عدد,شده,خوبی
# ---
# ['#ددانا', '#تیپیکو', '#شفا', '#دجابر']
# سود,ماهه,در,بوده,ریال,میلیارد,است,خالص,ریالی,بود,با,گزارش,میلیاردریالی,مواجه
# ---
# ['#ددانا']
# در,به,سود,با,ماهه,ریال,را,گزارش,ددانا,ریالی,از,خالص,خوبی,سرمایه
# ---
# ['#درازک']
# میلیارد,ریال,در,فروش,است,ماهه,بوده,ریالی,با,سود,به,عدد,زده,این
# ---
# ['#درهآور']
# است,فروش,در,میلیارد,ریالی,رسیده,خود,به,مرداد,میانگین,با,که,درهآور,بوده
# ---
# ['#درهاور']
# میلیارد,ریال,فروش,در,با,به,ماهه,است,درهاور,سود,ریالی,شده,داشته,این
# ---
# ['#دروز']
# در,میلیارد,ریال,است,ماهه,به,درامد,این,با,عدد,سود,ریالی,کرده,داشته
# ---
# ['#دریشمک']
# در,فروش,ریال,میلیارد,است,به,استدریشمک,با,را,از,ماه,کرده,ماهه,داشته
# ---
# ['#دزهراوی']
# در,میلیارد,ریال,فروش,است,ماهه,با,به,ریالی,سهم,بود,زیان,این,بوده
# ---
# ['#دسانکو']
# میلیارد,در,ریال,فروش,ریالی,با,است,به,ماهه,سود,بود,قبل,دسانکو,سهم
# ---
# ['#دسبحا', '#والبر']
# در,به,از,هم,سی,ازای,بود,کی,بی,موفق,خود,دیران,بعد,نهایت
# ---
# ['#دسبحا']
# در,به,سهم,ریال,شرکت,دسبحا,سرمایه,میلیارد,شده,است,سود,از,روز,ارزش
# ---
# ['#دسبحان']
# میلیارد,ریال,در,فروش,است,ریالی,سهم,با,ماهه,به,سود,بوده,داشته,زده
# ---
# ['#دسینا', '#وخارزم']
# ریال,مجمع,خبر,برای,تقسیم,دسینا,است,وخارزم,مهمی,در,کرد,خریدا,خرید,خریدpo
# ---
# ['#دسینا']
# میلیارد,ریال,در,فروش,با,است,به,ریالی,ماهه,سود,بود,این,عدد,داشته
# ---
# ['#دشیری']
# سود,ریال,در,میلیارد,ماهه,است,محقق,سهم,خالص,به,عملیاتی,کرده,از,با
# ---
# ['#دشیمی']
# میلیارد,ریال,در,فروش,است,ماهه,به,سود,بوده,با,داشته,ریالی,سهم,را
# ---
# ['#دعبید']
# میلیارد,در,ریال,فروش,با,به,است,ریالی,ماهه,خوبی,مواجه,سود,بود,سهم
# ---
# ['#دفارا', '#دکپسول']
# در,کپسول,شرکت,است,به,این,تولید,ژلاتین,میلیارد,ریال,با,که,سال,ایران
# ---
# ['#دفارا', '#هجرت']
# است,فروش,هجرت,سود,از,محل,کرده,ریال,اولیه,اعلام,عرضه,خوب,شناسایی,در
# ---
# ['#دفارا']
# در,ریال,میلیارد,فروش,به,است,ماهه,سود,با,عدد,بود,خوبی,رسیده,داشته
# ---
# ['#دفرا']
# میلیارد,ریال,در,فروش,است,ماهه,بوده,به,سود,با,داشته,هم,ریالی,زده
# ---
# ['#دقاضی']
# ریال,در,سود,ماهه,به,میلیارد,است,از,عملیاتی,کرده,محقق,بوده,سرمایه,با
# ---
# ['#دلر']
# ریال,میلیارد,در,فروش,است,ماهه,سود,این,به,با,خوبی,بوده,گزارش,زده
# ---
# ['#دلقما', '#بترانس']
# دلقما,متوقف,شدند,بترانس,بکام,خریداران,خریختخریخت,خرید,خریدpo,خریدا,خریداد,خریدار,ﻻزم,خریدارو
# ---
# ['#دلقما']
# ریال,میلیارد,در,فروش,است,به,ماهه,عدد,با,این,زده,که,بوده,سود
# ---
# ['#دماوند']
# در,میلیارد,ریال,با,درامد,به,است,از,شده,ریالی,انرژي,که,این,فروش
# ---
# ['#دهاورد']
# همراه,با,سود,در,ریالی,مجمع,دهاورد,تقسیم,بوده,است,خریدثاخت,خریداد,خریختخریخت,خریدسود
# ---
# ['#دهدشت']
# قرارداد,از,اندازي,تاريخ,شدن,طرف,دهدشت,مؤثر,راه,بگيردشفاف,تابع,باشد,كه,سرمایه
# ---
# ['#دپارس', '#هجرت']
# است,که,سهم,خوبی,کرده,دپارس,زده,سود,شناسایی,از,محل,فروش,شفاف,عدد
# ---
# ['#دپارس']
# ریال,میلیارد,در,با,فروش,است,ماهه,سود,بوده,ریالی,به,بود,این,زده
# ---
# ['#دکوثر', '#دامین']
# از,سود,در,دامین,این,است,به,شناسایی,سال,فروش,مرحله,محل,ریال,که
# ---
# ['#دکوثر']
# میلیارد,فروش,در,ریال,است,ریالی,به,با,بود,ماهه,سود,داشته,مواجه,خوبی
# ---
# ['#دکپسول', '#دفارا']
# به,ریال,دفارا,سود,دکپسول,متعلق,است,کرد,ازای,هم,میکنددکپسول,نظر,سهام,محقق
# ---
# ['#دکپسول']
# میلیارد,در,ریال,فروش,ریالی,ماهه,با,سود,است,محقق,زده,به,بوده,سهم
# ---
# ['#دکیمی']
# میلیارد,ریال,در,فروش,است,ماهه,سود,با,به,ریالی,بود,عدد,داشته,این
# ---
# ['#دی', '#دماوند']
# برای,میلیارد,نیروگاه,رسیده,سهامداران,از,به,فروش,محل,بانک,ریالی,سود,دی,خبرخوب
# ---
# ['#دی', '#سمگا']
# ناشر,به,سازمان,رعایت,می,معاملاتی,نماد,های,با,اجرایی,بازگشایی,ماهه,ثبت,باشد
# ---
# ['#دی', '#وبوعلی']
# را,ها,بانک,بنگاه,نیز,واگذاری,ادامه,دی,آگهی,در,وبوعلی,است,کرده,خریداد
# ---
# ['#دی', '#کرمان']
# دی,بانک,تکذیب,این,از,افزایش,در,سرمایه,منتفی,آگاه,منابع,پخش,اعلام,که
# ---
# ['#دی']
# در,دی,بانک,میلیارد,ریال,به,از,است,سود,زیان,منفی,های,تراز,ماهه
# ---
# ['#دیران', '#غبهنوش']
# از,شرکت,تاریخ,رخ,تا,تقاضاي,دیران,نداده,شفاف,عرضه,بازار,مشابه,گزارشگری,به
# ---
# ['#دیران']
# در,میلیارد,ریال,فروش,با,به,ماهه,است,از,ریالی,مالی,شده,این,شرکت
# ---
# ['#ذلقما']
# برای,داشت,ریال,میلیارد,خواهد,شده,خیریه,خوب,گذاری,فروش,برنده,سود,از,ذلقما
# ---
# ['#ذوب', '#کاوه', '#فملی']
# با,قیمت,پایه,از,عرضه,معامله,هرکیلوگرم,ریال,که,درصد,بالاتر,به,مس,شرکت
# ---
# ['#ذوب']
# در,است,ریال,میلیارد,به,ذوب,فروش,آهن,با,نرخ,از,بوده,ماهه,ریالی
# ---
# ['#رازی']
# مدل,پژو,به,پراید,سایپا,پرشیا,هیوندای,خودروهای,تعداد,کیا,فروش,نزدیک,اشاره,شرح
# ---
# ['#رافزا']
# است,در,محقق,این,سود,ماهه,گزارش,کرده,با,رافزا,بازار,ریال,هم,حضور
# ---
# ['#رانفور']
# میلیارد,ریال,در,درامد,با,است,سود,ریالی,ماهه,به,فروش,بوده,عدد,را
# ---
# ['#رانفوردر']
# در,میلیارد,ریال,سود,بوده,آوری,مجموعه,کرده,سال,انفورماتيک,خالص,رانفوردر,است,خدمات
# ---
# ['#رتاپ', '#بجهرم', '#وتجارت']
# وتجارت,مشتری,بجهرم,نداشت,رتاپ,خریدثاخت,خريداران,خريداري,خريدبخشي,خریخت,خریختخریخت,خرید,خریدpo,خریدا
# ---
# ['#رتاپ', '#تاپکیش']
# تامین,است,تاپکیش,بسته,داد,کننده,این,هم,رتاپ,را,قرار,خریداري,خریدارو,خریدخدمات
# ---
# ['#رتاپ']
# ریال,میلیارد,در,درامد,ماهه,سود,با,داشته,است,فروش,بود,سهم,به,ماه
# ---
# ['#رتکو']
# در,میلیارد,ریال,به,درامد,بود,است,با,ریالی,شده,را,از,ماهه,شرکت
# ---
# ['#رفاه']
# در,سود,ریال,سال,رفاه,قبل,کرده,رشد,به,سهم,عملیاتی,شود,نسبت,استفروشگاه
# ---
# ['#رقیام']
# به,در,سرمایه,از,افزایش,است,جهت,که,تصویب,محل,ثبت,ریال,هیئت,خوبی
# ---
# ['#رمپنا', '#بمپنا']
# شرکت,در,مپنا,به,سهام,هلدینگ,گروه,بمپنا,ایجاد,است,رمپنا,برق,نیز,سوم
# ---
# ['#رمپنا', '#وپاسار']
# مپنا,برای,آگهی,را,فوری,است,درصد,تومان,رمپنا,کرده,فروشد,وپاسار,مهم,اسفند
# ---
# ['#رمپنا']
# در,به,میلیارد,ریال,از,است,با,مپنا,رمپنا,سال,سود,شرکت,های,ماهه
# ---
# ['#رنیک']
# در,میلیارد,ریال,به,درامد,شرکت,است,داشته,ماهه,فروش,ریالی,رنیک,از,سود
# ---
# ['#روی']
# فاز,تولید,روی,تن,هزار,در,بهره,ظرفیت,سال,برداری,تا,مهدی,به,وی
# ---
# ['#رکارت']
# به,شرکت,فن,آوا,این,در,با,ثبت,سرمایه,سازمان,کارت,را,رسید,ماهه
# ---
# ['#رکیش', '#گوهران']
# گوهران,سود,که,انجام,شده,اگهی,به,بود,میلیارد,بلوک,گویا,شود,می,توسط
# ---
# ['#رکیش']
# ریال,میلیارد,در,است,سود,به,داشته,فروش,ماهه,با,این,عدد,درامد,رسیده
# ---
# ['#زاگرس', '#مبین']
# به,شرکت,از,های,سال,مبین,نرخ,در,هاي,است,ابلاغ,نامه,مورخ,پتروشیمی
# ---
# ['#زاگرس', '#پارسان', '#غدیر']
# کرد,تقسیم,ریال,مجمع,خود,در,غدیر,زاگرس,پارسان,تقریبا,را,برای,خبرخوب,خرمشهر
# ---
# ['#زاگرس']
# فروش,ریال,در,میلیارد,است,با,نرخ,ریالی,به,زاگرس,تن,ماهه,بوده,هزار
# ---
# ['#زبینا']
# میلیارد,در,ریال,فروش,ریالی,با,ماهه,است,به,مواجه,سود,شده,داشته,سهم
# ---
# ['#زدشت']
# میلیارد,در,فروش,ریال,با,ریالی,است,ماهه,به,خوبی,مواجه,بود,سود,داشته
# ---
# ['#زشريف']
# شرکت,زیر,کشت,گویا,آباد,بازار,بنیاد,زشريف,راهی,صنعت,شود,مجموعه,از,با
# ---
# ['#زشریف']
# در,میلیارد,ریال,به,است,بوده,با,فروش,ریالی,ماهه,که,تن,درامد,از
# ---
# ['#زشگزا']
# ریال,میلیارد,در,است,فروش,با,به,ریالی,ماهه,بوده,داشته,عدد,سود,نرخ
# ---
# ['#زفکا']
# در,میلیارد,ریال,فروش,است,ماهه,با,به,ریالی,شرکت,بوده,از,سود,این
# ---
# ['#زقیام', '#زگلدشت']
# به,ریال,در,صنعتی,با,همراه,زقیام,مزایده,گردید,مساحت,حدود,شرکت,احداث,یکباب
# ---
# ['#زقیام']
# میلیارد,ریال,در,فروش,است,ماهه,داشته,به,با,ریالی,بوده,سود,بود,داشت
# ---
# ['#زماهان']
# در,فروش,میلیارد,است,ریال,به,با,سود,ماه,شده,جوجه,ریالی,داشته,ماهه
# ---
# ['#زمگسا']
# میلیارد,ریال,فروش,در,است,ماهه,با,بوده,مواجه,ریالی,سود,سال,به,قبل
# ---
# ['#زنجان']
# به,تجهیزات,است,یورو,در,اقلام,می,مبلغ,با,از,توسط,زنجان,حمل,دقیق
# ---
# ['#زنگان']
# در,فروش,میلیارد,ریال,است,به,ماهه,داشته,با,ریالی,نرخ,سود,که,عملیاتی
# ---
# ['#زپارس']
# در,میلیارد,ریال,فروش,با,ریالی,است,ماهه,سود,کرده,این,به,زده,عدد
# ---
# ['#زکارت']
# سود,ریالی,میلیارد,ماهه,درامد,کارت,خالص,محقق,آوا,فن,کرده,که,دارد,است
# ---
# ['#زکشت']
# در,میلیارد,ریال,به,فروش,است,ماهه,با,سود,ریالی,از,افزايش,داشته,مي
# ---
# ['#زکوثر']
# زکوثر,به,کوثر,سازی,عرضه,چهارشنبه,اولیه,بخش,شرکت,کشاورزی,هر,سرمایه,کد,بازار
# ---
# ['#زگلدشت', '#زقیام']
# زمین,خرید,به,مساحت,در,شهرستان,تاسیس,زقیام,دامداری,زگلدشت,را,یک,واحد,جهت
# ---
# ['#زگلدشت']
# ریال,میلیارد,فروش,در,ماهه,است,بود,ریالی,با,به,نرخ,سود,بوده,نیز
# ---
# ['#ساباد']
# به,از,هیئت,مبلغ,شده,ریال,منظور,محل,که,گزارش,با,کيفيت,مدیرة,مطلوب
# ---
# ['#ساذری']
# در,به,شرکت,است,ریال,از,که,سرمایه,سود,ساذری,مالی,استساذری,زیان,سال
# ---
# ['#ساراب']
# میلیارد,ریال,در,فروش,با,است,سود,ماهه,داشته,ریالی,بود,به,سهم,مواجه
# ---
# ['#ساربیل']
# میلیارد,فروش,در,ریال,است,ریالی,با,به,بوده,ماهه,ماه,سود,داشته,بود
# ---
# ['#ساروج']
# در,سود,ریال,به,میلیارد,ریالی,از,ماهه,با,محقق,است,سهم,ساروج,زیان
# ---
# ['#ساروم']
# میلیارد,در,ریال,فروش,است,ماهه,سود,به,با,این,سهم,بوده,زده,شرکت
# ---
# ['#سامان', '#پاکشو']
# خریداری,گلرنگ,کرده,را,است,دیروز,بانک,سامان,مجموعه,شده,بلوک,توسط,که,پاکشو
# ---
# ['#سامان']
# در,سامان,به,ریال,بانک,سود,از,کرده,محقق,است,سال,ماهه,قبل,سهم
# ---
# ['#ساوه', '#زکوثر']
# به,عرضه,زکوثر,اولیه,نظر,چالش,در,دو,فعلی,مواجه,هستند,ساوه,بازار,ملاحظات
# ---
# ['#ساوه', '#سفارس', '#وصندوق', '#وامید']
# به,ریال,برای,ماهه,از,شرکت,سود,ساوه,وصندوق,محقق,سهم,قیمت,بازار,ورود
# ---
# ['#ساوه', '#شگویا', '#زکوثر']
# در,تند,قرار,اولیه,عرضه,سیمان,ساوه,شود,شگویا,نوبت,گفته,ترافیک,دارند,شرکت
# ---
# ['#ساوه']
# ساوه,در,به,سیمان,است,عرضه,که,شرکت,چهارشنبه,میلیون,سهم,ریالی,میلیارد,اولیه
# ---
# ['#ساوه،', '#پیزد', '#آریا']
# عرضه,نیز,لاستیک,ساسول,اولیه,هفته,شود,این,چهارشنبه,ساوه,قطعی,هامونی,است,شاید
# ---
# ['#سایرا']
# به,در,سال,سهم,با,مالي,مالی,است,عملکرد,قبل,هر,گزارش,سود,از
# ---
# ['#ساینا']
# ریال,در,میلیارد,فروش,است,با,به,سود,ریالی,داشته,ماهه,این,عدد,نرخ
# ---
# ['#سباقر']
# در,به,سباقر,این,که,ریال,از,است,زیان,هیئت,منظور,کدال,احداث,مبلغ
# ---
# ['#سبجنو']
# میلیارد,ریال,در,فروش,ماهه,است,سود,بود,به,ریالی,با,زده,سهم,خوب
# ---
# ['#سبزوا']
# در,ریال,میلیارد,به,فروش,ماهه,از,سود,سبزوا,با,سرمایه,استسبزوا,داشته,ها
# ---
# ['#سبهان', '#سخوز', '#سفانو']
# مهم,دلیل,نیز,به,چهارم,سفانو,است,سخوز,سیمان,سبهان,برای,العماره,بخش,اهمیت
# ---
# ['#سبهان', '#سفار']
# کرده,کار,با,است,فروش,جالبی,بازار,سود,سبهان,در,از,شناسایی,سفار,ریال
# ---
# ['#سبهان', '#سفانو']
# سود,کرده,واگذاری,واگذار,سهام,محل,از,وشناسایی,شناسایی,سفانو,است,این,سهم,ریال
# ---
# ['#سبهان']
# میلیارد,در,ریال,فروش,است,ماهه,به,با,ریالی,سود,بوده,عدد,بود,زده
# ---
# ['#ستران']
# ریال,در,فروش,میلیارد,است,با,به,نرخ,ماهه,تن,ریالی,ستران,از,های
# ---
# ['#سجام']
# به,در,از,ریال,زیان,های,شده,با,مبلغ,هزینه,کرده,افزایش,است,استسجام
# ---
# ['#سخاش']
# در,ریال,میلیارد,فروش,است,به,سود,ماهه,با,ریالی,بوده,عدد,این,شرکت
# ---
# ['#سخزر']
# میلیارد,ریال,در,فروش,است,سود,با,ماهه,به,ریالی,بوده,این,شرکت,مواجه
# ---
# ['#سخواف']
# خواف,جاده,شرکت,درمحل,مهاباد,تربت,جلسه,این,روستاي,خراسان,در,به,حيدريه,عمومی
# ---
# ['#سخوز', '#سبهان', '#سفانو']
# شرکت,می,سخوز,از,این,به,العماره,سهام,در,باشد,برداری,را,مجمع,بهره
# ---
# ['#سخوز']
# میلیارد,ریال,در,فروش,است,به,سود,بوده,با,ماهه,کرده,ریالی,خوبی,سهم
# ---
# ['#سدبیر']
# ریال,در,به,سود,سرمایه,استسدبیر,از,شرکت,کرده,فروش,مبلغ,محقق,ماهه,ها
# ---
# ['#سدشت']
# میلیارد,ریال,در,است,فروش,ریالی,سود,بوده,ماهه,با,درامد,عدد,سال,داشته
# ---
# ['#سدور']
# در,میلیارد,ریال,فروش,است,با,ماهه,ماه,بوده,ریالی,سود,بود,قبل,کرده
# ---
# ['#سرود']
# میلیارد,ریال,فروش,در,است,ماهه,سود,ریالی,بوده,با,سهم,مواجه,به,عملیاتی
# ---
# ['#سرچشمه', '#بساما']
# ریال,است,قیمت,که,فروش,بلوک,حدود,شناسایی,بساما,میرساند,این,با,سود,گفت
# ---
# ['#سرچشمه']
# در,به,سرچشمه,از,ریال,سود,شرکت,سرمایه,این,میلیارد,مس,است,سال,مجمع
# ---
# ['#سرچشمه،', '#بپاس', '#میدکو']
# می,از,فرابورسی,سرچشمه,آغاز,چهارم,تعهدی,میدکو,فروش,در,شود,بپاس,اسفندماه,نماد
# ---
# ['#سشرق']
# ریال,میلیارد,در,فروش,است,سود,داشته,این,بوده,به,ماهه,عدد,با,سشرق
# ---
# ['#سشمال']
# میلیارد,ریال,در,فروش,است,به,سود,این,با,عدد,ریالی,ماهه,بوده,داشته
# ---
# ['#سصفها']
# میلیارد,در,ریال,فروش,ماهه,سود,است,به,با,ریالی,بوده,شده,از,قبل
# ---
# ['#سصوفی']
# میلیارد,ریال,در,فروش,به,است,ماهه,ریالی,رسیده,بوده,این,سود,با,عدد
# ---
# ['#سغرب']
# ریال,میلیارد,فروش,در,با,است,بود,ریالی,سود,ماهه,به,نرخ,بوده,رشد
# ---
# ['#سفار']
# ریال,میلیارد,در,فروش,است,سود,این,بوده,بود,به,زده,ماهه,عدد,با
# ---
# ['#سفارس', '#ساوه']
# ساوه,سفارس,سود,از,میلیارد,در,محل,فروش,ریالی,خرید,خريداران,خريداري,خريدبخشي,خریخت
# ---
# ['#سفارس']
# در,به,سفارس,است,ریال,سود,میلیارد,از,گذاری,سرمایه,فروش,سهم,ها,سازی
# ---
# ['#سفارود']
# در,مجمع,شرکت,خيابان,به,زیان,خصوص,مورخ,قانون,شنبه,ماده,ساعت,العاده,بطور
# ---
# ['#سفاسی']
# به,زیان,در,ریال,از,کرده,شرکت,ماهه,با,بود,را,محقق,است,سهم
# ---
# ['#سفانو']
# ریال,میلیارد,در,است,به,فروش,ماهه,سود,سهم,داشته,با,بوده,این,عدد
# ---
# ['#سقاین']
# میلیارد,ریال,در,فروش,است,سود,به,ماهه,بوده,ریالی,زده,با,داشته,عملیاتی
# ---
# ['#سلار']
# است,سلار,بخش,مطبوعاتی,شرکت,تا,زیان,در,که,مقایسه,حدودی,نمی,دومکنفرانس,یا
# ---
# ['#سمازن']
# در,میلیارد,فروش,ریال,است,ریالی,با,سال,بود,داشته,به,مواجه,از,بوده
# ---
# ['#سمایه', '#وساخت']
# وساخت,از,در,سمایه,خرید,سهام,خصوص,استراتوس,ماجرا,جالب,است,سازی,ساختمان,شركت
# ---
# ['#سمایه']
# به,در,زیان,است,بانک,سمایه,ریال,با,این,از,میلیارد,سود,سرمایه,تومان
# ---
# ['#سمتاز']
# سود,در,ریال,است,کرده,ریالی,به,محقق,که,سهم,میلیارد,رسیده,سهمی,ماهه
# ---
# ['#سممتاز']
# کرده,هر,ماهه,در,سیمان,به,ممتاز,سممتاز,یا,محقق,است,کرمان,ازای,ریال
# ---
# ['#سمگا']
# به,در,ریال,از,سود,سمگا,سرمایه,مبلغ,شده,شرکت,میلیون,است,مطالبات,با
# ---
# ['#سنفت']
# مورخ,چهار,در,خيابان,کوچه,ساعت,جلسه,شنبه,تهران,عمومی,جنوبي,میگردد,برگزار,درمحل
# ---
# ['#سنوین']
# ریال,مجمع,سنوین,از,شد,در,تقسیم,خردمندان,خريدبخشي,خریختخریخت,خرید,خریدpo,خریدا,خریداد
# ---
# ['#سنیر']
# میلیارد,ریال,فروش,در,است,با,ریالی,ماهه,سود,به,از,زده,که,بوده
# ---
# ['#سهرمز', '#امید', '#وامید']
# سود,با,سهرمز,وامید,سرمایه,امید,شناسایی,گذاری,کرده,این,واگذاری,تسویه,تهاتر,مطالبات
# ---
# ['#سهرمز', '#وامید']
# ریال,از,تشکیل,سهرمز,که,میدهد,را,سود,وامید,در,کرد,مجمع,تقسیم,خروجی
# ---
# ['#سهرمز']
# در,میلیارد,ریال,فروش,به,است,با,داشته,سود,ریالی,ماهه,صادرات,از,سهم
# ---
# ['#سهگمت', '#سیلام']
# شركت,به,مبلغ,سهگمت,ميليون,رسانده,سهم,غيرعملياتي,سيمان,سرفصل,است,سود,را,ريال
# ---
# ['#سهگمت']
# میلیارد,در,ریال,فروش,است,به,با,سود,از,داشته,ریالی,بود,ماهه,که
# ---
# ['#سپ']
# در,میلیارد,ریال,به,است,درامد,این,داشته,بوده,فروش,ماهه,از,با,ریالی
# ---
# ['#سپاها', '#شیران']
# فردا,توقف,های,بازار,شیران,سپاها,خریدثاخت,خریدسود,خریدفروش,خرید,خریدش,خریدpo,خریدا,خریداد
# ---
# ['#سپاها']
# میلیارد,ریال,در,فروش,ریالی,با,به,است,ماهه,سود,بود,مواجه,رسیده,سهم
# ---
# ['#سپرده']
# میلیون,به,ریال,سال,عملیاتی,هزینه,بود,برآورد,حاشیه,ترتیب,بر,تا,درآمدهای,بالغ
# ---
# ['#سکارون']
# زیان,در,ماهه,ریال,است,کرده,که,عملیاتی,به,خيابان,نسبت,محقق,شده,قبل
# ---
# ['#سکاون']
# زیان,ریال,ماهه,در,بوده,که,دهی,میدهد,یافته,داشته,سرعت,حالی,است,کاهش
# ---
# ['#سکرد', '#سهگمت']
# شده,به,از,این,های,کنفرانس,است,درخواست,را,شرکت,در,علت,مطرح,می
# ---
# ['#سکرد', '#فباهنر']
# شرکت,کنفرانس,نوسان,تهران,بهادار,مطرح,به,شماره,رسانی,علت,اوراق,درخواست,طی,سهام
# ---
# ['#سکرد']
# ریال,میلیارد,در,فروش,است,به,با,زده,عدد,شده,رسیده,سود,این,ریالی
# ---
# ['#سکرما']
# در,میلیارد,ریال,فروش,است,با,ریالی,به,سود,سيمان,از,بود,ماهه,مواجه
# ---
# ['#سیدکو']
# در,ریال,سود,کرده,میلیارد,سرمایه,فروش,گذاری,سیدکو,است,ماهه,ها,محقق,استسیدکو
# ---
# ['#سیستم']
# ریال,میلیارد,در,به,است,درامد,ماهه,سال,فروش,داشته,سیستم,با,سود,شده
# ---
# ['#سیلام']
# میلیارد,در,ریال,فروش,است,ریالی,این,به,شده,با,عدد,زده,داشته,ماهه
# ---
# ['#سیمان']
# به,در,گاز,های,قیمت,سیمان,این,با,از,مازوت,که,کارخانه,افزایش,سیمانی
# ---
# ['#سیمرغ']
# در,میلیارد,ریال,فروش,است,ماهه,ریالی,به,با,سود,سیمرغ,کرده,سهم,داشته
# ---
# ['#شاراک', '#وبانک']
# ریال,سود,در,میلیارد,است,ماهه,عملیاتی,خالص,فروش,بوده,محقق,سهم,تقسیم,برای
# ---
# ['#شاراک']
# ریال,در,میلیارد,فروش,پلی,است,بوده,به,ماهه,پروپیلن,نرخ,ریالی,سود,با
# ---
# ['#شاملا']
# ریال,میلیارد,در,فروش,است,با,به,بوده,سود,ماهه,نرخ,این,سهم,شده
# ---
# ['#شاوان']
# در,به,سود,ریال,میلیارد,ماهه,است,عملیاتی,از,با,هاي,سال,شرکت,فروش
# ---
# ['#شبریز', '#البرز', '#اتکام']
# شبریز,های,البرز,اتکام,بلوک,خریدارو,خرید,خریدpo,خریدا,خریداد,خریدار,خریداران,خریداری,خریداري
# ---
# ['#شبریز', '#پارسان']
# سود,پارسان,برای,به,سال,که,میلیارد,شبریز,تبریز,خبرخوب,میتواند,خوبی,پتروشیمی,اثرات
# ---
# ['#شبریز']
# در,به,سود,ریال,ماهه,از,میلیارد,است,با,این,شبریز,کرده,که,خالص
# ---
# ['#شبصیر']
# ریال,فروش,در,میلیارد,است,نرخ,به,با,بود,ماهه,بوده,ریالی,مواجه,سود
# ---
# ['#شبندر']
# در,ریال,سود,به,ماهه,است,میلیارد,از,با,شبندر,عملیاتی,شرکت,نفت,کرده
# ---
# ['#شبهرن', '#شنفت', '#شرانل', '#شسپا']
# تعلیق,نمادها,بررسی,به,با,معاملاتی,تاریخ,حداکثر,روزها,هستند,موضوعادامه,ادامه,شرانل,این
# ---
# ['#شبهرن']
# ریال,در,فروش,میلیارد,است,نرخ,با,سود,بوده,ماهه,به,از,سهم,شبهرن
# ---
# ['#شتران']
# در,سود,ریال,به,ماهه,میلیارد,است,از,عملیاتی,خالص,شتران,نفت,شرکت,این
# ---
# ['#شتهران']
# به,در,ریال,سود,از,تهران,شرکت,سرمایه,خيابان,منظور,میلیارد,افزایش,مبلغ,هر
# ---
# ['#شتولی']
# به,زیان,در,هر,است,شرکت,هم,ریال,سهم,شده,ازای,سرمايه,پرس,محک
# ---
# ['#شتوکا']
# ریال,فروش,میلیارد,در,بوده,نرخ,با,است,سود,ریالی,ماهه,به,کرده,را
# ---
# ['#شجم']
# فروش,ریال,در,میلیارد,است,نرخ,با,به,بوده,ریالی,از,ماهه,تن,این
# ---
# ['#شخارک']
# ریال,در,فروش,میلیارد,است,با,ماهه,نرخ,تن,شده,متانول,داشته,بوده,ریالی
# ---
# ['#شدوص']
# ریال,در,میلیارد,فروش,است,نرخ,ماهه,با,به,ریالی,سود,عدد,شده,بوده
# ---
# ['#شراز']
# در,ریال,سود,به,میلیارد,ماهه,است,شراز,شرکت,عملیاتی,کرده,محقق,خالص,از
# ---
# ['#شرانل']
# ریال,فروش,میلیارد,در,است,نرخ,با,ماهه,بوده,ریالی,بود,مواجه,شده,سود
# ---
# ['#شرنگی']
# در,به,سود,از,ریال,قبل,شرکت,سال,سرمايه,مالی,رشد,عملیاتی,استشرنگی,شده
# ---
# ['#شزنگ']
# در,شرکت,است,زیان,به,عمومی,مجمع,این,ریال,صنعتي,شماره,شهرک,جنوبي,يک
# ---
# ['#شستا', '#افق', '#پاکشو']
# در,بورس,به,عرضه,های,از,اولیه,هلدینگ,این,شستا,شرکت,پرس,درج,سهام
# ---
# ['#شستا', '#شستا']
# در,بورس,شستا,گذاری,اولیه,تهران,عرضه,سرمایه,شرکت,اوراق,بهادار,اجتماعی,فروردین,تامین
# ---
# ['#شستا', '#وپترو']
# وپترو,تاریخ,اردیبهشت,شستا,فروشد,ریال,در,می,جوابیه,خريداري,خریخت,خریختخریخت,خرید,خریدpo
# ---
# ['#شستا']
# در,شستا,از,به,است,عرضه,میلیارد,شرکت,سال,سود,بازار,ریال,سهم,خواهد
# ---
# ['#شستا،']
# ارزش,شستا,امروز,از,تحلیلی,پول,احتساب,خرد,معاملات,میلیارد,با,به,بازار,رکورد
# ---
# ['#شسم']
# ریال,زیان,در,ماهه,کوچه,از,به,قبل,مالی,شسم,است,سال,بیشتر,شرکت
# ---
# ['#شسپا', '#شاراک']
# که,به,این,بلوک,را,در,سهامداران,شد,بودیم,شاراک,روزهای,گذشته,شاهد,هایی
# ---
# ['#شسپا']
# ریال,در,فروش,میلیارد,است,با,نرخ,بوده,از,به,ماهه,سود,ریالی,بود
# ---
# ['#شسینا']
# ریال,در,میلیارد,است,فروش,به,ماهه,سهم,نرخ,سود,شده,رسیده,بود,بوده
# ---
# ['#شصدف']
# به,در,شصدف,از,است,سهم,ریال,فروش,دوده,صبح,عرضه,سرمایه,نماد,بازار
# ---
# ['#شصفها']
# میلیارد,در,با,ریالی,ماهه,از,به,فروش,است,سود,ریال,درامد,داشته,بود
# ---
# ['#شغدیر']
# فروش,در,ریال,میلیارد,است,نرخ,بوده,با,ماهه,به,از,ریالی,تن,داشته
# ---
# ['#شفا', '#دجابر']
# شرکت,به,شفادارو,ميزان,سود,حيان,جابرابن,سرمايه,گذاري,داروسازي,ريال,خواهد,معادل,ملک
# ---
# ['#شفا']
# به,شرکت,در,سود,شفادارو,گذاري,دارو,سرمايه,از,با,اسوه,داروسازي,ميليون,ميزان
# ---
# ['#شفادارو']
# در,سال,ریال,میلیارد,است,سود,این,شفادارو,خالص,مبلغ,حالی,قبل,خوب,شده
# ---
# ['#شفارا']
# در,به,زیان,ریال,از,شرکت,سود,است,عملیاتی,کرده,سهم,ماهه,میلیارد,افزایش
# ---
# ['#شفارس']
# ریال,در,فروش,میلیارد,است,ریالی,با,نرخ,ماهه,به,بوده,بود,سود,شفارس
# ---
# ['#شفن', '#تاپیکو', '#وصندوق']
# به,سهامدار,عنوان,می,مجمع,تومانی,وصندوق,شفن,موثر,تاپیکو,سود,در,باشد,روی
# ---
# ['#شفن', '#تاپیکو']
# ریال,مرجان,بلوک,شرکت,درصد,میلیارد,پتروشیمی,گردید,با,از,درصدی,به,سهام,رساند
# ---
# ['#شفن', '#شخارک', '#زاگرس']
# در,سود,به,داشته,عملیاتی,متانول,بیشترین,را,است,شخارک,نسبت,تابستان,خالص,شفن
# ---
# ['#شفن']
# فروش,در,ریال,میلیارد,است,نرخ,بوده,ماهه,به,ریالی,با,کرده,هزار,بود
# ---
# ['#شلرد']
# در,با,پتروشیمی,راه,اندازی,لردگان,این,به,اوره,های,از,واحد,آمونیاک,شد
# ---
# ['#شلعاب']
# ریال,میلیارد,در,فروش,با,به,است,داشته,شده,ماهه,قبل,از,این,عدد
# ---
# ['#شلیا']
# در,به,از,را,ماهه,این,ریال,شرکت,مجمع,مورخ,سود,شلیا,سهم,است
# ---
# ['#شمواد']
# فروش,میلیارد,در,ریال,ریالی,با,است,نرخ,بود,به,مواجه,ماهه,را,شده
# ---
# ['#شنفت']
# ریال,فروش,در,میلیارد,است,نرخ,با,به,بود,بوده,ریالی,از,ماهه,سود
# ---
# ['#شوینده', '#وبشهر', '#وصنا']
# ریال,بر,مجمع,هم,وصنا,است,کرد,وبشهر,موثر,از,در,شوینده,اندکی,تقسیم
# ---
# ['#شوینده']
# در,به,سهم,سود,شوینده,است,ریال,ارزش,از,شرکت,میلیارد,با,شده,روز
# ---
# ['#شپارس']
# فروش,میلیارد,ریال,در,با,ریالی,به,نرخ,سود,بود,بوده,مواجه,است,ماهه
# ---
# ['#شپاس', '#شپترو', '#چکاوه', '#شفن', '#وپترو']
# فروش,در,شرکت,شفن,متری,اگهی,زیر,های,شپاس,شپترو,چکاوه,نظیر,یک,ملک
# ---
# ['#شپاس']
# ریال,در,فروش,میلیارد,است,ماهه,نرخ,سود,بوده,به,بود,با,نیز,داشته
# ---
# ['#شپاکسا']
# ریال,میلیارد,فروش,در,است,به,نرخ,سود,ماهه,ریالی,داشته,شده,را,کرده
# ---
# ['#شپترو']
# در,ریال,میلیارد,فروش,است,به,نرخ,سهم,با,از,زیان,ماهه,کرده,این
# ---
# ['#شپدیس', '#پارسان', '#وغدیر']
# سود,شپدیس,پارسان,تقسیم,تومان,حدود,با,تومانی,پارسیس,شدکانال,در,ازای,سهم,به
# ---
# ['#شپدیس']
# ریال,در,فروش,است,میلیارد,با,نرخ,به,تن,بوده,اوره,ریالی,ماهه,شپدیس
# ---
# ['#شپلی']
# در,ریال,فروش,میلیارد,به,است,نرخ,با,داشته,شده,ماهه,شرکت,از,ولی
# ---
# ['#شپمچا']
# به,از,در,ریال,ها,رسیده,هیئت,سرمایه,شرکت,خيابان,منظور,محل,دارایی,مبلغ
# ---
# ['#شپنا', '#شپنا']
# در,بورس,است,شپنا,فروش,ماه,کالا,به,نفت,داشته,پالایش,اصفهان,نسبت,مهر
# ---
# ['#شپنا', '#شیران', '#وصندوق']
# ریال,سود,میلیارد,حدود,با,کرد,شیران,به,شناسایی,توجه,خواهند,ریالی,وصندوق,شپنا
# ---
# ['#شپنا']
# در,ریال,ماهه,به,سود,میلیارد,از,است,شپنا,با,شرکت,کرده,عملیاتی,این
# ---
# ['#شکبیر']
# در,میلیارد,ریال,فروش,است,سود,ماهه,ریالی,بوده,با,مواجه,به,کرده,سهم
# ---
# ['#شکر']
# سود,میلیارد,در,ریالی,به,ریال,محقق,ماهه,رسیده,زده,همین,است,شکر,فروش
# ---
# ['#شکربن']
# فروش,میلیارد,ریال,در,ریالی,نرخ,است,با,به,سود,ماهه,کرده,تن,بود
# ---
# ['#شکف']
# در,به,مالی,ماهه,شرکت,صورت,کاهش,سرمايه,افزايش,زیان,شد,بر,بانک,هزینه
# ---
# ['#شکلر']
# ریال,میلیارد,فروش,در,است,نرخ,سود,بود,به,با,ریالی,از,ماهه,داشته
# ---
# ['#شگامرن']
# است,بخش,سازی,شگامرن,در,کمی,نحوه,کمتر,اولشگامرن,سال,کرده,به,مشابه,گزارش
# ---
# ['#شگامرون']
# به,ریال,در,از,منظور,تجدید,محل,سرمایه,هیئت,مبلغ,تاریخ,کار,که,اصلاح
# ---
# ['#شگل']
# ریال,فروش,میلیارد,در,است,نرخ,با,به,بوده,سود,ریالی,بود,از,مواجه
# ---
# ['#شگويا4']
# در,ادامه,سهام,عرضه,رقابت,مي,غيرمديريتي,عمده,نماد,به,روز,ريال,شنبه,شركت
# ---
# ['#شگویا', '#صبا', '#تملت،', '#زکوثر']
# در,معاملاتی,نمادهای,انجام,خواهد,ساعت,مذکور,مورخ,شد,تا,به,از,شنبه,الی
# ---
# ['#شگویا', '#صبا،']
# در,ساعت,انجام,تا,معاملات,به,اطلاع,رساند,اجرایی,شد,سفارشات,راستای,دستورالعمل,شگویا
# ---
# ['#شگویا', '#فارس']
# به,شد,عرضه,در,سال,با,فارس,های,از,این,فروش,سهام,سود,می
# ---
# ['#شگویا']
# به,در,شگویا,است,شرکت,بخش,سازی,شده,این,هزار,از,pet,تن,فروش
# ---
# ['#شیراز', '#شیراز']
# ریال,میلیارد,در,است,فروش,داشت,نرخ,با,تن,شیراز,خوبی,صادر,مرداد,بود
# ---
# ['#شیراز', '#کرماشا']
# به,نرخ,اوره,در,فروش,از,هاي,داخلي,رساند,کود,محترم,استحضار,کشاورزي,وزارت
# ---
# ['#شیراز']
# در,ریال,میلیارد,است,فروش,نرخ,با,ماهه,کرده,تن,هزار,صادر,بود,سود
# ---
# ['#شیران', '#شپنا']
# از,شیران,شپنا,بلوک,خریدار,گویا,ها,ریال,این,برای,خبرمیدهند,شده,شناسایی,شد
# ---
# ['#شیران', '#وآتی']
# فروش,بلوک,شیران,وآتی,خریدارو,خرید,خریدpo,خریدا,خریداد,خریدار,خریداران,ﻻزم,خریخت,خریداري
# ---
# ['#شیران', '#واتی']
# در,سود,ریال,واتی,شیران,برای,چهارشنبه,داشتفوری,حدود,بلوک,خواهد,روز,ریالی,آگهی
# ---
# ['#شیران']
# در,ریال,میلیارد,فروش,است,با,به,نرخ,شیران,بوده,سود,ماهه,از,داشته
# ---
# ['#صبا', '#آریا', '#شستا']
# هفته,این,صبا,یعنی,اول,ساسول,بعد,شود,اردیبهشت,چهارشنبه,آریا,شستا,می,عرضه
# ---
# ['#صبا', '#تاصیکو']
# نکته,در,صورت,محاسبات,ارزش,است,این,وضعیت,بورسی,تاصیکو,گذاری,پرتفوی,صبا,تامین
# ---
# ['#صبا', '#زکوثر']
# معاملاتی,شرکت,گذاری,نماد,سرمایه,ساعت,معاملات,صبا,باشد,ادامه,کوثر,خواهد,انجام,در
# ---
# ['#صبا']
# در,به,صبا,از,گذاری,عرضه,سرمایه,شرکت,است,ریال,سود,ارزش,تامین,که
# ---
# ['#صرافی']
# ملی,صرافی,ﻻزم,خریداد,خريداري,خريدبخشي,خریخت,خریختخریخت,خرید,خریدpo,خریدا,خریدار,خريدار,خریداران
# ---
# ['#عرضه_بزرگ']
# دولت,اساس,برنامه,به,فروش,قرار,شویم,عرضهبزرگ,نامه,که,آن,های,صندوق,هیت
# ---
# ['#غاذر', '#وآذر']
# از,غاذر,طریق,های,سرمایه,شرکت,باشد,مراجع,وآذر,جمله,من,به,پیاذر,صنعت
# ---
# ['#غاذر']
# در,ریال,میلیارد,فروش,است,به,ریالی,با,ماهه,داشته,کتلت,بود,سود,نرخ
# ---
# ['#غالبر']
# در,ریال,میلیارد,به,است,فروش,سود,با,این,شده,ماهه,ریالی,بوده,از
# ---
# ['#غبشهر']
# ریال,میلیارد,فروش,در,به,است,ریالی,نرخ,بود,با,ماهه,سود,از,رسیده
# ---
# ['#غبهار', '#غشهداب']
# که,از,است,شده,زیرمجموعه,مشابه,سود,بهتر,محقق,مدت,غبهار,در,تازگی,به
# ---
# ['#غبهار']
# سود,میلیارد,در,ریالی,است,سال,کرده,جالب,عملیاتی,استغبهار,خالص,فروش,به,مورد
# ---
# ['#غبهنوش']
# ریال,فروش,در,میلیارد,است,نرخ,بود,به,ماهه,با,داشته,بوده,کمی,زده
# ---
# ['#غدام']
# ریال,در,فروش,میلیارد,با,نرخ,بوده,است,بود,به,ماهه,ریالی,سال,عدد
# ---
# ['#غدشت']
# میلیارد,در,ریال,فروش,ریالی,است,با,ماهه,داشته,به,سود,بوده,را,سال
# ---
# ['#غدیس', '#کگاز', '#غدیس']
# به,قرارداد,شیشه,هر,نسبت,دو,در,غدیس,صورت,مبلغ,سی,مطابق,شرکت,پس
# ---
# ['#غدیس']
# ریال,فروش,در,میلیارد,است,ماهه,به,با,نرخ,غدیس,از,سود,شده,بوده
# ---
# ['#غسالم']
# میلیارد,در,ریال,فروش,با,است,به,بوده,داشته,ریالی,عدد,این,ماهه,شده
# ---
# ['#غشاذر']
# میلیارد,ریال,در,فروش,با,است,ماهه,این,سود,به,عدد,بوده,ریالی,مواجه
# ---
# ['#غشان', '#بمپنا']
# مالی,به,از,مي,باشد,ماهه,تغییر,روزهاي,دوره,یا,اهمیتی,رخ,تا,تقاضاي
# ---
# ['#غشان']
# میلیارد,ریال,در,فروش,به,ماهه,است,با,از,ریالی,سود,بوده,که,بود
# ---
# ['#غشصفا']
# ریال,میلیارد,در,فروش,است,بوده,از,به,با,سود,خوب,زده,ماهه,بود
# ---
# ['#غشصفها']
# از,مشوق,در,قانوني,مصوب,ساختار,مالي,اصلاح,مجوز,عالي,غشصفها,کرد,کشور,هماهنگي
# ---
# ['#غشهد']
# در,به,ریال,از,است,فروش,میلیارد,ماهه,شرکت,سود,داشته,غشهد,سرمایه,دارایی
# ---
# ['#غشهداب', '#غبهار']
# غبهار,پايه,چهارشنبه,در,مي,بهاران,گلبهار,شركت,امروز,صنعت,بازار,کشت,خراسان,فرابورس
# ---
# ['#غشهداب']
# در,ریال,میلیارد,فروش,است,به,نرخ,بوده,با,سود,شده,ریالی,ماهه,بود
# ---
# ['#غشوکو']
# در,سود,ریال,زیان,به,ماهه,است,عملیاتی,از,میلیارد,داشته,شرکت,کرده,رسیده
# ---
# ['#غصینو']
# در,به,سود,از,ریال,است,میلیارد,افزایش,شرکت,با,نرخ,ماهه,که,محصولات
# ---
# ['#غفارس']
# میلیارد,در,فروش,ریال,با,است,ریالی,ماهه,سود,مواجه,به,از,بوده,قبل
# ---
# ['#غفارس...گزارش']
# از,به,محل,انباشته,معافيت,سرمایه,ریال,منظور,در,هیئت,مبلغ,استفاده,جلوگيري,ماليات
# ---
# ['#غمارگ', '#غمارگ']
# با,غمارگ,به,توسط,موجود,اهمیت,معاملاتی,شده,روز,متوقف,کاری,منتشر,در,مدت
# ---
# ['#غمارگ']
# ریال,فروش,میلیارد,در,به,است,نرخ,با,ماهه,سود,داشته,را,بود,بوده
# ---
# ['#غمهرا']
# ریال,در,فروش,میلیارد,است,نرخ,به,با,بود,ماهه,سود,را,این,از
# ---
# ['#غمینو']
# میلیارد,ریال,در,فروش,به,ریالی,با,است,از,ماهه,سود,بود,بوده,داشته
# ---
# ['#غناب']
# فروش,شرکت,در,ریال,غناب,دارایی,پنج,مبلغ,اشراق,طریق,بهای,تمام,ساعت,خيابان
# ---
# ['#غنوش']
# به,در,ریال,از,سود,غنوش,فروش,ماهه,نوش,شرکت,میلیارد,می,مازندران,معاملاتی
# ---
# ['#غنیلی']
# زیان,کرده,است,محقق,ریال,توفق,افزایش,لازم,مصوب,نداشته,نقدی,گزارش,نمودند,ارائه
# ---
# ['#غويتا']
# ریال,محقق,ماهه,است,در,کرده,سود,داشته,بود,خوبی,حسابرسی,ویتانا,تلفیقی,شده
# ---
# ['#غویتا']
# میلیارد,فروش,ریال,در,است,با,ریالی,به,سود,عدد,بوده,ماهه,بود,داشته
# ---
# ['#غپاذر']
# در,میلیارد,ریال,به,فروش,است,با,ریالی,ماهه,سهم,سود,را,بوده,رسیده
# ---
# ['#غپاک']
# ریال,میلیارد,در,فروش,است,با,به,ماهه,سود,بوده,سهم,شده,زده,این
# ---
# ['#غپونه']
# در,سود,به,ریال,است,ماهه,کرده,خالص,غپونه,استغپونه,ریالی,سهم,رسیده,نسبت
# ---
# ['#غپینو', '#غصینو', '#خودکفا']
# روغن,به,کارخانه,حاضر,خودکفا,خزر,بلوک,فعال,غصینو,خریدار,خرید,پرتودانه,درحال,صنعت
# ---
# ['#غپینو', '#غصینو']
# مینو,گروه,به,صنعتی,کارخانه,شرکت,روغن,این,با,تولید,تولیدی,نیاز,در,های
# ---
# ['#غپینو']
# در,میلیارد,ریال,فروش,است,با,سود,ریالی,به,زده,این,ماهه,بوده,بود
# ---
# ['#غپیچک']
# به,از,منظور,مبلغ,سرمایه,هیئت,ریال,در,تاریخ,شمول,تهرانخيابان,شرکت,سه,سهامداران
# ---
# ['#غچین']
# در,ریال,میلیارد,فروش,به,با,است,بوده,ریالی,نرخ,سود,از,عدد,این
# ---
# ['#غگرجي']
# شرکت,سرمایه,ثبت,افزایش,مجمع,اعلام,این,رسید,هم,کرد,تا,است,را,به
# ---
# ['#غگرجی']
# در,ریال,میلیارد,فروش,است,به,ماهه,از,سود,با,ریالی,عدد,شرکت,بود
# ---
# ['#غگز']
# به,با,ریال,هاي,در,غگز,زیان,گز,شده,است,منظور,توجه,سکه,تا
# ---
# ['#غگل']
# در,ریال,میلیارد,فروش,به,است,سال,از,مالی,ماهه,قبل,با,ریالی,سود
# ---
# ['#غگلستا']
# میلیارد,در,ریال,فروش,با,است,به,ماهه,ریالی,سود,بوده,از,این,عدد
# ---
# ['#غگلپا']
# ریال,فروش,میلیارد,در,نرخ,بود,است,به,ماهه,با,ریالی,سود,عدد,این
# ---
# ['#غگیلا']
# در,می,بازار,پاستوریزه,سود,با,ماهه,است,مواجه,غگیلا,زودی,ایران,پگاه,شیرها
# ---
# ['#فاذر']
# در,به,میلیارد,ریال,شرکت,درامد,فاذر,از,با,است,ماهه,ریالی,شده,سود
# ---
# ['#فاذر:']
# را,پول,به,از,که,است,چرا,کارخانه,پرداخت,آنکه,مجموعه,کرده,آذرآب,این
# ---
# ['#فاراک', '#فاذر']
# در,سازی,این,قرارداد,است,ماشین,گفت,که,وزارت,صنعت,داخل,تجهیزات,پتروشیمی,فاراک
# ---
# ['#فاراک']
# در,به,است,شرکت,ریال,میلیارد,از,درامد,که,با,فاراک,ماهه,ماه,گزارش
# ---
# ['#فارس', '#بفجر']
# فروش,ریال,فارس,سود,از,بفجر,در,شناسایی,محل,گذاری,میلیارد,ها,سرمایه,نماد
# ---
# ['#فارس', '#شگویا']
# به,در,از,ریال,شرکت,سهم,سود,عرضه,شگویا,محل,تعداد,این,پتروشیمی,شناسایی
# ---
# ['#فارس', '#نوری']
# نوری,فارس,در,از,عرضه,شده,بورس,به,ماه,ریال,میلیارد,فروش,که,می
# ---
# ['#فارس', '#پترول']
# فارس,از,هلدینگ,خلیج,به,می,پترول,پتروگچساران,خبری,پتروشیمی,منابع,سوی,طلب,خبر
# ---
# ['#فارس']
# ...
# ['#ومعادن', '#کگل', '#فولاد']
# برای,سیاست,نکته,که,ومعادن,گزارش,فولاد,است,را,محاسبه,نیز,کرده,از,کگل
# ---
# ['#ومعادن']
# در,به,از,سرمایه,ریال,ومعادن,شرکت,افزایش,سهم,کرده,را,حال,هر,سود
# ---
# ['#ومعادن)']
# به,که,از,این,است,در,بیدار,تامین,توسعه,شده,سرمایه,شرکت,ومعادن,تمدن
# ---
# ['#ومعلم', '#بزاگرس', '#زماها']
# یک,عرضه,در,این,هفته,نکته,بازار,دوشنبه,شود,سه,جالب,مهمان,اولیه,سال
# ---
# ['#ومعلم']
# به,ریال,در,با,میلیارد,مبلغ,است,سهم,سود,سال,سنواتی,که,ومعلم,معلم
# ---
# ['#ومعیار']
# در,از,است,شرکت,که,برای,با,به,محترم,تاکنون,سازمان,فولاد,سازی,قابل
# ---
# ['#وملت']
# در,شرکت,محقق,سود,ریال,کرده,ماهه,استوملت,زیان,مورخ,مجمع,جلسه,ساعت,برگزار
# ---
# ['#وملل']
# در,ریال,به,میلیارد,سود,مثبت,تراز,است,وملل,را,از,سال,گزارش,ماهه
# ---
# ['#وملي']
# به,سهام,توسط,رساني,قيمت,تغييرات,بيش,با,شد,كنفرانس,از,توجه,وملي,برگزاري
# ---
# ['#وملی']
# به,در,از,است,ریال,ملی,این,کفش,سود,که,وملی,دارايي,ها,محل
# ---
# ['#ومهان', '#ومهان']
# است,در,ریال,سود,دی,مسیر,ومهان,کرده,محقق,ماهه,سهم,عرضه,میلیون,مالي
# ---
# ['#ومهان']
# در,ریال,عرضه,ومهان,سود,مهر,میلیون,است,توسعه,کرده,میلیارد,با,محقق,اولیه
# ---
# ['#ونفت']
# در,به,ریال,سود,شرکت,میلیارد,ونفت,از,با,ها,نفت,است,گذاری,سرمایه
# ---
# ['#ونوین', '#تنوین']
# میلیون,سود,ریال,مبلغ,از,به,نقدی,تنوینونوین,که,سهم,در,خواهد,قالب,بود
# ---
# ['#ونوین', '#ثجوان']
# به,شرکت,بانک,شده,فروش,با,است,می,از,سهم,مبلغ,توجه,نوین,تسهیلات
# ---
# ['#ونوین']
# در,به,ریال,از,میلیارد,است,بانک,ونوین,سود,ها,سرمایه,ماهه,منفی,تراز
# ---
# ['#ونيرو']
# افزایش,مهلت,سرمایه,استفاده,از,مجوز,تمدید,به,شماره,با,این,موافقت,گردید,ونيرو
# ---
# ['#ونیرو']
# در,به,ریال,از,شرکت,سود,سرمایه,ونیرو,میلیارد,است,مبلغ,میلیون,های,افزایش
# ---
# ['#ونیکی']
# در,سود,ریال,ونیکی,از,سرمایه,به,میلیارد,سهم,است,داشته,فروش,گذاری,ها
# ---
# ['#ونیکی)']
# داراییها,بورس,سرمايه,رسانی,گذاري,به,روز,منبع,ارزش,خالص,ونیکی,ملي,ايران,آرمون
# ---
# ['#وهنر']
# به,در,از,ریال,سرمایه,مبلغ,وهنر,با,سود,افزایش,محل,شرکت,هیئت,است
# ---
# ['#وهور', '#وغدیر']
# سال,در,از,نیمه,مالی,چند,شده,افت,است,برق,میلیارد,نسبت,گيلان,سهم
# ---
# ['#وهور']
# به,در,شرکت,نیروگاه,با,این,وهور,است,ریال,سود,از,برق,انرژی,بخش
# ---
# ['#وپارس', '#خساپا', '#خودرو', '#خگستر']
# وپارس,خساپا,روزهای,خگستر,خودرو,به,افزایش,های,بازگشایی,شده,نظر,شد,خواهند,آتی
# ---
# ['#وپارس', '#خساپا']
# توقف,وپارس,بازار,خساپا,فردا,های,خریداری,خریداري,خريدبخشي,خریخت,خریدسود,خریدخدمات,خریختخریخت,خرید
# ---
# ['#وپارس', '#خگستر']
# ریال,واگذاری,میلیارد,شناسایی,محل,میکند,را,این,سود,از,کرده,خگستر,وپارس,واگذار
# ---
# ['#وپارس', '#وساخت']
# کرده,وپارس,سود,واگذاری,را,است,حدود,شناسایی,میلیارد,ان,با,وساخت,فروش,ریال
# ---
# ['#وپارس', '#پارسیان']
# در,از,به,میلیارد,سنگان,معدن,پارسیان,که,یک,این,سود,خالص,شد,های
# ---
# ['#وپارس']
# در,به,ریال,از,میلیارد,است,بانک,سود,پارسیان,سرمایه,وپارس,این,با,سال
# ---
# ['#وپاسار', '#بپاس']
# اسفند,سیم,سهم,آگهی,تاریخ,با,حدود,زده,آخر,به,نرخ,است,را,هم
# ---
# ['#وپاسار', '#رمپنا']
# می,از,اسفند,در,نیز,را,تاریخ,سهم,با,نرخ,رمپنا,فروشد,ریال,وپاسار
# ---
# ['#وپاسار', '#وبصادر', '#ونوین', '#ونوین', '#وبصادر', '#وتجارت', '#وپاسار', '#وپست', '#وتجارت', '#وپست،', '#وکار', '#وخاور', '#وسینا', '#وبملت']
# به,مربوط,بیشترین,نسبت,است,تابستان,پاییز,فصلی,کاهش,رشد,وبصادر,وتجارت,از,وپاسار
# ---
# ['#وپاسار', '#ومعان']
# وپاسار,در,روز,هم,یکجا,را,میفروشد,مثل,قیمت,بانکی,ومعان,نقد,سهم,ها
# ---
# ['#وپاسار']
# در,ریال,میلیارد,سود,به,ماهه,است,تراز,مثبت,وپاسار,از,را,سال,این
# ---
# ['#وپترو', '#پلوله']
# سهام,سازی,وپترو,شفاف,پلوله,عملیات,اجرایی,توقف,توقیف,ﻻزم,خریدا,خريدبخشي,خریخت,خریختخریخت
# ---
# ['#وپترو']
# در,به,سود,وپترو,میلیارد,از,ریال,سال,است,ریالی,سازی,های,داشته,گذاري
# ---
# ['#وپخش', '#دتوزیع']
# است,مهر,فروش,سود,کرده,شناسایی,ریال,با,میلیون,گزارش,پرتفوی,گذاری,تا,داروپخش
# ---
# ['#وپخش']
# در,ریال,سود,به,از,میلیارد,است,وپخش,شرکت,سال,سهم,های,با,سرمایه
# ---
# ['#وپسا']
# سرمايه,ساختمان,محقق,فارس,خليج,صنعت,وپسا,صبر,کرده,سال,قبل,مثل,گذاري,را
# ---
# ['#وپست', '#ونوین', '#وپارس', '#وپاسار']
# به,بهادار,اوراق,رعایت,عدم,تهران,بورس,ماده,در,پذیرش,تا,توجه,اعطای,رساند
# ---
# ['#وپست']
# در,به,ریال,میلیارد,است,بانک,ماهه,مثبت,سود,تراز,با,سال,زیان,وپست
# ---
# ['#وکادو']
# در,به,سود,ریال,وکادو,از,رسیده,سال,میلیون,سهم,مجمع,ماهه,میلیارد,شرکت
# ---
# ['#وکادوبا']
# فروش,اسفند,شناسایی,احياء,سنگ,گذاری,است,وکادوبا,طبس,سپاهان,زغال,کرده,در,سود
# ---
# ['#وکار']
# در,ریال,میلیارد,سود,است,به,ماهه,منفی,تراز,از,وکار,تسهیلات,سپرده,پرداختی
# ---
# ['#وکوثر']
# در,ادغام,مجمع,جلسه,این,خيابان,مجامع,میلیارد,شرکت,روز,وکوثر,ریال,درمحل,مورخ
# ---
# ['#وگردش']
# در,به,خیابان,با,پلاک,وگردش,تهران,از,بلوار,بانک,ریال,کرمان,سازی,این
# ---
# ['#وگستر']
# در,ریال,سود,به,میلیون,کرده,است,میلیارد,مبلغ,ماهه,مالیات,وگستر,تا,سال
# ---
# ['#ویکس']
# بحران,به,در,ویکس,آمریکا,شاخص,مالی,نیستپارسیس,صورتیکه,بود,رسید,قاب,آخرین,بار
# ---
# ['#پارتا', '#پیزد']
# ایران,در,فرابورس,دوم,مجتمع,صنایع,پارتا,لاستیک,پیزد,شرکت,بازار,یزد,درج,خریدpo
# ---
# ['#پارتا']
# در,به,لاستیک,سود,است,ریال,با,ماهه,های,تولید,پارتا,از,که,قبل
# ---
# ['#پارس', '#آریا']
# عرضه,به,آخرين,در,ماه,فروردين,خواهد,زياد,نگراني,شد,لغو,شيوع,دليل,مي
# ---
# ['#پارس', '#جم']
# پتروشیمی,کنیم,از,با,جم,های,که,خوراک,پارس,آن,پروژه,را,ایجاد,این
# ---
# ['#پارس']
# در,ریال,فروش,میلیارد,است,به,ماهه,پارس,نرخ,با,استایرن,بوده,از,سود
# ---
# ['#پارسان', '#زاگرس']
# سود,حدود,پارسان,میکند,میلیارد,از,تومان,محل,شناسایی,به,زاگرس,یعنی,ازای,ریال
# ---
# ['#پارسان', '#شپدیس']
# است,به,سود,ریال,اضافه,شپدیس,ازای,هنوز,کرده,پارسان,محقق,میلیون,امروز,مجامع
# ---
# ['#پارسان', '#شیراز']
# در,تبدیل,پارسان,بدهی,عمده,به,ای,بخش,شیراز,تسهیلات,تسویه,ارزی,از,شد
# ---
# ['#پارسان', '#وغدیر']
# سهم,برای,به,ازای,هر,ریال,وغدیر,پارس,است,تومان,خوبی,یعنی,موثر,سود
# ---
# ['#پارسان']
# در,سهم,از,پارسان,به,سود,ریال,است,مجمع,این,شرکت,که,درصد,هر
# ---
# ['#پارسان)', '#شپدیس']
# به,سهم,سود,تومان,سال,که,ازای,از,در,هر,پارسان,مالی,پارسیان,تا
# ---
# ['#پارسان)']
# ماهانه,گاز,بعد,ارزش,به,خالص,مرداد,پارسیان,روزرسانی,ارائه,پارسان,گزارش,نفت,از
# ---
# ['#پارسیان']
# در,ریال,از,به,سود,پارسیان,میلیارد,سرمایه,ماهه,افزایش,مبلغ,ریالی,است,شرکت
# ---
# ['#پاسا']
# ریال,فروش,میلیارد,در,است,نرخ,با,به,ماهه,ریالی,بوده,بود,شده,سود
# ---
# ['#پاكشو)،', '#شكربن)،صنايع', '#كخاك)،', '#خپويش)', '#اخابر)']
# معاملاتي,قيمت,مي,با,حراج,آماده,شركت,استفاده,معامله,انجام,نوسان,از,محدوديت,مكانيزم
# ---
# ['#پاکشو']
# ریال,در,فروش,میلیارد,است,نرخ,با,به,ریالی,سود,پودر,مایعات,ماهه,مواجه
# ---
# ['#پتایر']
# ریال,میلیارد,در,فروش,است,ماهه,نرخ,به,با,زده,کرده,بود,پتایر,سود
# ---
# ['#پترول', '#فارس', '#ممسنی']
# عرضهمی,با,شود,دوباره,ممسنی,ریالی,قیمت,فارس,پترول,خریداری,خریداد,خریدش,خریختخریخت,خرید
# ---
# ['#پترول', '#فارس']
# فروش,پتروشیمی,است,پترول,شرکت,ها,این,فارس,بلوک,توسط,شفاف,عرضه,گذاری,خریدار
# ---
# ['#پترول']
# در,از,به,شرکت,سرمایه,پترول,سود,ریال,میلیارد,پتروشیمی,گذاری,این,است,با
# ---
# ['#پخش', '#والبر', '#پخش']
# پخش,شركت,درصد,در,شود,سهم,عام,البرز,سهامي,با,مديريتي,بازارمی,است,بلوک
# ---
# ['#پخش', '#والبر']
# ریال,برای,فروش,بلوک,والبر,شناسایی,رفتن,از,سود,ازای,حدود,شده,در,شود
# ---
# ['#پخش']
# در,میلیارد,ریال,با,درامد,به,ریالی,ماهه,البرز,بوده,است,شده,فروش,از
# ---
# ['#پدرخش']
# ریال,میلیارد,در,فروش,با,است,شده,این,ماهه,به,سود,نرخ,عدد,بوده
# ---
# ['#پرداخت']
# میلیارد,ریال,در,با,است,فروش,ماهه,ریالی,داشته,به,سود,بود,بوده,مواجه
# ---
# ['#پرديس']
# ریال,سود,کرده,میلیارد,فروش,گذاری,در,گذاري,است,شناسایی,پرديس,سرمایه,ها,شهریور
# ---
# ['#پردیس']
# در,ریال,گذاری,سود,سرمایه,پردیس,ها,کرده,است,فروش,از,به,میلیارد,گزارش
# ---
# ['#پسهند']
# فروش,ریال,در,میلیارد,است,نرخ,با,ریالی,ماهه,بود,شده,به,مواجه,داشته
# ---
# ['#پسهند.در']
# فروش,ریال,نرخ,میلیارد,است,بود,با,ریالی,در,بوده,اول,ثبات,همین,زده
# ---
# ['#پسهند9']
# ریال,میلیارد,ماهه,سود,در,به,عملیاتی,خالص,است,رسیده,فروش,را,پسهند,برابر
# ---
# ['#پشاهین']
# ریال,در,مدت,پشاهین,کرده,قبل,این,مشابه,پلاستيک,عدد,ماهه,سال,توليدي,شاهين
# ---
# ['#پعایق']
# به,در,سود,ریال,از,که,سرمایه,هیئت,رسیده,گزارش,منظور,مشابه,مدت,پعایق
# ---
# ['#پلاست']
# به,در,زیان,ریال,مالی,از,است,ولی,ماهه,مبلغ,سود,هیئت,که,حال
# ---
# ['#پلاسک']
# ریال,میلیارد,است,در,فروش,با,داشته,سهم,زیان,ماهه,از,به,بوده,این
# ---
# ['#پلوله', '#وپترو']
# سود,در,است,افزايش,به,از,شرکت,فروش,هاي,مربوط,تحول,ریال,خواهد,ماهه
# ---
# ['#پلوله']
# در,ریال,به,میلیارد,سود,است,ماهه,سال,پلوله,شرکت,کرده,خالص,محقق,از
# ---
# ['#پکرمان', '#وبانک']
# وبانک,ریال,است,پکرمان,نقد,توسط,نرخ,بلوک,که,یکجا,در,منتظر,شود,بود
# ---
# ['#پکرمان']
# در,فروش,ریال,میلیارد,با,ریالی,است,نرخ,به,ماهه,سود,بوده,مواجه,بود
# ---
# ['#پکویر']
# در,ریال,فروش,میلیارد,است,به,نرخ,با,این,سود,شده,پکویر,ماهه,از
# ---
# ['#پیزد']
# ریال,در,میلیارد,ماهه,به,بازار,پیزد,قبل,داشته,فروش,پارتا,سال,گرددیک,عرضه
# ---
# ['#چافست']
# در,ریال,میلیارد,فروش,به,است,با,شرکت,ماهه,ریالی,از,سود,داشته,سهم
# ---
# ['#چدن', '#فساز']
# می,عرضه,شود,چدن,ریال,با,فساز,مرداد,نرخ,روز,دوشنبه,در,سهم,برای
# ---
# ['#چدن', '#فسازان']
# سود,فسازان,کرده,فروش,میلیون,ریال,است,با,از,شناسایی,شرکت,محل,چدن,سهم
# ---
# ['#چدن', '#فغلسا...چه']
# نماد,سازان,چدن,شرکت,قشنگی,درج,به,غلتک,های,فغلساچه,با,متعلق,خریدخدمات,خریدار
# ---
# ['#چدن']
# در,ریال,فروش,میلیارد,است,به,نرخ,با,ماهه,سود,ریالی,از,سهم,بوده
# ---
# ['#چفیبر']
# به,در,فروش,از,مزایده,شرکت,فیبر,های,ریال,آلات,عمومی,قیمت,با,چفیبر
# ---
# ['#چنوپا']
# خيابان,کردچنوپا,سيزدهم,دوشنبه,ميرعماد,در,جلسه,ساعت,عمومی,تهران,درمحل,میگردد,برگزار,این
# ---
# ['#چکارن']
# در,ریال,به,میلیارد,فروش,با,از,است,بوده,که,شده,این,شرکت,ماهه
# ---
# ['#چکاوه']
# فروش,ریال,در,میلیارد,نرخ,با,است,بوده,ماهه,شده,به,ریالی,این,افت
# ---
# ['#چکاپا']
# ریال,در,میلیارد,نرخ,است,فروش,به,رول,نیز,سفید,خمير,از,شده,سود
# ---
# ['#کاتد']
# نرخ,این,معاملات,از,که,در,محصول,میانگین,معامله,مشاهده,کالا,با,کمتر,دیماه
# ---
# ['#کاذر']
# ریال,در,میلیارد,فروش,است,ماهه,نرخ,با,به,بود,ریالی,شده,سود,داشته
# ---
# ['#کارا']
# در,میلیارد,کارا,خيابان,فروش,ریال,روز,چهارراه,تهران,رسیده,داشته,نماد,شهيد,بالاتر
# ---
# ['#کاسپین']
# ریال,میلیارد,در,فروش,ماهه,است,سود,با,بوده,رشد,به,کاسپین,این,خوب
# ---
# ['#کالا']
# در,به,ریال,میلیارد,بورس,شرکت,از,سود,کالا,است,مبلغ,ماهه,درامد,سرمایه
# ---
# ['#کاما', '#فروی', '#کاما']
# از,کاما,احتمالا,دیگر,بود,کمتر,این,با,سوی,در,تعدادکد,تاثیر,سود,تومان
# ---
# ['#کاما', '#فروی']
# فروی,ریال,سود,کرده,عرضه,فروش,شرکت,از,است,به,روی,اصفهان,ذوب,بازار
# ---
# ['#کاما']
# در,فروش,ریال,میلیارد,است,سود,با,ریالی,به,روی,از,سهم,ماهه,نرخ
# ---
# ['#کاوه']
# ریال,در,فروش,میلیارد,است,به,نرخ,تن,با,ریالی,هزار,از,شمش,کرده
# ---
# ['#کایتا']
# کایتا,زیان,کرده,ریال,ماهه,است,را,به,در,خيابان,محقق,این,افزایش,نجات
# ---
# ['#کباده']
# به,در,است,قبل,ریال,از,هر,سود,کباده,سال,که,استتهيه,استقلال,یا
# ---
# ['#کبافق']
# به,در,است,ریال,فروش,از,کبافق,شده,ماهه,سال,با,سود,میلیارد,تن
# ---
# ['#کترام']
# ریال,میلیارد,در,فروش,است,نرخ,ماهه,به,با,بوده,داشته,ریالی,مواجه,سود
# ---
# ['#کتوکا']
# فروش,ریال,میلیارد,در,است,ریالی,با,به,نرخ,ماهه,بوده,داشته,سود,رشد
# ---
# ['#کحافظ']
# ریال,در,میلیارد,به,فروش,ماهه,از,داشته,بوده,است,شده,خوبی,رسیده,زیان
# ---
# ['#کخاک']
# ریال,در,میلیارد,فروش,است,ماهه,با,نرخ,سود,ریالی,بوده,سهم,مواجه,به
# ---
# ['#کدما']
# ریال,در,میلیارد,فروش,ماهه,است,سود,به,با,شده,سهم,ریالی,این,داشته
# ---
# ['#کرازی']
# در,فروش,ریال,میلیارد,است,دارویی,نرخ,به,با,شرکت,ریالی,بود,ماهه,سود
# ---
# ['#کرماشا']
# ریال,میلیارد,در,فروش,است,نرخ,با,ریالی,به,تن,سود,ماهه,هزار,کرده
# ---
# ['#کرمان', '#وساخت']
# وساخت,برای,به,تمام,شده,سود,این,بهای,فروش,توسط,با,از,نظر,میلیارد
# ---
# ['#کرمان']
# در,به,از,کرمان,شرکت,سرمایه,با,ریال,سود,است,سازی,گذاری,این,میلیارد
# ---
# ['#کرونا', '#گکوثر']
# به,کرونا,حفظ,در,خواهد,ویروس,بین,شرکت,شهروندی,مقرر,است,ثانوی,کوثر,منتشر
# ---
# ['#کرونا']
# را,نکنید,فراموش,کرونا,خريداران,خريداري,خريدبخشي,خریخت,خریختخریخت,خرید,خریدpo,خریدا,خریداد,خردادعدد
# ---
# ['#کرونا،']
# از,کرد,کشور,این,چین,ویروس,فعال,خواهد,صندوق,بهبود,بانک,عملیات,های,repo
# ---
# ['#کروی']
# در,کروی,ریال,سود,به,است,از,میلیارد,سال,سهم,این,بخش,تا,های
# ---
# ['#کساوه']
# ریال,فروش,در,میلیارد,به,نرخ,با,است,بود,ریالی,بوده,ماهه,سود,زده
# ---
# ['#کساپا', '#خساپا']
# توسط,فروش,به,مجموعه,خودروسازی,میرسد,های,آغا,کساپا,بلوک,نظر,شده,سهام,زیر
# ---
# ['#کساپا']
# در,میلیارد,ریال,فروش,به,ریالی,است,ماهه,نرخ,رسیده,با,زیان,بوده,رشد
# ---
# ['#کسرا', '#ولغدر']
# ولغدر,های,بازار,کسرا,فردا,توقف,ﻻزم,خریدار,خریختخریخت,خرید,خریدpo,خریدا,خریداد,خریدارو
# ---
# ['#کسرا']
# ریال,فروش,در,میلیارد,است,نرخ,با,ماهه,بود,ریالی,سود,به,زده,بوده
# ---
# ['#کسرام']
# فروش,ریال,در,میلیارد,است,نرخ,با,بوده,ریالی,ماهه,به,زیان,شده,قبل
# ---
# ['#کسعدی']
# ریال,میلیارد,در,با,است,ماهه,درامد,سود,فروش,به,بوده,کرده,شده,ریالی
# ---
# ['#کشرق']
# فروش,ریال,در,است,میلیارد,به,شده,نرخ,با,داشته,بوده,ریالی,از,مواجه
# ---
# ['#کصدف']
# با,به,این,می,شرکت,در,باشد,قیمت,از,تا,یا,است,بر,کصدف
# ---
# ['#کطبس', '#کپرور', '#کشرق']
# قیمت,فولاد,در,شمش,سنگ,معادن,زغال,با,به,پایه,تعیین,شود,بورس,این
# ---
# ['#کطبس', '#کپرور']
# است,سازی,میلیارد,شفاف,حل,فروش,سود,زده,کرده,شناسایی,کطبس,از,کپرور,ریال
# ---
# ['#کطبس']
# ریال,فروش,در,میلیارد,است,نرخ,با,ریالی,به,داشته,ماهه,سود,شده,بوده
# ---
# ['#کفرآور']
# زیان,در,ریال,از,کرده,ماهه,است,به,فروش,کفرآور,سود,سهم,را,شده
# ---
# ['#کفرا']
# ریال,در,میلیارد,فروش,است,به,با,ماهه,بود,سهم,خوب,عدد,ریالی,این
# ---
# ['#کفراور']
# در,شرکت,سود,ریال,جاده,رسیده,کلات,بالاخره,استکفراور,ساعت,میگردد,یکشنبه,جلسه,فرآورده
# ---
# ['#کفپارس']
# در,ریال,میلیارد,فروش,به,است,با,از,بوده,داشته,که,شرکت,این,های
# ---
# ['#کقزوی']
# در,از,فروش,به,زیان,استکقزوی,افزایش,سال,ریال,نرخ,شرکت,بود,محصولات,می
# ---
# ['#کلر']
# در,کلر,ریال,به,با,فروش,میلیارد,پارس,از,است,شرکت,که,سازی,شود
# ---
# ['#کلوند']
# میلیارد,ریال,در,فروش,است,به,ماهه,با,ریالی,بوده,سود,مواجه,داشته,خوبی
# ---
# ['#کماسه']
# در,ریال,فروش,است,به,میلیارد,با,شرکت,نرخ,از,این,ماهه,بود,ریالی
# ---
# ['#کمرجان']
# ریال,در,فروش,میلیارد,به,است,میلیون,ماهه,از,تومان,شده,این,عدد,بوده
# ---
# ['#کمنگنز']
# ریال,فروش,در,است,میلیارد,نرخ,به,ماهه,با,ریالی,شده,سود,سهم,بود
# ---
# ['#کنور', '#ومعادن', '#فزرین']
# در,سرب,تولید,وروی,معدنی,سرمایه,شمش,آن,شرکت,گذاری,شود,روی,سه,تن
# ---
# ['#کنور']
# ریال,در,میلیارد,فروش,است,به,گندله,نرخ,کنسانتره,ماهه,بوده,با,سود,ریالی
# ---
# ['#کنگین']
# ریال,را,کرد,کنگین,از,تقسیم,خریدخدمات,خریداد,خريدبخشي,خریخت,خریختخریخت,خرید,خریدpo,خریدا
# ---
# ['#کهرام']
# در,زیان,ماهه,ریال,به,کرده,سود,است,شده,رسیده,سرعت,عملیاتی,دهی,کهرام
# ---
# ['#کهمدا']
# فروش,ریال,میلیارد,در,است,نرخ,با,ریالی,ماهه,بوده,بود,تن,سود,داشته
# ---
# ['#کوثر']
# در,به,از,شرکت,کوثر,ریال,بیمه,سرمایه,سود,میلیارد,است,گزارش,با,افزایش
# ---
# ['#کورز']
# به,در,ریال,از,کورز,ماهه,منظور,جلسه,هیئت,رسیده,است,که,سود,سرمایه
# ---
# ['#کویر']
# در,ریال,به,فروش,میلیارد,با,است,کویر,شرکت,نرخ,از,سود,بوده,ریالی
# ---
# ['#کپارس']
# در,میلیارد,ریال,فروش,به,ماهه,با,بود,است,ریالی,سود,بوده,مواجه,کپارس
# ---
# ['#کپرور', '#کشرق']
# از,متوقف,شوند,احتمالا,نیز,برده,این,مصوبه,کپرور,کشرق,می,سود,خریداد,خریختخریخت
# ---
# ['#کپرور']
# ریال,فروش,میلیارد,در,نرخ,با,است,ریالی,بوده,سود,بود,به,ماهه,از
# ---
# ['#کپشیر']
# ریال,فروش,میلیارد,در,نرخ,است,ماهه,به,با,بوده,ریالی,بود,عدد,رسیده
# ---
# ['#کچاد', '#فخوز']
# در,با,شد,فخوز,ارزش,نرخ,نهایت,عرضه,افزوده,رقابتی,چادرملو,تن,مالیات,کالا
# ---
# ['#کچاد', '#کمنگنز']
# به,بهادار,اوراق,رعایت,بورس,عدم,تهران,ماده,ناشر,شده,دستورالعمل,فوق,ثبت,ماهه
# ---
# ['#کچاد']
# در,ریال,است,فروش,به,میلیارد,نرخ,با,شرکت,از,شمش,ماهه,گندله,سود
# ---
# ['#کچینی']
# شرکت,کچینی,در,همه,روز,میگرددکاشی,ورشکستگی,ساعت,ایرانا,واقع,خودرو,به,کرج,جاده
# ---
# ['#کگاز', '#غدیس']
# به,سي,با,مبلغ,قرارداد,نسبت,شيشه,خريد,صورت,تسويه,بوده,بطر,غدیس,ماهه
# ---
# ['#کگاز']
# ریال,فروش,در,میلیارد,است,نرخ,با,ماهه,به,بوده,بود,شده,رشد,این
# ---
# ['#کگل', '#فولاد', '#وامید']
# کگل,برای,به,توجه,در,قرار,کمتر,مدیره,ای,امروز,است,فولاد,دست,که
# ---
# ['#کگل', '#میدکو']
# به,برای,جز,گویا,اول,های,که,افتتاح,معاون,شرکت,مربوط,کگل,فولاد,سنگ
# ---
# ['#کگل', '#ومعادن', '#فولاد']
# سود,ومعادن,با,کگل,حوالی,نظر,به,فولاد,اعلام,نماید,تقسیم,میتواند,ریال,خریداران
# ---
# ['#کگل', '#ومعادن']
# مجموعه,افزایش,مهم,از,ومعادن,زیر,برنامه,کگل,سرمایه,های,یکی,خريدبخشي,خريد,خريدار
# ---
# ['#کگل', '#کچاد', '#کنور', '#کگهر']
# قیمت,کنسانتره,در,گندله,ضرایب,آهن,ایران,کگهر,فردا,جدید,وزارت,به,میشود,برای
# ---
# ['#کگل', '#کچاد']
# در,با,فولاد,است,نرخ,این,شرکت,از,کنسانتره,چادرملو,صنعتی,معدنی,مبارکه,اعلام
# ---
# ['#کگل', '#کگهر']
# گهر,گل,شرکت,آهن,منطقه,تولید,افتتاح,پروژه,توسعه,سالانه,میلیون,تن,با,در
# ---
# ['#کگل']
# در,ریال,میلیارد,به,فروش,است,با,ماهه,شرکت,سال,از,سود,این,گندله
# ---
# ['#کگهر']
# در,فروش,به,است,ریال,میلیارد,نرخ,با,ریالی,ماهه,بوده,سود,را,شده
# ---
# ['#کی_بی_سی']
# میلیارد,ریال,در,فروش,با,بود,به,است,ماهه,خوب,ریالی,این,سود,از
# ---
# ['#کیسون']
# در,شرکت,کیسون,به,از,است,ریال,قرارداد,این,با,سرمایه,های,که,سود
# ---
# ['#کیمیا']
# ریال,فروش,در,میلیارد,است,به,ماهه,سود,با,نرخ,بود,ریالی,بوده,از
# ---
# ['#گتوشا']
# بازار,او,به,را,از,ورود,با,شیشلیک,داریم,می,مهمانی,رفته,پدیده,اسم
# ---
# ['#گوهران', '#رکیش']
# رکیش,ریال,سود,میلیارد,نرخ,فروش,گوهران,میکند,محل,از,شناسایی,در,با,را
# ---
# ['#گوهران', '#وامید']
# از,است,وامید,مدت,مشابه,های,ریال,امید,گوهران,در,کرده,محقق,مجموعه,بیشتر
# ---
# ['#گوهران']
# در,سود,ریال,سرمایه,به,فروش,گوهران,کرده,میلیارد,مجمع,گذاری,استگوهران,است,ها
# ---
# ['#گپارس']
# ریال,در,فروش,سود,کرده,آپارتمان,یک,میلیون,محقق,شفاف,خود,به,متری,نرخ
# ---
# ['#گکوثر']
# ریال,میلیارد,در,با,است,بوده,درامد,این,ماهه,فروش,عدد,افت,را,به
# ---
# ['#گکیش']
# در,به,ریال,سود,استگکیش,شده,از,کرد,تقسیم,مجمع,منظور,هیئت,گکیش,ریالی
# ---
# ['#گگهر']
# درصدی,از,محل,سهامداران,شده,مطالبات,گگهر,حال,حسابرس,نقدی,تایید,رسید,آورده,به
# ---

# %%
# Look at the most common top words --> add them to the stop word list
from collections import Counter

# Let's first pull out the top 30 words for each companies
words = []
for companies in data.columns:
    top = [word for (word, count) in top_dict[companies]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['سهم',
#  'تاصیکو',
#  'در',
#  'به',
#  'درصد',
#  'فولاد',
#  'از',
#  'شود',
#  'لازم',
#  'پرتفوی',
#  'دومین',
#  'nav',
#  'pnav',
#  'حاضر',
#  'بورسی',
#  'نسبت',
#  'را',
#  'حال',
#  'تحلیلی',
#  'روزرسانی',
#  'است',
#  'مالکیت',
#  'توضیح',
#  'صورت',
#  'پارسیس',
#  'بعد',
#  'استکانال',
#  'افزایش',
#  'دارد',
#  'محدوده',
#  'در',
#  'سهم',
#  'ماه',
#  'nav',
#  'رشد',
#  'ای',
#  'درصد',
#  'آذر',
#  'است',
#  'درصدی',
#  'روز',
#  'فوق',
#  'پارسیس',
#  'ان',
#  'محدوده',
#  'ارائه',
#  'تحلیلی',
#  'گزارش',
#  'حاضر',
#  'pnav',
#  'با',
#  'به',
#  'قابل',
#  'حال',
#  'بعد',
#  'روزرسانی',
#  'مشاهده',
#  'استکانال',
#  'وسپه',
#  'مقایسه',
#  'سهم',
#  'در',
#  'رسانی',
#  'استکانال',
#  'نسبت',
#  'حاضر',
#  'محدوده',
#  'پارسیس',
#  'پارسان',
#  'به',
#  'pnav',
#  'روز',
#  'تحلیلی',
#  'هر',
#  'حال',
#  'nav',
#  'درصد',
#  'خریداري',
#  'خریداقا',
#  'خرید',
#  'خریدpo',
#  'خریداری',
#  'خریدا',
#  'خریداد',
#  'خریدار',
#  'خریداران',
#  'خریختخریخت',
#  'خریدارو',
#  'ﻻزم',
#  'خریخت',
#  'در',
#  'به',
#  'ریال',
#  'شرکت',
#  'مبلغ',
#  'از',
#  'آسپ',
#  'سرمایه',
#  'با',
#  'پروژه',
#  'قرارداد',
#  'افزایش',
#  'میلیون',
#  'ماهه',
#  'شده',
#  'میلیارد',
#  'مورخ',
#  'است',
#  'نقدی',
#  'مجمع',
#  'محل',
#  'استآسپ',
#  'آورده',
#  'مجوز',
#  'های',
#  'فروش',
#  'مطالبات',
#  'شماره',
#  'عمومی',
#  'محقق',
#  'به',
#  'از',
#  'در',
#  'ریال',
#  'مزایده',
#  'آبین',
#  'قم',
#  'شرکت',
#  'آبشيرين',
#  'صنعت',
#  'محل',
#  'با',
#  'فروش',
#  'های',
#  'قدیم',
#  'کاشان',
#  'هیئت',
#  'کرده',
#  'میلیارد',
#  'گزارش',
#  'ثبتی',
#  'پایه',
#  'بخشی',
#  'سرمایه',
#  'فرعی',
#  'ارزیابی',
#  'منظور',
#  'شماره',
#  'پلاک',
#  'کیلومتر',
#  'به',
#  'آرمان',
#  'در',
#  'منظور',
#  'ریال',
#  'از',
#  'با',
#  'ریالی',
#  'سرمایه',
#  'هیئت',
#  'تعلیق',
#  'مالي',
#  'توجه',
#  'تاریخ',
#  'ماده',
#  'ماهه',
#  'بیمه',
#  'مبلغ',
#  'سود',
#  'که',
#  'خیلی',
#  'می',
#  'مدیرة',
#  'معاملاتی',
#  'معاملات',
#  'کرده',
#  'انجام',
#  'هر',
#  'نیست',
#  'ایران',
#  'آريان',
#  'کرد',
#  'ریال',
#  'مجمع',
#  'در',
#  'پارس',
#  'با',
#  'سرمايه',
#  'نماد',
#  'تقسیم',
#  'گذاري',
#  'شرکت',
#  'خریداد',
#  'خریختخریخت',
#  'خرید',
#  'خریدpo',
#  'خریدا',
#  'ﻻزم',
#  'خریداري',
#  'خریدار',
#  'خریداران',
#  'خریدارو',
#  'خريدبخشي',
#  'خریداری',
#  'خریداقا',
#  'خریدثاخت',
#  'خریدخدمات',
#  'خریخت',
#  'خروجی',
#  'خريداري',
#  'در',
#  'به',
#  'ریال',
#  'میلیارد',
#  'عرضه',
#  'با',
#  'آریا',
#  'فروش',
#  'شرکت',
#  'ساسول',
#  'این',
#  'است',
#  'اولیه',
#  'های',
#  'نرخ',
#  'ماهه',
#  'سهام',
#  'هم',
#  'هفته',
#  'سبک',
#  'سود',
#  'سنگین',
#  'شود',
#  'ریالی',
#  'می',
#  'شده',
#  'عدد',
#  'فردا',
#  'بود',
#  'سرمایه',
#  'در',
#  'به',
#  'سود',
#  'آریان',
#  'سال',
#  'پارس',
#  'قبل',
#  'ریالی',
#  'شرکت',
#  'است',
#  'خيابان',
#  'ماهه',
#  'شده',
#  'عادی',
#  'داشت',
#  'مجمع',
#  'مي',
#  'با',
#  'گذاري',
#  'تحقق',
#  'را',
#  'شرکتهاي',
#  'ریال',
#  'سهام',
#  'سالیانه',
#  'عمومی',
#  'از',
#  'سامانه',
#  'روز',
#  'مالي',
#  'در',
#  'است',
#  'میلیارد',
#  'به',
#  'آسیا',
#  'از',
#  'با',
#  'بیمه',
#  'شرکت',
#  'ریالی',
#  'سود',
#  'ریال',
#  'را',
#  'که',
#  'ماهه',
#  'مالی',
#  'سرمایه',
#  'های',
#  'این',
#  'دارد',
#  'کرده',
#  'واحد',
#  'ارزیابی',
#  'محقق',
#  'املاک',
#  'خالص',
#  'تجدید',
#  'شماره',
#  'شده',
#  'اطلاع',
#  'از',
#  'به',
#  'سرمایه',
#  'انباشته',
#  'هیئت',
#  'ریال',
#  'سود',
#  'منظور',
#  'شده',
#  'مبلغ',
#  'در',
#  'محل',
#  'نقدينگي',
#  'نقدی',
#  'افزایش',
#  'معافيت',
#  'مالي',
#  'اصلاح',
#  'که',
#  'مزاياي',
#  'مالياتي',
#  'مطالبات',
#  'حال',
#  'جلوگيري',
#  'رسیده',
#  'آورده',
#  'مدیره',
#  'حسابرس',
#  'مدیرة',
#  'استفاده',
#  'میلیارد',
#  'در',
#  'ریال',
#  'به',
#  'است',
#  'با',
#  'ماهه',
#  'سود',
#  'این',
#  'بوده',
#  'درامد',
#  'ریالی',
#  'آپ',
#  'سهم',
#  'رسیده',
#  'از',
#  'شرکت',
#  'عدد',
#  'شده',
#  'که',
#  'داشته',
#  'عملیاتی',
#  'فروش',
#  'های',
#  'خالص',
#  'جمع',
#  'ماه',
#  'کرد',
#  'کمی',
#  'رشد',
#  'بهمن',
#  'روز',
#  'خرید',
#  'شنبه',
#  'از',
#  'قیمت',
#  'سفارش',
#  'فروش',
#  'حداکثر',
#  'است',
#  'آکنتور',
#  'میگیرد',
#  'تا',
#  'سهم',
#  'سه',
#  'خریداری',
#  'خریداري',
#  'خریداقا',
#  'خریختخریخت',
#  'خریدارو',
#  'خریداران',
#  'خریدار',
#  'خریداد',
#  'خریدا',
#  'خریدثاخت',
#  'خریدpo',
#  'خريدبخشي',
#  'خریخت',
#  'خریدسود',
#  'خردمندان',
#  'به',
#  'در',
#  'زیان',
#  'آینده',
#  'سرمایه',
#  'ریال',
#  'صنعتي',
#  'افزایش',
#  'سازان',
#  'آينده',
#  'بهشت',
#  'پارس',
#  'با',
#  'تعلیق',
#  'نماد',
#  'تاریخ',
#  'فرابورس',
#  'ایران',
#  'دستورالعمل',
#  'بازرگاني',
#  'وضعیت',
#  'توجه',
#  'ماهه',
#  'ماده',
#  'استناد',
#  'گرددآینده',
#  'سهامداران',
#  'بند',
#  'مي',
#  'می',
#  'به',
#  'در',
#  'العاده',
#  'بطور',
#  'فوق',
#  'چهار',
#  'مجمع',
#  'براساس',
#  'کار',
#  'جالب',
#  'سامانه',
#  'خلاصه',
#  'خيابان',
#  'منتشره',
#  'ورزشي',
#  'سالن',
#  'امور',
#  'پارک',
#  'کدال',
#  'سهام',
#  'صاحبان',
#  'تاریخ',
#  'اجتماعي',
#  'ساعت',
#  'گردید',
#  'کگهر',
#  'وزارت',
#  'روز',
#  'حد',
#  'مجموعه',
#  'در',
#  'به',
#  'ریال',
#  'از',
#  'مبلغ',
#  'شرکت',
#  'سرمایه',
#  'مجمع',
#  'سود',
#  'افزایش',
#  'اتکام',
#  'مورخ',
#  'محل',
#  'عمومی',
#  'سهم',
#  'میلیون',
#  'کارمزد',
#  'ماهه',
#  'ثبت',
#  'که',
#  'است',
#  'انباشته',
#  'جلسه',
#  'این',
#  'تاریخ',
#  'منظور',
#  'ساعت',
#  'روز',
#  'اندوخته',
#  'ها',
#  'در',
#  'به',
#  'ریال',
#  'از',
#  'سود',
#  'افزایش',
#  'سرمایه',
#  'مبلغ',
#  'است',
#  'با',
#  'شرکت',
#  'اتکای',
#  'ماهه',
#  'میلیون',
#  'محل',
#  'میلیارد',
#  'مجمع',
#  'خيابان',
#  'جلسه',
#  'خالص',
#  'ریالی',
#  'اندوخته',
#  'که',
#  'سال',
#  'محقق',
#  'کرده',
#  'مورخ',
#  'انباشته',
#  'این',
#  'ثبت',
#  'در',
#  'ریال',
#  'میلیارد',
#  'به',
#  'فروش',
#  'است',
#  'ماهه',
#  'با',
#  'بوده',
#  'داشته',
#  'درامد',
#  'کمی',
#  'افت',
#  'شرکت',
#  'ریالی',
#  'اخابر',
#  'از',
#  'که',
#  'شد',
#  'این',
#  'تلفیقی',
#  'جمع',
#  'سود',
#  'مواجه',
#  'استاخابر',
#  'کرده',
#  'فروردین',
#  'را',
#  'عدد',
#  'نظر',
#  'خرد',
#  'معاملات',
#  'ارزش',
#  'میانگین',
#  'ابتدای',
#  'از',
#  'هفتگی',
#  'در',
#  'سال',
#  'اختصاصی',
#  'سوم',
#  'به',
#  'کار',
#  'تومان',
#  'خود',
#  'داد',
#  'با',
#  'میلیارد',
#  'هفته',
#  'دلاری',
#  'پایان',
#  'بهمن',
#  'خریداد',
#  'خريداري',
#  'خريدبخشي',
#  'خریخت',
#  'خریختخریخت',
#  'خرید',
#  'خریدpo',
#  'خریدا',
#  'میلیارد',
#  'ریال',
#  'سال',
#  'است',
#  'بینی',
#  'در',
#  'پیش',
#  'بودجه',
#  'عربستان',
#  'درآمد',
#  'شده',
#  'دلار',
#  'تولید',
#  'نفت',
#  'از',
#  'می',
#  'برآورد',
#  'کسری',
#  'یا',
#  'با',
#  'ناخالص',
#  'به',
#  'سعودی',
#  'داخلی',
#  'شود',
#  'هزینه',
#  'کاهش',
#  'آینده',
#  'زده',
#  'که',
#  'تن',
#  'عرضه',
#  'هزار',
#  'رشد',
#  'میلیارد',
#  'تقاضا',
#  'تومان',
#  'قیمت',
#  'نسبت',
#  'تا',
#  'نرخ',
#  'درصدی',
#  'رقابت',
#  'معامله',
#  'قیمتی',
#  'سقف',
#  'حدود',
#  'به',
#  'برای',
#  'ها',
#  'فولاد',
#  'شمش',
#  'بورس',
#  'پایهارزش',
#  'کالا',
#  'فملی',
#  'فخوز',
#  'مسقیمت',
#  'ارفع',
#  'آرمون',
#  'ریال',
#  'فروش',
#  'میلیارد',
#  'در',
#  'است',
#  'با',
#  'نرخ',
#  'ریالی',
#  'به',
#  'ماهه',
#  'تن',
#  'بوده',
#  'هزار',
#  'کرده',
#  'صادرات',
#  'سود',
#  'از',
#  'بود',
#  'شده',
#  'داخلی',
#  'مواجه',
#  'سهم',
#  'خوبی',
#  'ارفع',
#  'را',
#  'خوب',
#  'صادراتی',
#  'فروخته',
#  'که',
#  'عدد',
#  'به',
#  'از',
#  'منظور',
#  'ریال',
#  'هیئت',
#  'سرمایه',
#  'سود',
#  'انباشته',
#  'مبلغ',
#  'محل',
#  'گزارش',
#  'مالي',
#  'حسابرس',
#  'ساختار',
#  'بهبود',
#  'در',
#  'مدیره',
#  'مدیرة',
#  'شده',
#  'که',
#  'رسیده',
#  'بازرس',
#  'افزایش',
#  'قانونی',
#  'توجیهی',
#  'پیشنهادافزایش',
#  'اظهارنظر',
#  'جهت',
#  'تاریخ',
#  'اسیا',
#  'از',
#  'ریال',
#  'زیر',
#  'مجموعه',
#  'تقسیم',
#  'های',
#  'والبر',
#  'کرد',
#  'اعتلا',
#  'خریدا',
#  'خريدبخشي',
#  'خریخت',
#  'خریختخریخت',
#  'خرید',
#  'خریدpo',
#  'ﻻزم',
#  'خریداد',
#  'خريداري',
#  'خریداران',
#  'خریدارو',
#  'خریداري',
#  'خریداری',
#  'خریداقا',
#  'خریدثاخت',
#  'خریدخدمات',
#  'خریدار',
#  'خريدار',
#  'خريداران',
#  'خریدش',
#  'خردادماه',
#  'در',
#  'سرمایه',
#  'ریال',
#  'سود',
#  'به',
#  'از',
#  'گذاری',
#  'شرکت',
#  'میلیارد',
#  'است',
#  'ها',
#  'میلیون',
#  'فروش',
#  'استاعتلا',
#  'که',
#  'مبلغ',
#  'اعتلا',
#  'با',
#  'افزایش',
#  'محل',
#  'شده',
#  'را',
#  'مجمع',
#  'کرده',
#  'مطالبات',
#  'گزارش',
#  'داشته',
#  'آورده',
#  'ریالی',
#  'نقدی',
#  'در',
#  'ریال',
#  'میلیارد',
#  'به',
#  'از',
#  'شرکت',
#  'درامد',
#  'است',
#  'با',
#  'که',
#  'خيابان',
#  'سود',
#  'ماهه',
#  'این',
#  'مجمع',
#  'شده',
#  'ریالی',
#  'افرا',
#  'سال',
#  'جمع',
#  'مورخ',
#  'قبل',
#  'فروش',
#  'استافرا',
#  'کرده',
#  'داشته',
#  'کل',
#  'جلسه',
#  'بوده',
#  'سهم',
#  'در',
#  'میلیارد',
#  'به',
#  'ریال',
#  'است',
#  'فروش',
#  'با',
#  'ریالی',
#  'ماهه',
#  'درامد',
#  'افق',
#  'سود',
#  'کوروش',
#  'سهم',
#  'از',
#  'شرکت',
#  'رسیده',
#  'این',
#  'های',
#  'بود',
#  'رشد',
#  'شده',
#  'سال',
#  'عدد',
#  'که',
#  'گزارش',
#  'بوده',
#  'خوب',
#  'ماه',
#  'را',
#  'افق',
#  'نماد',
#  'فروشگاه',
#  'امروز',
#  'معاملات',
#  'شنبه',
#  'تاييد',
#  'زنجيره',
#  'شركت',
#  'معاملاتي',
#  'نگرديد',
#  'سه',
#  'هاي',
#  'كوروش',
#  'اي',
#  'مورخ',
#  'كليه',
#  'خرید',
#  'خریخت',
#  'خریختخریخت',
#  'خريدبخشي',
#  'ﻻزم',
#  'خريداران',
#  'خریدpo',
#  'خریدا',
#  'خریداد',
#  'خریدار',
#  'خریداران',
#  'خریدارو',
#  'خريداري',
#  'بیمه',
#  'درصدی',
#  'البرز',
#  'می',
#  'شود',
#  'بلوک',
#  'در',
#  'سهام',
#  'توسط',
#  'ای',
#  'اتکایی',
#  'اتکام',
#  'عرضه',
#  'دولت',
#  'ایبنا',
#  'واگذار',
#  'شرکت',
#  'خصوصی',
#  'سازی',
#  'امین',
#  'سازمان',
#  'خریدخدمات',
#  'خریدارو',
#  'خرمشهرکوچه',
#  'خریداري',
#  'خریداری',
#  'خریداقا',
#  'خریدثاخت',
#  'خرنیگ',
#  'خرمشهر',
#  'ریال',
#  'شراز',
#  'البرز',
#  'شاوان',
#  'قیمت',
#  'است',
#  'بلوکی',
#  'بیمه',
#  'خریدثاخت',
#  'خریداد',
#  'خریدسود',
#  'خریخت',
#  'خریختخریخت',
#  'خرید',
#  'خریدpo',
#  'خریدا',
#  'خریدار',
#  'خریداقا',
#  'خریداران',
#  'خریدارو',
#  'خريدبخشي',
#  'خریداری',
#  'خریدخدمات',
#  'خریداري',
#  'ﻻزم',
#  'خریدش',
#  'خرمشهر',
#  'خردادماه',
#  'خردادومعادن',
#  'خردافزایش',
#  'در',
#  'از',
#  'به',
#  'مالی',
#  'البرز',
#  'شرکت',
#  'با',
#  'است',
#  'بازار',
#  'سهم',
#  'سازی',
#  'های',
#  'بیمه',
#  'ماهه',
#  'ریال',
#  'افزايش',
#  'عرضه',
#  'گزارش',
#  'تاریخ',
#  'سود',
#  'تا',
#  'طي',
#  'که',
#  'قبلی',
#  'صورت',
#  'دوره',
#  'منتهی',
#  'سرمايه',
#  'گزارشگری',
#  'مقطع',
#  'ریال',
#  'در',
#  'میلیارد',
#  'است',
#  'به',
#  'سرمایه',
#  'امید',
#  'درامد',
#  'فروش',
#  'خوبی',
#  'از',
#  'زده',
#  'عدد',
#  'سال',
#  'شده',
#  'سود',
#  'ماه',
#  'را',
#  'ماهه',
#  'مالی',
#  'شرکت',
#  'مبلغ',
#  'کرده',
#  'این',
#  'که',
#  'اولین',
#  'با',
#  'گزارش',
#  'داشته',
#  'افزایش',
#  'سود',
#  'ریال',
#  'میلیارد',
#  'ریالی',
#  'در',
#  'است',
#  'ماهه',
#  'با',
#  'محقق',
#  'کرده',
#  'به',
#  'درامد',
#  'غیرعملیاتی',
#  'عملیاتی',
#  'بود',
#  'موفق',
#  'خالص',
#  'هر',
#  'را',
#  'حالا',
#  'رسیده',
#  'شده',
#  'تحقق',
#  'سهم',
#  'ايران',
#  'بورس',
#  'که',
#  'انرژي',
#  'دارد',
#  'خریداران',
#  'در',
#  'به',
#  'انرژی',
#  'بورس',
#  'با',
#  'اوراق',
#  'ریال',
#  'بهادار',
#  'ایران',
#  'از',
#  ...]

# %%
# Let's aggregate this list and identify the most common words
Counter(words).most_common()
# Out:
# [('در', 897),
#  ('به', 855),
#  ('است', 791),
#  ('ریال', 780),
#  ('از', 715),
#  ('با', 697),
#  ('سود', 641),
#  ('میلیارد', 604),
#  ('ماهه', 568),
#  ('شرکت', 555),
#  ('فروش', 538),
#  ('این', 511),
#  ('که', 483),
#  ('شده', 467),
#  ('کرده', 462),
#  ('را', 455),
#  ('سهم', 439),
#  ('ریالی', 428),
#  ('داشته', 394),
#  ('بوده', 363),
#  ('بود', 316),
#  ('سال', 294),
#  ('سرمایه', 262),
#  ('های', 256),
#  ('محقق', 243),
#  ('رسیده', 227),
#  ('نرخ', 208),
#  ('عدد', 206),
#  ('مواجه', 197),
#  ('گزارش', 192),
#  ('می', 186),
#  ('خوبی', 173),
#  ('خریدار', 167),
#  ('عملیاتی', 167),
#  ('خرید', 163),
#  ('خریدا', 162),
#  ('افزایش', 159),
#  ('خریداد', 158),
#  ('مبلغ', 158),
#  ('ماه', 157),
#  ('زده', 157),
#  ('قبل', 156),
#  ('خریدpo', 155),
#  ('خریداران', 149),
#  ('خریختخریخت', 147),
#  ('ها', 145),
#  ('خریدارو', 137),
#  ('مجمع', 137),
#  ('خوب', 136),
#  ('خریخت', 132),
#  ('درامد', 129),
#  ('خریداري', 125),
#  ('زیان', 124),
#  ('خالص', 123),
#  ('خریداری', 117),
#  ('خريدبخشي', 116),
#  ('میلیون', 107),
#  ('مالی', 107),
#  ('محل', 103),
#  ('خريداري', 103),
#  ('تا', 103),
#  ('هم', 101),
#  ('رشد', 99),
#  ('روز', 98),
#  ('گذاری', 98),
#  ('هر', 96),
#  ('خریداقا', 92),
#  ('سهام', 90),
#  ('مدت', 90),
#  ('مورخ', 83),
#  ('جمع', 83),
#  ('نیز', 82),
#  ('عرضه', 81),
#  ('تاریخ', 78),
#  ('برای', 78),
#  ('مشابه', 78),
#  ('شناسایی', 77),
#  ('خریدثاخت', 74),
#  ('بازار', 68),
#  ('خريداران', 67),
#  ('سازی', 67),
#  ('شد', 65),
#  ('شود', 64),
#  ('خواهد', 64),
#  ('تن', 62),
#  ('خریدخدمات', 60),
#  ('بانک', 59),
#  ('کمی', 58),
#  ('خريدار', 58),
#  ('منظور', 57),
#  ('کرد', 56),
#  ('عمومی', 54),
#  ('داشت', 54),
#  ('ﻻزم', 53),
#  ('مجموعه', 53),
#  ('نماد', 52),
#  ('مهر', 52),
#  ('جلسه', 51),
#  ('ازای', 51),
#  ('قیمت', 50),
#  ('سرمايه', 49),
#  ('صورت', 46),
#  ('بورس', 46),
#  ('تهران', 46),
#  ('خردمندان', 45),
#  ('خردافزایش', 45),
#  ('ساعت', 44),
#  ('مي', 43),
#  ('تومان', 43),
#  ('زیر', 43),
#  ('بلوک', 43),
#  ('نسبت', 42),
#  ('خریدسود', 42),
#  ('ثبت', 42),
#  ('هیئت', 41),
#  ('هزار', 41),
#  ('دارد', 40),
#  ('درصد', 39),
#  ('فولاد', 39),
#  ('افت', 39),
#  ('ارزش', 38),
#  ('خردادومعادن', 38),
#  ('خيابان', 37),
#  ('خريد', 37),
#  ('تقسیم', 36),
#  ('سهامداران', 36),
#  ('تولید', 36),
#  ('حال', 35),
#  ('توجه', 35),
#  ('گذاري', 35),
#  ('ولی', 34),
#  ('باشد', 34),
#  ('ایران', 33),
#  ('حدود', 33),
#  ('اوراق', 33),
#  ('نظر', 32),
#  ('توسط', 32),
#  ('خردادماه', 31),
#  ('بر', 31),
#  ('دی', 31),
#  ('هاي', 30),
#  ('یک', 30),
#  ('خروجی', 29),
#  ('فروردین', 29),
#  ('بهادار', 29),
#  ('شفاف', 29),
#  ('انجام', 28),
#  ('انباشته', 28),
#  ('مدیره', 28),
#  ('خریدش', 28),
#  ('قرارداد', 27),
#  ('معاملات', 27),
#  ('میانگین', 27),
#  ('یا', 27),
#  ('آن', 27),
#  ('برگزار', 27),
#  ('خرده', 27),
#  ('شنبه', 26),
#  ('رساند', 26),
#  ('اولیه', 25),
#  ('خرسی', 25),
#  ('ريال', 25),
#  ('اسفند', 25),
#  ('فوق', 24),
#  ('هزینه', 24),
#  ('بهتر', 24),
#  ('بخش', 24),
#  ('پروژه', 23),
#  ('مطالبات', 23),
#  ('ماده', 23),
#  ('خرم', 23),
#  ('نقدی', 22),
#  ('مالي', 22),
#  ('بیمه', 22),
#  ('پارس', 22),
#  ('شمش', 22),
#  ('آورده', 21),
#  ('مزایده', 21),
#  ('معاملاتی', 21),
#  ('اعلام', 21),
#  ('تعداد', 21),
#  ('رعایت', 21),
#  ('پتروشیمی', 21),
#  ('خودرو', 21),
#  ('تجدید', 20),
#  ('شركت', 20),
#  ('گروه', 20),
#  ('توسعه', 20),
#  ('پرتفوی', 19),
#  ('شماره', 19),
#  ('ارزیابی', 19),
#  ('فرابورس', 19),
#  ('اول', 19),
#  ('تامین', 19),
#  ('خیلی', 18),
#  ('بهمن', 18),
#  ('معامله', 18),
#  ('جهت', 18),
#  ('فارس', 18),
#  ('بیش', 18),
#  ('عدم', 18),
#  ('عملکرد', 18),
#  ('خروجي', 18),
#  ('مورد', 18),
#  ('تسهیلات', 18),
#  ('تحلیلی', 17),
#  ('خود', 17),
#  ('سازمان', 17),
#  ('خرمشهر', 17),
#  ('میگردد', 17),
#  ('واگذاری', 17),
#  ('درمحل', 17),
#  ('خریدفروش', 17),
#  ('ناشر', 17),
#  ('خصوص', 17),
#  ('زد', 17),
#  ('کاهش', 16),
#  ('افزايش', 16),
#  ('شهریور', 16),
#  ('دارایی', 16),
#  ('جمعا', 16),
#  ('صنعت', 15),
#  ('پلاک', 15),
#  ('اطلاع', 15),
#  ('نفت', 15),
#  ('خرنیگ', 15),
#  ('ابان', 15),
#  ('پس', 15),
#  ('مذکور', 15),
#  ('خردادفاذر', 15),
#  ('تسویه', 15),
#  ('دو', 15),
#  ('بعد', 14),
#  ('تحقق', 14),
#  ('فملی', 14),
#  ('خرمدره', 14),
#  ('اجرایی', 14),
#  ('اطلاعات', 14),
#  ('باید', 14),
#  ('وساخت', 14),
#  ('خساپا', 14),
#  ('مثبت', 14),
#  ('پارسان', 13),
#  ('مدیرة', 13),
#  ('حسابرس', 13),
#  ('دستورالعمل', 13),
#  ('فخوز', 13),
#  ('قرار', 13),
#  ('گویا', 13),
#  ('فروشد', 13),
#  ('وغدیر', 13),
#  ('تیر', 13),
#  ('کمتر', 13),
#  ('تراز', 13),
#  ('وتجارت', 13),
#  ('مهم', 13),
#  ('حاضر', 12),
#  ('درصدی', 12),
#  ('مجوز', 12),
#  ('تعلیق', 12),
#  ('کالا', 12),
#  ('صادرات', 12),
#  ('فروخته', 12),
#  ('امروز', 12),
#  ('ايران', 12),
#  ('آهن', 12),
#  ('ساختمان', 12),
#  ('رسید', 12),
#  ('نامه', 12),
#  ('اصفهان', 12),
#  ('تصویب', 12),
#  ('ومعادن', 12),
#  ('نقد', 12),
#  ('مربوط', 12),
#  ('مس', 12),
#  ('خروج', 12),
#  ('محدوده', 11),
#  ('واحد', 11),
#  ('حداکثر', 11),
#  ('گردید', 11),
#  ('کل', 11),
#  ('بررسی', 11),
#  ('مرداد', 11),
#  ('اين', 11),
#  ('اذر', 11),
#  ('تاپیکو', 11),
#  ('تمام', 11),
#  ('آگهی', 11),
#  ('صنعتی', 11),
#  ('ملی', 11),
#  ('صادر', 11),
#  ('معادل', 11),
#  ('ای', 10),
#  ('ارائه', 10),
#  ('هفته', 10),
#  ('سه', 10),
#  ('کار', 10),
#  ('داد', 10),
#  ('پذیرش', 10),
#  ('بسیار', 10),
#  ('گردد', 10),
#  ('تغییر', 10),
#  ('داده', 10),
#  ('دستگاه', 10),
#  ('نوین', 10),
#  ('ملت', 10),
#  ('همچنین', 10),
#  ('روی', 10),
#  ('منفی', 10),
#  ('سپرده', 10),
#  ('پرداختی', 10),
#  ('کنسانتره', 10),
#  ('کارخانه', 10),
#  ('بیشتر', 10),
#  ('کگل', 10),
#  ('لازم', 9),
#  ('پارسیس', 9),
#  ('قابل', 9),
#  ('استفاده', 9),
#  ('صنعتي', 9),
#  ('معاملاتي', 9),
#  ('واگذار', 9),
#  ('غیرعملیاتی', 9),
#  ('وبانک', 9),
#  ('ميليون', 9),
#  ('طی', 9),
#  ('وپاسار', 9),
#  ('گذشته', 9),
#  ('البته', 9),
#  ('مازاد', 9),
#  ('متعلق', 9),
#  ('کم', 9),
#  ('کشور', 9),
#  ('مقدار', 9),
#  ('اردیبهشت', 9),
#  ('خبرخوب', 9),
#  ('منظم', 9),
#  ('وامید', 9),
#  ('توقف', 9),
#  ('پایه', 8),
#  ('اصلاح', 8),
#  ('آینده', 8),
#  ('چهار', 8),
#  ('جالب', 8),
#  ('داخلی', 8),
#  ('صادراتی', 8),
#  ('خرمشهرکوچه', 8),
#  ('دوره', 8),
#  ('اوره', 8),
#  ('خبر', 8),
#  ('محصولات', 8),
#  ('تجارت', 8),
#  ('برق', 8),
#  ('بهای', 8),
#  ('دلیل', 8),
#  ('هلدینگ', 8),
#  ('موضوع', 8),
#  ('کرمان', 8),
#  ('نحوه', 8),
#  ('شهيد', 8),
#  ('ونوین', 8),
#  ('منتشر', 8),
#  ('همراه', 8),
#  ('وپارس', 8),
#  ('موجودی', 8),
#  ('درج', 8),
#  ('سیمان', 8),
#  ('سيمان', 8),
#  ('خاصی', 8),
#  ('نوری', 8),
#  ('سنگ', 8),
#  ('آذر', 7),
#  ('ان', 7),
#  ('فردا', 7),
#  ('سالیانه', 7),
#  ('سامانه', 7),
#  ('العاده', 7),
#  ('اندوخته', 7),
#  ('تلفیقی', 7),
#  ('پیش', 7),
#  ('دلار', 7),
#  ('البرز', 7),
#  ('مناقصه', 7),
#  ('شدن', 7),
#  ('واقع', 7),
#  ('اگر', 7),
#  ('مجموع', 7),
#  ('افشای', 7),
#  ('قانون', 7),
#  ('تیپیکو', 7),
#  ('دریافت', 7),
#  ('صنایع', 7),
#  ('قيمت', 7),
#  ('جاده', 7),
#  ('زمین', 7),
#  ('اقتصاد', 7),
#  ('بدهی', 7),
#  ('طریق', 7),
#  ('خرندکماسه', 7),
#  ('موجود', 7),
#  ('ورنا', 7),
#  ('سایپا', 7),
#  ('خرند', 7),
#  ('میکند', 7),
#  ('جدید', 7),
#  ('مجامع', 7),
#  ('متوقف', 7),
#  ('تاريخ', 7),
#  ('نزد', 7),
#  ('فوری', 7),
#  ('چهارشنبه', 7),
#  ('امسال', 7),
#  ('شرایط', 7),
#  ('نکته', 7),
#  ('خوزستان', 7),
#  ('شکر', 7),
#  ('چدن', 7),
#  ('پارسیان', 7),
#  ('تاصیکو', 6),
#  ('pnav', 6),
#  ('روزرسانی', 6),
#  ('مالکیت', 6),
#  ('استکانال', 6),
#  ('رسانی', 6),
#  ('بخشی', 6),
#  ('براساس', 6),
#  ('وزارت', 6),
#  ('حد', 6),
#  ('درآمد', 6),
#  ('رقابت', 6),
#  ('امید', 6),
#  ('گرفت', 6),
#  ('اضافه', 6),
#  ('تومانی', 6),
#  ('سهمی', 6),
#  ('پتروشيمي', 6),
#  ('کنفرانس', 6),
#  ('برخی', 6),
#  ('نداشته', 6),
#  ('نمادهای', 6),
#  ('بسته', 6),
#  ('گاز', 6),
#  ('بابت', 6),
#  ('تنوین', 6),
#  ('عام', 6),
#  ('عمده', 6),
#  ('خریدقطعات', 6),
#  ('خریدفوری', 6),
#  ('گفت', 6),
#  ('یکجا', 6),
#  ('پنج', 6),
#  ('ثنوسا', 6),
#  ('پرداخت', 6),
#  ('جم', 6),
#  ('ما', 6),
#  ('محصول', 6),
#  ('خرداد', 6),
#  ('کشت', 6),
#  ('نهایت', 6),
#  ('مبارکه', 6),
#  ('حمل', 6),
#  ('پیشرفت', 6),
#  ('تجهیزات', 6),
#  ('خدمات', 6),
#  ('نزدیک', 6),
#  ('مطابق', 6),
#  ('ظرفیت', 6),
#  ('علت', 6),
#  ('ادامه', 6),
#  ('ذوب', 6),
#  ('خردادعدد', 6),
#  ('محترم', 6),
#  ('کوثر', 6),
#  ('ساوه', 6),
#  ('وصندوق', 6),
#  ('چهارم', 6),
#  ('همچنان', 6),
#  ('شیران', 6),
#  ('صنايع', 6),
#  ('شستا', 6),
#  ('ملک', 6),
#  ('سهامدار', 6),
#  ('صبا', 6),
#  ('پترول', 6),
#  ('ماهانه', 6),
#  ('nav', 5),
#  ('بورسی', 5),
#  ('نیست', 5),
#  ('آریا', 5),
#  ('سازان', 5),
#  ('وضعیت', 5),
#  ('ابتدای', 5),
#  ('تقاضا', 5),
#  ('ساختار', 5),
#  ('بهبود', 5),
#  ('قانونی', 5),
#  ('توجیهی', 5),
#  ('پیشنهادافزایش', 5),
#  ('والبر', 5),
#  ('قرن', 5),
#  ('برنده', 5),
#  ('بترانس', 5),
#  ('مهلت', 5),
#  ('دیگر', 5),
#  ('مسیر', 5),
#  ('طبقه', 5),
#  ('ميدان', 5),
#  ('هایی', 5),
#  ('طرح', 5),
#  ('خسته', 5),
#  ('داریم', 5),
#  ('رمپنا', 5),
#  ('ورود', 5),
#  ('فن', 5),
#  ('شفن', 5),
#  ('وپترو', 5),
#  ('خبرخوبی', 5),
#  ('شهر', 5),
#  ('خسرو', 5),
#  ('میشود', 5),
#  ('راستای', 5),
#  ('یکشنبه', 5),
#  ('کاری', 5),
#  ('مجتمع', 5),
#  ('مشارکت', 5),
#  ('بالاتر', 5),
#  ('فقط', 5),
#  ('پیرو', 5),
#  ('مدیرعامل', 5),
#  ('آماده', 5),
#  ('رفع', 5),
#  ('میزان', 5),
#  ('اهمیت', 5),
#  ('منابع', 5),
#  ('ندارد', 5),
#  ('خپارس', 5),
#  ('اگهی', 5),
#  ('خساپاخساپا', 5),
#  ('واگذاري', 5),
#  ('خط', 5),
#  ('حوالی', 5),
#  ('پخش', 5),
#  ('خساپاستوساپا', 5),
#  ('بهره', 5),
#  ('برداری', 5),
#  ('آوا', 5),
#  ('راهی', 5),
#  ('موثر', 5),
#  ('زکوثر', 5),
#  ('کد', 5),
#  ('هستند', 5),
#  ('شگویا', 5),
#  ('نشده', 5),
#  ('سایر', 5),
#  ('ده', 5),
#  ('نبش', 5),
#  ('میدهد', 5),
#  ('فرآورده', 5),
#  ('استحضار', 5),
#  ('کانال', 5),
#  ('وبشهر', 5),
#  ('برنامه', 5),
#  ('توافق', 5),
#  ('فروی', 5),
#  ('کاما', 5),
#  ('گندله', 5),
#  ('معادن', 5),
#  ('وصنعت', 5),
#  ('وسینا', 5),
#  ('توضیح', 4),
#  ('سنگین', 4),
#  ('عادی', 4),
#  ('املاک', 4),
#  ('بطور', 4),
#  ('سالن', 4),
#  ('کدال', 4),
#  ('صاحبان', 4),
#  ('کگهر', 4),
#  ('پایان', 4),
#  ('بودجه', 4),
#  ('برآورد', 4),
#  ('آرمون', 4),
#  ('بازرس', 4),
#  ('دولت', 4),
#  ('گزارشگری', 4),
#  ('اولین', 4),
#  ('خلیج', 4),
#  ('متانول', 4),
#  ('سطح', 4),
#  ('شیمی', 4),
#  ('راه', 4),
#  ('شرقي', 4),
#  ('صورتی', 4),
#  ('پکرمان', 4),
#  ('نیروگاه', 4),
#  ('سامان', 4),
#  ('اعطای', 4),
#  ('الزامات', 4),
#  ('ظرف', 4),
#  ('بفجر', 4),
#  ('بلوار', 4),
#  ('رتاپ', 4),
#  ('بودن', 4),
#  ('کلیه', 4),
#  ('كه', 4),
#  ('انتقال', 4),
#  ('غشهداب', 4),
#  ('ايرانيان', 4),
#  ('گردیده', 4),
#  ('دوم', 4),
#  ('دماوند', 4),
#  ('نویسی', 4),
#  ('اقدام', 4),
#  ('شیر', 4),
#  ('دهی', 4),
#  ('نصاب', 4),
#  ('مشهد', 4),
#  ('مفاد', 4),
#  ('سینا', 4),
#  ('درخواست', 4),
#  ('خساپاشرکت', 4),
#  ('احداث', 4),
#  ('توثیق', 4),
#  ('اتیلن', 4),
#  ('پلی', 4),
#  ('ابهامات', 4),
#  ('ادغام', 4),
#  ('سپه', 4),
#  ('دوباره', 4),
#  ('شیراز', 4),
#  ('خراسان', 4),
#  ('خزامیا', 4),
#  ('خزر', 4),
#  ('مطرح', 4),
#  ('وساپا', 4),
#  ('شنیده', 4),
#  ('یافته', 4),
#  ('تعدیل', 4),
#  ('بازگشایی', 4),
#  ('خگستر', 4),
#  ('نداشت', 4),
#  ('مشتری', 4),
#  ('دارو', 4),
#  ('هجرت', 4),
#  ('دفارا', 4),
#  ('رخ', 4),
#  ('روزهای', 4),
#  ('کاوه', 4),
#  ('رازی', 4),
#  ('مدیریت', 4),
#  ('فاز', 4),
#  ('آباد', 4),
#  ('معدن', 4),
#  ('سرب', 4),
#  ('گوهران', 4),
#  ('زاگرس', 4),
#  ('توليد', 4),
#  ('خواهند', 4),
#  ('بالای', 4),
#  ('اما', 4),
#  ('آخرین', 4),
#  ('گام', 4),
#  ('قطعی', 4),
#  ('شاید', 4),
#  ('سبهان', 4),
#  ('کيلومتر', 4),
#  ('خشان', 4),
#  ('استراتوس', 4),
#  ('کوچه', 4),
#  ('نموده', 4),
#  ('مصرف', 4),
#  ('رکورد', 4),
#  ('تابستان', 4),
#  ('فصلی', 4),
#  ('ذاتی', 4),
#  ('شپدیس', 4),
#  ('شپنا', 4),
#  ('حراج', 4),
#  ('تندگویان', 4),
#  ('کند', 4),
#  ('اخیر', 4),
#  ('یعنی', 4),
#  ('صندوق', 4),
#  ('مقرر', 4),
#  ('سوی', 4),
#  ('رینگ', 4),
#  ('آمار', 4),
#  ('ورق', 4),
#  ('وسکاب', 4),
#  ('کچاد', 4),
#  ('روي', 4),
#  ('فساز', 4),
#  ('غلتک', 4),
#  ('او', 4),
#  ('تغییرات', 4),
#  ('کاتد', 4),
#  ('وبملت', 4),
#  ('ونک', 4),
#  ('بار', 4),
#  ('خشكي', 4),
#  ('عملیات', 4),
#  ('اختیار', 4),
#  ('دید', 4),
#  ('هنوز', 4),
#  ('سپاهان', 4),
#  ('خشرق', 4),
#  ('خیابان', 4),
#  ('لیزینگ', 4),
#  ('وبصادر', 4),
#  ('انتشار', 4),
#  ('پیشنهاد', 4),
#  ('خشایار', 4),
#  ('اعطایی', 4),
#  ('مشاهده', 3),
#  ('وسپه', 3),
#  ('ساسول', 3),
#  ('جلوگيري', 3),
#  ('سفارش', 3),
#  ('میگیرد', 3),
#  ('بند', 3),
#  ('منتشره', 3),
#  ('اتکام', 3),
#  ('خرد', 3),
#  ('سوم', 3),
#  ('ناخالص', 3),
#  ('ارفع', 3),
#  ('خصوصی', 3),
#  ('بلوکی', 3),
#  ('قبلی', 3),
#  ('منتهی', 3),
#  ('مقطع', 3),
#  ('موفق', 3),
#  ('حالا', 3),
#  ('انرژي', 3),
#  ('انرژی', 3),
#  ('توان', 3),
#  ('چین', 3),
#  ('اندکی', 3),
#  ('اکتیو', 3),
#  ('رود', 3),
#  ('دارویی', 3),
#  ('شهرک', 3),
#  ('بساما', 3),
#  ('موارد', 3),
#  ('تمدید', 3),
#  ('بمپنا', 3),
#  ('بپاس', 3),
#  ('بکام', 3),
#  ('دامنه', 3),
#  ('صدر', 3),
#  ('غیر', 3),
#  ('فباهنر', 3),
#  ('برگزاری', 3),
#  ('مهمان', 3),
#  ('تاپکیش', 3),
#  ('مراحل', 3),
#  ('خبهمن', 3),
#  ('همین', 3),
#  ('اسفندماه', 3),
#  ('آلات', 3),
#  ('تملت', 3),
#  ('مزبور', 3),
#  ('خکرمان', 3),
#  ('اقتصادی', 3),
#  ('سهامی', 3),
#  ('مربوطه', 3),
#  ('احتمالی', 3),
#  ('شفافیت', 3),
#  ('نیاز', 3),
#  ('فاذر', 3),
#  ('مرکزی', 3),
#  ('نجات', 3),
#  ('اشاره', 3),
#  ('زمانی', 3),
#  ('سرعت', 3),
#  ('دستور', 3),
#  ('خارج', 3),
#  ('دعوت', 3),
#  ('دفتر', 3),
#  ('تهیه', 3),
#  ('اجرای', 3),
#  ('تصمیم', 3),
#  ('استان', 3),
#  ('چک', 3),
#  ('نمود', 3),
#  ('اراضی', 3),
#  ('شاهد', 3),
#  ('ثعمرا', 3),
#  ('زیرمجموعه', 3),
#  ('گرفته', 3),
#  ('غاذر', 3),
#  ('فعاليت', 3),
#  ('خاص', 3),
#  ('کارآفرین', 3),
#  ('همه', 3),
#  ('دریافتی', 3),
#  ('مالیات', 3),
#  ('مديريت', 3),
#  ('نخست', 3),
#  ('متوسط', 3),
#  ('میفروشد', 3),
#  ('زمان', 3),
#  ('ولساپا', 3),
#  ('خودروسازی', 3),
#  ('آغاز', 3),
#  ('داروسازي', 3),
#  ('اهميت', 3),
#  ('گرديد', 3),
#  ('دسینا', 3),
#  ('وخارزم', 3),
#  ('دپارس', 3),
#  ('مصوب', 3),
#  ('خبری', 3),
#  ('نداده', 3),
#  ('شرايط', 3),
#  ('خستگي', 3),
#  ('بلوم', 3),
#  ('آوری', 3),
#  ('زودی', 3),
#  ('مپنا', 3),
#  ('ایجاد', 3),
#  ('تهاتر', 3),
#  ('وی', 3),
#  ('رکیش', 3),
#  ('مبین', 3),
#  ('زقیام', 3),
#  ('زگلدشت', 3),
#  ('زنجان', 3),
#  ('کشاورزی', 3),
#  ('تاسیس', 3),
#  ('فعلی', 3),
#  ('سفارس', 3),
#  ('عنوان', 3),
#  ('گفته', 3),
#  ('لاستیک', 3),
#  ('یزد', 3),
#  ('پیزد', 3),
#  ('رشدی', 3),
#  ('سخوز', 3),
#  ('میدکو', 3),
#  ('خشکی', 3),
#  ('خشکسالی', 3),
#  ('نمی', 3),
#  ('سمایه', 3),
#  ('بالغ', 3),
#  ('حالی', 3),
#  ('خسارتهای', 3),
#  ('اهم', 3),
#  ('مطالب', 3),
#  ('سکرد', 3),
#  ('نوسان', 3),
#  ('روند', 3),
#  ('مصرفی', 3),
#  ('شبریز', 3),
#  ('شسپا', 3),
#  ('بازهم', 3),
#  ('شفادارو', 3),
#  ('تواند', 3),
#  ('خریده', 3),
#  ('بیشترین', 3),
#  ('پاییز', 3),
#  ('وصنا', 3),
#  ('بدون', 3),
#  ('توضیحات', 3),
#  ('اساس', 3),
#  ('غبهار', 3),
#  ('غدیس', 3),
#  ('حسابرسی', 3),
#  ('فعال', 3),
#  ('آید', 3),
#  ('طلب', 3),
#  ('صمت', 3),
#  ('محاسبه', 3),
#  ('بصورت', 3),
#  ('مذكور', 3),
#  ('کروی', 3),
#  ('فاسمین', 3),
#  ('ونیکی', 3),
#  ('عالی', 3),
#  ('معاون', 3),
#  ('توقیف', 3),
#  ('فلامی', 3),
#  ('هرمز', 3),
#  ('تاثیر', 3),
#  ('لوله', 3),
#  ('تایید', 3),
#  ('توليدي', 3),
#  ('دارايي', 3),
#  ('استبیمه', 3),
#  ('ممسنی', 3),
#  ('نمودن', 3),
#  ('وتوصا', 3),
#  ('تبعی', 3),
#  ('ملي', 3),
#  ('چند', 3),
#  ('یکی', 3),
#  ('تسويه', 3),
#  ('منبع', 3),
#  ('داراییها', 3),
#  ('کسب', 3),
#  ('معدنی', 3),
#  ('دوشنبه', 3),
#  ('وپست', 3),
#  ('پارتا', 3),
#  ('احتمالا', 3),
#  ('کرونا', 3),
#  ('کشرق', 3),
#  ('کپرور', 3),
#  ('مقایسه', 2),
#  ('آسپ', 2),
#  ('آرمان', 2),
#  ('معافيت', 2),
#  ('مزاياي', 2),
#  ('بازرگاني', 2),
#  ('استناد', 2),
#  ('امور', 2),
#  ('دلاری', 2),
#  ('قیمتی', 2),
#  ('سقف', 2),
#  ('اظهارنظر', 2),
#  ('اعتلا', 2),
#  ('افق', 2),
#  ('زنجيره', 2),
#  ('كليه', 2),
#  ('شراز', 2),
#  ('شاوان', 2),
#  ('طي', 2),
#  ('اوان', 2),
#  ('نهایی', 2),
#  ('ترانسفو', 2),
#  ('بجهرم', 2),
#  ('کنون', 2),
#  ('خاور', 2),
#  ('تقریبا', 2),
#  ('نشان', 2),
#  ('بوعلی', 2),
#  ('نرسيده', 2),
#  ('خليج', 2),
#  ('پاسارگاد', 2),
#  ('بنابراین', 2),
#  ('قوی', 2),
#  ('بگیلان', 2),
#  ('گيلان', 2),
#  ('مسير', 2),
#  ('استتوسعه', 2),
#  ('بیلت', 2),
#  ('اسلب', 2),
#  ('cis', 2),
#  ('ثبات', 2),
#  ('ارسال', 2),
#  ('منتظر', 2),
#  ('آثار', 2),
#  ('گستر', 2),
#  ('مرجان', 2),
#  ('گازی', 2),
#  ('تایرا', 2),
#  ('تبرک', 2),
#  ('بتواند', 2),
#  ('قزوين', 2),
#  ('ابتداي', 2),
#  ('تلیسه', 2),
#  ('تخصیص', 2),
#  ('تعهد', 2),
#  ('پذیره', 2),
#  ('خریدند', 2),
#  ('توریل', 2),
#  ('آذرآب', 2),
#  ('هپکو', 2),
#  ('تپکو', 2),
#  ('وزیر', 2),
#  ('قصد', 2),
#  ('دابور', 2),
#  ('کلر', 2),
#  ('جهاد', 2),
#  ('ثاخت', 2),
#  ('تجاری', 2),
#  ('بدوی', 2),
#  ('رای', 2),
#  ('دانشگاه', 2),
#  ('شمالي', 2),
#  ('مسکونی', 2),
#  ('کیسون', 2),
#  ('ثتران', 2),
#  ('مصالح', 2),
#  ('مرکز', 2),
#  ('گیری', 2),
#  ('تصمیمات', 2),
#  ('طبق', 2),
#  ('توافقات', 2),
#  ('احتراما', 2),
#  ('آقای', 2),
#  ('مهدی', 2),
#  ('رأی', 2),
#  ('محمد', 2),
#  ('اعتماد', 2),
#  ('ثعتما', 2),
#  ('بازدهي', 2),
#  ('عمران', 2),
#  ('ساخت', 2),
#  ('غير', 2),
#  ...]

# %%
# If more than half of the companies have it as a top word, exclude it from the list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 500]
add_stop_words
# Out:
# ['در',
#  'به',
#  'است',
#  'ریال',
#  'از',
#  'با',
#  'سود',
#  'میلیارد',
#  'ماهه',
#  'شرکت',
#  'فروش',
#  'این']

# %%
stop_words = ['را', 'با', 'است', 'می', 'که', 'این', 'از', 'به', 'در', 'و', 'های', 'برای', 'آن', 'یک', 'ها',
             'شود', 'شده', 'خود', 'کرد', 'ای', 'کرده', 'داشته', 'بوده', 'بود', 'زده', 'تا', 'هر', 'هم', 'نیز',
             'خواهد', 'شد', 'بر', 'دارد', 'زد', 'آن', 'یا', 'باشد', 'میگردد', 'ای' ]

# %%
# Let's update our document-term matrix with the new list of stop words

from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer

# Read in cleaned data
data_clean = pd.read_pickle('data_clean.pkl')

# Add new stop words
stop_words = add_stop_words + stop_words

# Recreate document-term matrix
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(data_clean.Post)
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_stop.index = data_clean.hashtags

# Pickle it for later use
import pickle
pickle.dump(cv, open("cv_stop.pkl", "wb"))
data_stop.to_pickle("dtm_stop.pkl")

# %%
# Find the number of unique words that each companies uses

unique_list = []
for companies in data.columns:
    uniques = data[companies].nonzero()[0].size
    unique_list.append(uniques)
data_words = pd.DataFrame(list(zip(data_clean.hashtags, unique_list)), columns=['companies',"unique_words"])
data_unique_sort = data_words.sort_values(by= "unique_words")
data_unique_sort
# Out:
# C:\Users\Mohammad Reza Jalali\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   """
#                  companies  unique_words
# 738  ['#وایران', '#خودرو']             2
# 499             ['#صرافی']             2
# 153   ['#ثنوسا', '#ونوین']             4
# 492    ['#شیران', '#وآتی']             4
# 970             ['#کرونا']             4
# ..                     ...           ...
# 616              ['#فملی']          1055
# 295               ['#ذوب']          1090
# 703            ['#های_وب']          1127
# 750             ['#وبملت']          1263
# 222             ['#خودرو']          1375
#
# [1033 rows x 2 columns]

# %%
#find total number of words which a companies uses

total_list = []

for companies in data.columns:
    totals = sum(data[companies])
    total_list.append(totals)

data_words['total_words'] = total_list

data_wpm_sort = data_words.sort_values(by ='total_words' )
data_wpm_sort
# Out:
#                  companies  unique_words  total_words
# 499             ['#صرافی']             2            2
# 738  ['#وایران', '#خودرو']             2            2
# 492    ['#شیران', '#وآتی']             4            4
# 970             ['#کرونا']             4            4
# 153   ['#ثنوسا', '#ونوین']             4            4
# ..                     ...           ...          ...
# 204             ['#خساپا']          1017         5542
# 750             ['#وبملت']          1263         6212
# 222             ['#خودرو']          1375         6739
# 616              ['#فملی']          1055         6757
# 629             ['#فولاد']           979         6863
#
# [1033 rows x 3 columns]

# %%
data_wpm_sort =data_wpm_sort[data_wpm_sort['unique_words'] != data_wpm_sort['total_words']]
data_wpm_sort
# Out:
#                           companies  unique_words  total_words
# 997                      ['#کنگین']             6            7
# 391                      ['#سنوین']             7            8
# 683            ['#ممسنی', '#پترول']             8            9
# 29    ['#البرز', '#شراز', '#شاوان']             8           10
# 786  ['#وساخت', '#تنوین', '#وبشهر']            10           11
# ..                              ...           ...          ...
# 204                      ['#خساپا']          1017         5542
# 750                      ['#وبملت']          1263         6212
# 222                      ['#خودرو']          1375         6739
# 616                       ['#فملی']          1055         6757
# 629                      ['#فولاد']           979         6863
#
# [960 rows x 3 columns]

# %%
corrmat = data_wpm_sort.drop(labels=['companies'], axis=1)
corrmat
# Out:
#      unique_words  total_words
# 997             6            7
# 391             7            8
# 683             8            9
# 29              8           10
# 786            10           11
# ..            ...          ...
# 204          1017         5542
# 750          1263         6212
# 222          1375         6739
# 616          1055         6757
# 629           979         6863
#
# [960 rows x 2 columns]

# %%
correlated_data = corrmat.corr()
correlated_data
# Out:
#               unique_words  total_words
# unique_words      1.000000     0.923851
# total_words       0.923851     1.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.pairplot(corrmat)
plt.tight_layout()

# %%
Counter(words).most_common()
# Out:
# [('در', 897),
#  ('به', 855),
#  ('است', 791),
#  ('ریال', 780),
#  ('از', 715),
#  ('با', 697),
#  ('سود', 641),
#  ('میلیارد', 604),
#  ('ماهه', 568),
#  ('شرکت', 555),
#  ('فروش', 538),
#  ('این', 511),
#  ('که', 483),
#  ('شده', 467),
#  ('کرده', 462),
#  ('را', 455),
#  ('سهم', 439),
#  ('ریالی', 428),
#  ('داشته', 394),
#  ('بوده', 363),
#  ('بود', 316),
#  ('سال', 294),
#  ('سرمایه', 262),
#  ('های', 256),
#  ('محقق', 243),
#  ('رسیده', 227),
#  ('نرخ', 208),
#  ('عدد', 206),
#  ('مواجه', 197),
#  ('گزارش', 192),
#  ('می', 186),
#  ('خوبی', 173),
#  ('خریدار', 167),
#  ('عملیاتی', 167),
#  ('خرید', 163),
#  ('خریدا', 162),
#  ('افزایش', 159),
#  ('خریداد', 158),
#  ('مبلغ', 158),
#  ('ماه', 157),
#  ('زده', 157),
#  ('قبل', 156),
#  ('خریدpo', 155),
#  ('خریداران', 149),
#  ('خریختخریخت', 147),
#  ('ها', 145),
#  ('خریدارو', 137),
#  ('مجمع', 137),
#  ('خوب', 136),
#  ('خریخت', 132),
#  ('درامد', 129),
#  ('خریداري', 125),
#  ('زیان', 124),
#  ('خالص', 123),
#  ('خریداری', 117),
#  ('خريدبخشي', 116),
#  ('میلیون', 107),
#  ('مالی', 107),
#  ('محل', 103),
#  ('خريداري', 103),
#  ('تا', 103),
#  ('هم', 101),
#  ('رشد', 99),
#  ('روز', 98),
#  ('گذاری', 98),
#  ('هر', 96),
#  ('خریداقا', 92),
#  ('سهام', 90),
#  ('مدت', 90),
#  ('مورخ', 83),
#  ('جمع', 83),
#  ('نیز', 82),
#  ('عرضه', 81),
#  ('تاریخ', 78),
#  ('برای', 78),
#  ('مشابه', 78),
#  ('شناسایی', 77),
#  ('خریدثاخت', 74),
#  ('بازار', 68),
#  ('خريداران', 67),
#  ('سازی', 67),
#  ('شد', 65),
#  ('شود', 64),
#  ('خواهد', 64),
#  ('تن', 62),
#  ('خریدخدمات', 60),
#  ('بانک', 59),
#  ('کمی', 58),
#  ('خريدار', 58),
#  ('منظور', 57),
#  ('کرد', 56),
#  ('عمومی', 54),
#  ('داشت', 54),
#  ('ﻻزم', 53),
#  ('مجموعه', 53),
#  ('نماد', 52),
#  ('مهر', 52),
#  ('جلسه', 51),
#  ('ازای', 51),
#  ('قیمت', 50),
#  ('سرمايه', 49),
#  ('صورت', 46),
#  ('بورس', 46),
#  ('تهران', 46),
#  ('خردمندان', 45),
#  ('خردافزایش', 45),
#  ('ساعت', 44),
#  ('مي', 43),
#  ('تومان', 43),
#  ('زیر', 43),
#  ('بلوک', 43),
#  ('نسبت', 42),
#  ('خریدسود', 42),
#  ('ثبت', 42),
#  ('هیئت', 41),
#  ('هزار', 41),
#  ('دارد', 40),
#  ('درصد', 39),
#  ('فولاد', 39),
#  ('افت', 39),
#  ('ارزش', 38),
#  ('خردادومعادن', 38),
#  ('خيابان', 37),
#  ('خريد', 37),
#  ('تقسیم', 36),
#  ('سهامداران', 36),
#  ('تولید', 36),
#  ('حال', 35),
#  ('توجه', 35),
#  ('گذاري', 35),
#  ('ولی', 34),
#  ('باشد', 34),
#  ('ایران', 33),
#  ('حدود', 33),
#  ('اوراق', 33),
#  ('نظر', 32),
#  ('توسط', 32),
#  ('خردادماه', 31),
#  ('بر', 31),
#  ('دی', 31),
#  ('هاي', 30),
#  ('یک', 30),
#  ('خروجی', 29),
#  ('فروردین', 29),
#  ('بهادار', 29),
#  ('شفاف', 29),
#  ('انجام', 28),
#  ('انباشته', 28),
#  ('مدیره', 28),
#  ('خریدش', 28),
#  ('قرارداد', 27),
#  ('معاملات', 27),
#  ('میانگین', 27),
#  ('یا', 27),
#  ('آن', 27),
#  ('برگزار', 27),
#  ('خرده', 27),
#  ('شنبه', 26),
#  ('رساند', 26),
#  ('اولیه', 25),
#  ('خرسی', 25),
#  ('ريال', 25),
#  ('اسفند', 25),
#  ('فوق', 24),
#  ('هزینه', 24),
#  ('بهتر', 24),
#  ('بخش', 24),
#  ('پروژه', 23),
#  ('مطالبات', 23),
#  ('ماده', 23),
#  ('خرم', 23),
#  ('نقدی', 22),
#  ('مالي', 22),
#  ('بیمه', 22),
#  ('پارس', 22),
#  ('شمش', 22),
#  ('آورده', 21),
#  ('مزایده', 21),
#  ('معاملاتی', 21),
#  ('اعلام', 21),
#  ('تعداد', 21),
#  ('رعایت', 21),
#  ('پتروشیمی', 21),
#  ('خودرو', 21),
#  ('تجدید', 20),
#  ('شركت', 20),
#  ('گروه', 20),
#  ('توسعه', 20),
#  ('پرتفوی', 19),
#  ('شماره', 19),
#  ('ارزیابی', 19),
#  ('فرابورس', 19),
#  ('اول', 19),
#  ('تامین', 19),
#  ('خیلی', 18),
#  ('بهمن', 18),
#  ('معامله', 18),
#  ('جهت', 18),
#  ('فارس', 18),
#  ('بیش', 18),
#  ('عدم', 18),
#  ('عملکرد', 18),
#  ('خروجي', 18),
#  ('مورد', 18),
#  ('تسهیلات', 18),
#  ('تحلیلی', 17),
#  ('خود', 17),
#  ('سازمان', 17),
#  ('خرمشهر', 17),
#  ('میگردد', 17),
#  ('واگذاری', 17),
#  ('درمحل', 17),
#  ('خریدفروش', 17),
#  ('ناشر', 17),
#  ('خصوص', 17),
#  ('زد', 17),
#  ('کاهش', 16),
#  ('افزايش', 16),
#  ('شهریور', 16),
#  ('دارایی', 16),
#  ('جمعا', 16),
#  ('صنعت', 15),
#  ('پلاک', 15),
#  ('اطلاع', 15),
#  ('نفت', 15),
#  ('خرنیگ', 15),
#  ('ابان', 15),
#  ('پس', 15),
#  ('مذکور', 15),
#  ('خردادفاذر', 15),
#  ('تسویه', 15),
#  ('دو', 15),
#  ('بعد', 14),
#  ('تحقق', 14),
#  ('فملی', 14),
#  ('خرمدره', 14),
#  ('اجرایی', 14),
#  ('اطلاعات', 14),
#  ('باید', 14),
#  ('وساخت', 14),
#  ('خساپا', 14),
#  ('مثبت', 14),
#  ('پارسان', 13),
#  ('مدیرة', 13),
#  ('حسابرس', 13),
#  ('دستورالعمل', 13),
#  ('فخوز', 13),
#  ('قرار', 13),
#  ('گویا', 13),
#  ('فروشد', 13),
#  ('وغدیر', 13),
#  ('تیر', 13),
#  ('کمتر', 13),
#  ('تراز', 13),
#  ('وتجارت', 13),
#  ('مهم', 13),
#  ('حاضر', 12),
#  ('درصدی', 12),
#  ('مجوز', 12),
#  ('تعلیق', 12),
#  ('کالا', 12),
#  ('صادرات', 12),
#  ('فروخته', 12),
#  ('امروز', 12),
#  ('ايران', 12),
#  ('آهن', 12),
#  ('ساختمان', 12),
#  ('رسید', 12),
#  ('نامه', 12),
#  ('اصفهان', 12),
#  ('تصویب', 12),
#  ('ومعادن', 12),
#  ('نقد', 12),
#  ('مربوط', 12),
#  ('مس', 12),
#  ('خروج', 12),
#  ('محدوده', 11),
#  ('واحد', 11),
#  ('حداکثر', 11),
#  ('گردید', 11),
#  ('کل', 11),
#  ('بررسی', 11),
#  ('مرداد', 11),
#  ('اين', 11),
#  ('اذر', 11),
#  ('تاپیکو', 11),
#  ('تمام', 11),
#  ('آگهی', 11),
#  ('صنعتی', 11),
#  ('ملی', 11),
#  ('صادر', 11),
#  ('معادل', 11),
#  ('ای', 10),
#  ('ارائه', 10),
#  ('هفته', 10),
#  ('سه', 10),
#  ('کار', 10),
#  ('داد', 10),
#  ('پذیرش', 10),
#  ('بسیار', 10),
#  ('گردد', 10),
#  ('تغییر', 10),
#  ('داده', 10),
#  ('دستگاه', 10),
#  ('نوین', 10),
#  ('ملت', 10),
#  ('همچنین', 10),
#  ('روی', 10),
#  ('منفی', 10),
#  ('سپرده', 10),
#  ('پرداختی', 10),
#  ('کنسانتره', 10),
#  ('کارخانه', 10),
#  ('بیشتر', 10),
#  ('کگل', 10),
#  ('لازم', 9),
#  ('پارسیس', 9),
#  ('قابل', 9),
#  ('استفاده', 9),
#  ('صنعتي', 9),
#  ('معاملاتي', 9),
#  ('واگذار', 9),
#  ('غیرعملیاتی', 9),
#  ('وبانک', 9),
#  ('ميليون', 9),
#  ('طی', 9),
#  ('وپاسار', 9),
#  ('گذشته', 9),
#  ('البته', 9),
#  ('مازاد', 9),
#  ('متعلق', 9),
#  ('کم', 9),
#  ('کشور', 9),
#  ('مقدار', 9),
#  ('اردیبهشت', 9),
#  ('خبرخوب', 9),
#  ('منظم', 9),
#  ('وامید', 9),
#  ('توقف', 9),
#  ('پایه', 8),
#  ('اصلاح', 8),
#  ('آینده', 8),
#  ('چهار', 8),
#  ('جالب', 8),
#  ('داخلی', 8),
#  ('صادراتی', 8),
#  ('خرمشهرکوچه', 8),
#  ('دوره', 8),
#  ('اوره', 8),
#  ('خبر', 8),
#  ('محصولات', 8),
#  ('تجارت', 8),
#  ('برق', 8),
#  ('بهای', 8),
#  ('دلیل', 8),
#  ('هلدینگ', 8),
#  ('موضوع', 8),
#  ('کرمان', 8),
#  ('نحوه', 8),
#  ('شهيد', 8),
#  ('ونوین', 8),
#  ('منتشر', 8),
#  ('همراه', 8),
#  ('وپارس', 8),
#  ('موجودی', 8),
#  ('درج', 8),
#  ('سیمان', 8),
#  ('سيمان', 8),
#  ('خاصی', 8),
#  ('نوری', 8),
#  ('سنگ', 8),
#  ('آذر', 7),
#  ('ان', 7),
#  ('فردا', 7),
#  ('سالیانه', 7),
#  ('سامانه', 7),
#  ('العاده', 7),
#  ('اندوخته', 7),
#  ('تلفیقی', 7),
#  ('پیش', 7),
#  ('دلار', 7),
#  ('البرز', 7),
#  ('مناقصه', 7),
#  ('شدن', 7),
#  ('واقع', 7),
#  ('اگر', 7),
#  ('مجموع', 7),
#  ('افشای', 7),
#  ('قانون', 7),
#  ('تیپیکو', 7),
#  ('دریافت', 7),
#  ('صنایع', 7),
#  ('قيمت', 7),
#  ('جاده', 7),
#  ('زمین', 7),
#  ('اقتصاد', 7),
#  ('بدهی', 7),
#  ('طریق', 7),
#  ('خرندکماسه', 7),
#  ('موجود', 7),
#  ('ورنا', 7),
#  ('سایپا', 7),
#  ('خرند', 7),
#  ('میکند', 7),
#  ('جدید', 7),
#  ('مجامع', 7),
#  ('متوقف', 7),
#  ('تاريخ', 7),
#  ('نزد', 7),
#  ('فوری', 7),
#  ('چهارشنبه', 7),
#  ('امسال', 7),
#  ('شرایط', 7),
#  ('نکته', 7),
#  ('خوزستان', 7),
#  ('شکر', 7),
#  ('چدن', 7),
#  ('پارسیان', 7),
#  ('تاصیکو', 6),
#  ('pnav', 6),
#  ('روزرسانی', 6),
#  ('مالکیت', 6),
#  ('استکانال', 6),
#  ('رسانی', 6),
#  ('بخشی', 6),
#  ('براساس', 6),
#  ('وزارت', 6),
#  ('حد', 6),
#  ('درآمد', 6),
#  ('رقابت', 6),
#  ('امید', 6),
#  ('گرفت', 6),
#  ('اضافه', 6),
#  ('تومانی', 6),
#  ('سهمی', 6),
#  ('پتروشيمي', 6),
#  ('کنفرانس', 6),
#  ('برخی', 6),
#  ('نداشته', 6),
#  ('نمادهای', 6),
#  ('بسته', 6),
#  ('گاز', 6),
#  ('بابت', 6),
#  ('تنوین', 6),
#  ('عام', 6),
#  ('عمده', 6),
#  ('خریدقطعات', 6),
#  ('خریدفوری', 6),
#  ('گفت', 6),
#  ('یکجا', 6),
#  ('پنج', 6),
#  ('ثنوسا', 6),
#  ('پرداخت', 6),
#  ('جم', 6),
#  ('ما', 6),
#  ('محصول', 6),
#  ('خرداد', 6),
#  ('کشت', 6),
#  ('نهایت', 6),
#  ('مبارکه', 6),
#  ('حمل', 6),
#  ('پیشرفت', 6),
#  ('تجهیزات', 6),
#  ('خدمات', 6),
#  ('نزدیک', 6),
#  ('مطابق', 6),
#  ('ظرفیت', 6),
#  ('علت', 6),
#  ('ادامه', 6),
#  ('ذوب', 6),
#  ('خردادعدد', 6),
#  ('محترم', 6),
#  ('کوثر', 6),
#  ('ساوه', 6),
#  ('وصندوق', 6),
#  ('چهارم', 6),
#  ('همچنان', 6),
#  ('شیران', 6),
#  ('صنايع', 6),
#  ('شستا', 6),
#  ('ملک', 6),
#  ('سهامدار', 6),
#  ('صبا', 6),
#  ('پترول', 6),
#  ('ماهانه', 6),
#  ('nav', 5),
#  ('بورسی', 5),
#  ('نیست', 5),
#  ('آریا', 5),
#  ('سازان', 5),
#  ('وضعیت', 5),
#  ('ابتدای', 5),
#  ('تقاضا', 5),
#  ('ساختار', 5),
#  ('بهبود', 5),
#  ('قانونی', 5),
#  ('توجیهی', 5),
#  ('پیشنهادافزایش', 5),
#  ('والبر', 5),
#  ('قرن', 5),
#  ('برنده', 5),
#  ('بترانس', 5),
#  ('مهلت', 5),
#  ('دیگر', 5),
#  ('مسیر', 5),
#  ('طبقه', 5),
#  ('ميدان', 5),
#  ('هایی', 5),
#  ('طرح', 5),
#  ('خسته', 5),
#  ('داریم', 5),
#  ('رمپنا', 5),
#  ('ورود', 5),
#  ('فن', 5),
#  ('شفن', 5),
#  ('وپترو', 5),
#  ('خبرخوبی', 5),
#  ('شهر', 5),
#  ('خسرو', 5),
#  ('میشود', 5),
#  ('راستای', 5),
#  ('یکشنبه', 5),
#  ('کاری', 5),
#  ('مجتمع', 5),
#  ('مشارکت', 5),
#  ('بالاتر', 5),
#  ('فقط', 5),
#  ('پیرو', 5),
#  ('مدیرعامل', 5),
#  ('آماده', 5),
#  ('رفع', 5),
#  ('میزان', 5),
#  ('اهمیت', 5),
#  ('منابع', 5),
#  ('ندارد', 5),
#  ('خپارس', 5),
#  ('اگهی', 5),
#  ('خساپاخساپا', 5),
#  ('واگذاري', 5),
#  ('خط', 5),
#  ('حوالی', 5),
#  ('پخش', 5),
#  ('خساپاستوساپا', 5),
#  ('بهره', 5),
#  ('برداری', 5),
#  ('آوا', 5),
#  ('راهی', 5),
#  ('موثر', 5),
#  ('زکوثر', 5),
#  ('کد', 5),
#  ('هستند', 5),
#  ('شگویا', 5),
#  ('نشده', 5),
#  ('سایر', 5),
#  ('ده', 5),
#  ('نبش', 5),
#  ('میدهد', 5),
#  ('فرآورده', 5),
#  ('استحضار', 5),
#  ('کانال', 5),
#  ('وبشهر', 5),
#  ('برنامه', 5),
#  ('توافق', 5),
#  ('فروی', 5),
#  ('کاما', 5),
#  ('گندله', 5),
#  ('معادن', 5),
#  ('وصنعت', 5),
#  ('وسینا', 5),
#  ('توضیح', 4),
#  ('سنگین', 4),
#  ('عادی', 4),
#  ('املاک', 4),
#  ('بطور', 4),
#  ('سالن', 4),
#  ('کدال', 4),
#  ('صاحبان', 4),
#  ('کگهر', 4),
#  ('پایان', 4),
#  ('بودجه', 4),
#  ('برآورد', 4),
#  ('آرمون', 4),
#  ('بازرس', 4),
#  ('دولت', 4),
#  ('گزارشگری', 4),
#  ('اولین', 4),
#  ('خلیج', 4),
#  ('متانول', 4),
#  ('سطح', 4),
#  ('شیمی', 4),
#  ('راه', 4),
#  ('شرقي', 4),
#  ('صورتی', 4),
#  ('پکرمان', 4),
#  ('نیروگاه', 4),
#  ('سامان', 4),
#  ('اعطای', 4),
#  ('الزامات', 4),
#  ('ظرف', 4),
#  ('بفجر', 4),
#  ('بلوار', 4),
#  ('رتاپ', 4),
#  ('بودن', 4),
#  ('کلیه', 4),
#  ('كه', 4),
#  ('انتقال', 4),
#  ('غشهداب', 4),
#  ('ايرانيان', 4),
#  ('گردیده', 4),
#  ('دوم', 4),
#  ('دماوند', 4),
#  ('نویسی', 4),
#  ('اقدام', 4),
#  ('شیر', 4),
#  ('دهی', 4),
#  ('نصاب', 4),
#  ('مشهد', 4),
#  ('مفاد', 4),
#  ('سینا', 4),
#  ('درخواست', 4),
#  ('خساپاشرکت', 4),
#  ('احداث', 4),
#  ('توثیق', 4),
#  ('اتیلن', 4),
#  ('پلی', 4),
#  ('ابهامات', 4),
#  ('ادغام', 4),
#  ('سپه', 4),
#  ('دوباره', 4),
#  ('شیراز', 4),
#  ('خراسان', 4),
#  ('خزامیا', 4),
#  ('خزر', 4),
#  ('مطرح', 4),
#  ('وساپا', 4),
#  ('شنیده', 4),
#  ('یافته', 4),
#  ('تعدیل', 4),
#  ('بازگشایی', 4),
#  ('خگستر', 4),
#  ('نداشت', 4),
#  ('مشتری', 4),
#  ('دارو', 4),
#  ('هجرت', 4),
#  ('دفارا', 4),
#  ('رخ', 4),
#  ('روزهای', 4),
#  ('کاوه', 4),
#  ('رازی', 4),
#  ('مدیریت', 4),
#  ('فاز', 4),
#  ('آباد', 4),
#  ('معدن', 4),
#  ('سرب', 4),
#  ('گوهران', 4),
#  ('زاگرس', 4),
#  ('توليد', 4),
#  ('خواهند', 4),
#  ('بالای', 4),
#  ('اما', 4),
#  ('آخرین', 4),
#  ('گام', 4),
#  ('قطعی', 4),
#  ('شاید', 4),
#  ('سبهان', 4),
#  ('کيلومتر', 4),
#  ('خشان', 4),
#  ('استراتوس', 4),
#  ('کوچه', 4),
#  ('نموده', 4),
#  ('مصرف', 4),
#  ('رکورد', 4),
#  ('تابستان', 4),
#  ('فصلی', 4),
#  ('ذاتی', 4),
#  ('شپدیس', 4),
#  ('شپنا', 4),
#  ('حراج', 4),
#  ('تندگویان', 4),
#  ('کند', 4),
#  ('اخیر', 4),
#  ('یعنی', 4),
#  ('صندوق', 4),
#  ('مقرر', 4),
#  ('سوی', 4),
#  ('رینگ', 4),
#  ('آمار', 4),
#  ('ورق', 4),
#  ('وسکاب', 4),
#  ('کچاد', 4),
#  ('روي', 4),
#  ('فساز', 4),
#  ('غلتک', 4),
#  ('او', 4),
#  ('تغییرات', 4),
#  ('کاتد', 4),
#  ('وبملت', 4),
#  ('ونک', 4),
#  ('بار', 4),
#  ('خشكي', 4),
#  ('عملیات', 4),
#  ('اختیار', 4),
#  ('دید', 4),
#  ('هنوز', 4),
#  ('سپاهان', 4),
#  ('خشرق', 4),
#  ('خیابان', 4),
#  ('لیزینگ', 4),
#  ('وبصادر', 4),
#  ('انتشار', 4),
#  ('پیشنهاد', 4),
#  ('خشایار', 4),
#  ('اعطایی', 4),
#  ('مشاهده', 3),
#  ('وسپه', 3),
#  ('ساسول', 3),
#  ('جلوگيري', 3),
#  ('سفارش', 3),
#  ('میگیرد', 3),
#  ('بند', 3),
#  ('منتشره', 3),
#  ('اتکام', 3),
#  ('خرد', 3),
#  ('سوم', 3),
#  ('ناخالص', 3),
#  ('ارفع', 3),
#  ('خصوصی', 3),
#  ('بلوکی', 3),
#  ('قبلی', 3),
#  ('منتهی', 3),
#  ('مقطع', 3),
#  ('موفق', 3),
#  ('حالا', 3),
#  ('انرژي', 3),
#  ('انرژی', 3),
#  ('توان', 3),
#  ('چین', 3),
#  ('اندکی', 3),
#  ('اکتیو', 3),
#  ('رود', 3),
#  ('دارویی', 3),
#  ('شهرک', 3),
#  ('بساما', 3),
#  ('موارد', 3),
#  ('تمدید', 3),
#  ('بمپنا', 3),
#  ('بپاس', 3),
#  ('بکام', 3),
#  ('دامنه', 3),
#  ('صدر', 3),
#  ('غیر', 3),
#  ('فباهنر', 3),
#  ('برگزاری', 3),
#  ('مهمان', 3),
#  ('تاپکیش', 3),
#  ('مراحل', 3),
#  ('خبهمن', 3),
#  ('همین', 3),
#  ('اسفندماه', 3),
#  ('آلات', 3),
#  ('تملت', 3),
#  ('مزبور', 3),
#  ('خکرمان', 3),
#  ('اقتصادی', 3),
#  ('سهامی', 3),
#  ('مربوطه', 3),
#  ('احتمالی', 3),
#  ('شفافیت', 3),
#  ('نیاز', 3),
#  ('فاذر', 3),
#  ('مرکزی', 3),
#  ('نجات', 3),
#  ('اشاره', 3),
#  ('زمانی', 3),
#  ('سرعت', 3),
#  ('دستور', 3),
#  ('خارج', 3),
#  ('دعوت', 3),
#  ('دفتر', 3),
#  ('تهیه', 3),
#  ('اجرای', 3),
#  ('تصمیم', 3),
#  ('استان', 3),
#  ('چک', 3),
#  ('نمود', 3),
#  ('اراضی', 3),
#  ('شاهد', 3),
#  ('ثعمرا', 3),
#  ('زیرمجموعه', 3),
#  ('گرفته', 3),
#  ('غاذر', 3),
#  ('فعاليت', 3),
#  ('خاص', 3),
#  ('کارآفرین', 3),
#  ('همه', 3),
#  ('دریافتی', 3),
#  ('مالیات', 3),
#  ('مديريت', 3),
#  ('نخست', 3),
#  ('متوسط', 3),
#  ('میفروشد', 3),
#  ('زمان', 3),
#  ('ولساپا', 3),
#  ('خودروسازی', 3),
#  ('آغاز', 3),
#  ('داروسازي', 3),
#  ('اهميت', 3),
#  ('گرديد', 3),
#  ('دسینا', 3),
#  ('وخارزم', 3),
#  ('دپارس', 3),
#  ('مصوب', 3),
#  ('خبری', 3),
#  ('نداده', 3),
#  ('شرايط', 3),
#  ('خستگي', 3),
#  ('بلوم', 3),
#  ('آوری', 3),
#  ('زودی', 3),
#  ('مپنا', 3),
#  ('ایجاد', 3),
#  ('تهاتر', 3),
#  ('وی', 3),
#  ('رکیش', 3),
#  ('مبین', 3),
#  ('زقیام', 3),
#  ('زگلدشت', 3),
#  ('زنجان', 3),
#  ('کشاورزی', 3),
#  ('تاسیس', 3),
#  ('فعلی', 3),
#  ('سفارس', 3),
#  ('عنوان', 3),
#  ('گفته', 3),
#  ('لاستیک', 3),
#  ('یزد', 3),
#  ('پیزد', 3),
#  ('رشدی', 3),
#  ('سخوز', 3),
#  ('میدکو', 3),
#  ('خشکی', 3),
#  ('خشکسالی', 3),
#  ('نمی', 3),
#  ('سمایه', 3),
#  ('بالغ', 3),
#  ('حالی', 3),
#  ('خسارتهای', 3),
#  ('اهم', 3),
#  ('مطالب', 3),
#  ('سکرد', 3),
#  ('نوسان', 3),
#  ('روند', 3),
#  ('مصرفی', 3),
#  ('شبریز', 3),
#  ('شسپا', 3),
#  ('بازهم', 3),
#  ('شفادارو', 3),
#  ('تواند', 3),
#  ('خریده', 3),
#  ('بیشترین', 3),
#  ('پاییز', 3),
#  ('وصنا', 3),
#  ('بدون', 3),
#  ('توضیحات', 3),
#  ('اساس', 3),
#  ('غبهار', 3),
#  ('غدیس', 3),
#  ('حسابرسی', 3),
#  ('فعال', 3),
#  ('آید', 3),
#  ('طلب', 3),
#  ('صمت', 3),
#  ('محاسبه', 3),
#  ('بصورت', 3),
#  ('مذكور', 3),
#  ('کروی', 3),
#  ('فاسمین', 3),
#  ('ونیکی', 3),
#  ('عالی', 3),
#  ('معاون', 3),
#  ('توقیف', 3),
#  ('فلامی', 3),
#  ('هرمز', 3),
#  ('تاثیر', 3),
#  ('لوله', 3),
#  ('تایید', 3),
#  ('توليدي', 3),
#  ('دارايي', 3),
#  ('استبیمه', 3),
#  ('ممسنی', 3),
#  ('نمودن', 3),
#  ('وتوصا', 3),
#  ('تبعی', 3),
#  ('ملي', 3),
#  ('چند', 3),
#  ('یکی', 3),
#  ('تسويه', 3),
#  ('منبع', 3),
#  ('داراییها', 3),
#  ('کسب', 3),
#  ('معدنی', 3),
#  ('دوشنبه', 3),
#  ('وپست', 3),
#  ('پارتا', 3),
#  ('احتمالا', 3),
#  ('کرونا', 3),
#  ('کشرق', 3),
#  ('کپرور', 3),
#  ('مقایسه', 2),
#  ('آسپ', 2),
#  ('آرمان', 2),
#  ('معافيت', 2),
#  ('مزاياي', 2),
#  ('بازرگاني', 2),
#  ('استناد', 2),
#  ('امور', 2),
#  ('دلاری', 2),
#  ('قیمتی', 2),
#  ('سقف', 2),
#  ('اظهارنظر', 2),
#  ('اعتلا', 2),
#  ('افق', 2),
#  ('زنجيره', 2),
#  ('كليه', 2),
#  ('شراز', 2),
#  ('شاوان', 2),
#  ('طي', 2),
#  ('اوان', 2),
#  ('نهایی', 2),
#  ('ترانسفو', 2),
#  ('بجهرم', 2),
#  ('کنون', 2),
#  ('خاور', 2),
#  ('تقریبا', 2),
#  ('نشان', 2),
#  ('بوعلی', 2),
#  ('نرسيده', 2),
#  ('خليج', 2),
#  ('پاسارگاد', 2),
#  ('بنابراین', 2),
#  ('قوی', 2),
#  ('بگیلان', 2),
#  ('گيلان', 2),
#  ('مسير', 2),
#  ('استتوسعه', 2),
#  ('بیلت', 2),
#  ('اسلب', 2),
#  ('cis', 2),
#  ('ثبات', 2),
#  ('ارسال', 2),
#  ('منتظر', 2),
#  ('آثار', 2),
#  ('گستر', 2),
#  ('مرجان', 2),
#  ('گازی', 2),
#  ('تایرا', 2),
#  ('تبرک', 2),
#  ('بتواند', 2),
#  ('قزوين', 2),
#  ('ابتداي', 2),
#  ('تلیسه', 2),
#  ('تخصیص', 2),
#  ('تعهد', 2),
#  ('پذیره', 2),
#  ('خریدند', 2),
#  ('توریل', 2),
#  ('آذرآب', 2),
#  ('هپکو', 2),
#  ('تپکو', 2),
#  ('وزیر', 2),
#  ('قصد', 2),
#  ('دابور', 2),
#  ('کلر', 2),
#  ('جهاد', 2),
#  ('ثاخت', 2),
#  ('تجاری', 2),
#  ('بدوی', 2),
#  ('رای', 2),
#  ('دانشگاه', 2),
#  ('شمالي', 2),
#  ('مسکونی', 2),
#  ('کیسون', 2),
#  ('ثتران', 2),
#  ('مصالح', 2),
#  ('مرکز', 2),
#  ('گیری', 2),
#  ('تصمیمات', 2),
#  ('طبق', 2),
#  ('توافقات', 2),
#  ('احتراما', 2),
#  ('آقای', 2),
#  ('مهدی', 2),
#  ('رأی', 2),
#  ('محمد', 2),
#  ('اعتماد', 2),
#  ('ثعتما', 2),
#  ('بازدهي', 2),
#  ('عمران', 2),
#  ('ساخت', 2),
#  ('غير', 2),
#  ...]

# %%
# number of negative words for every companies
data_bad_words = data.transpose()[['زیان' ,'افت' ,'کاهش' ,'تعلیق' ,'منفی' ,'بدهی']]


data_bw = pd.concat([data_bad_words.زیان + data_bad_words.افت +
                     data_bad_words.کاهش + data_bad_words.تعلیق +
                     data_bad_words.منفی + data_bad_words.بدهی]) 

data_bw = pd.DataFrame(data_bw, columns = ['bad_words'])
data_bw
# Out:
#                      bad_words
# hashtags
# ['#NAV', '#تاصیکو']          0
# ['#NAV', '#وسپه']            0
# ['#NAV', '#پارسان']          0
# ['#آ_س_پ']                   2
# ['#آبین']                    0
# ...                        ...
# ['#گوهران']                  0
# ['#گپارس']                   0
# ['#گکوثر']                  23
# ['#گکیش']                    0
# ['#گگهر']                    0
#
# [1033 rows x 1 columns]

# %%
# number of positive words for every companies
data_good_words = data.transpose()[['سود','افزایش','رشد','مثبت','پیشرفت','بهبود']]

data_gw = pd.concat([data_good_words.پیشرفت + data_good_words.رشد +
                     data_good_words.سود + data_good_words.افزایش +
                     data_good_words.مثبت + data_good_words.بهبود])


data_gw = pd.DataFrame(data_gw, columns = ['good_words'])
data_gw
# Out:
#                      good_words
# hashtags
# ['#NAV', '#تاصیکو']           1
# ['#NAV', '#وسپه']             2
# ['#NAV', '#پارسان']           0
# ['#آ_س_پ']                   10
# ['#آبین']                     3
# ...                         ...
# ['#گوهران']                  40
# ['#گپارس']                    3
# ['#گکوثر']                   29
# ['#گکیش']                     5
# ['#گگهر']                     1
#
# [1033 rows x 1 columns]

# %%
data_gw['bad_words'] = data_bw.bad_words

# %%
data_gbw = data_gw.sort_values(by ='good_words', ascending = False)
data_gbw
# Out:
#                        good_words  bad_words
# hashtags
# ['#وبملت']                    191         30
# ['#فولاد']                    162         10
# ['#کچاد']                     134         11
# ['#فملی']                     130         12
# ['#کگل']                      114         18
# ...                           ...        ...
# ['#سکاون']                      0          5
# ['#وتجارت', '#فملی']            0          0
# ['#سپاها', '#شیران']            0          0
# ['#وپارس', '#خساپا']            0          0
# ['#زگلدشت', '#زقیام']           0          0
#
# [1033 rows x 2 columns]

# %%
#remove rows with zero good and bad words
data_gbw =data_gbw[data_gbw['good_words'] != data_gbw['bad_words']]
data_gbw
# Out:
#                        good_words  bad_words
# hashtags
# ['#وبملت']                    191         30
# ['#فولاد']                    162         10
# ['#کچاد']                     134         11
# ['#فملی']                     130         12
# ['#کگل']                      114         18
# ...                           ...        ...
# ['#وپسا']                       0          1
# ['#قجام']                       0          2
# ['#پارسان', '#شیراز']           0          1
# ['#شسم']                        0          6
# ['#سکاون']                      0          5
#
# [792 rows x 2 columns]

# %%
data_gbw.index.name = ''
data_gbw
# Out:
#                        good_words  bad_words
#
# ['#وبملت']                    191         30
# ['#فولاد']                    162         10
# ['#کچاد']                     134         11
# ['#فملی']                     130         12
# ['#کگل']                      114         18
# ...                           ...        ...
# ['#وپسا']                       0          1
# ['#قجام']                       0          2
# ['#پارسان', '#شیراز']           0          1
# ['#شسم']                        0          6
# ['#سکاون']                      0          5
#
# [792 rows x 2 columns]

# %%
data_gbw.describe()
# Out:
#        good_words   bad_words
# count  792.000000  792.000000
# mean    26.299242    5.799242
# std     26.987146    8.958612
# min      0.000000    0.000000
# 25%      3.000000    0.000000
# 50%     18.000000    2.000000
# 75%     44.000000    8.000000
# max    191.000000   73.000000

# %%
correlated_data = data_gbw.corr()
correlated_data
# Out:
#             good_words  bad_words
# good_words    1.000000   0.444554
# bad_words     0.444554   1.000000

# %%
sns.pairplot(data_gbw)
plt.tight_layout()

# %%
plt.rcParams['figure.figsize'] = [15, 10]

for i, companies in enumerate(data_gbw.index):
    x = data_gbw.good_words.loc[companies]
    y = data_gbw.bad_words.loc[companies]
    plt.scatter(x, y, color = "blue")
    #plt.text(x+1.5, y+0.5, data_gbw.index[i], fontsize = 10 )
    #plt.xlim(-5, 155)
    
plt.title('Number of Bad and Good Words')
plt.xlabel('Number of Good Words', fontsize =15)
plt.ylabel('Number of Bad Words', fontsize=15);
plt.show()

# %%
plt.rcParams['figure.figsize'] = [15, 10]

for i, companies in enumerate(data_gbw.index):
    x = data_gbw.good_words.loc[companies]
    y = data_gbw.bad_words.loc[companies]
    plt.scatter(x, y, color = "blue")
    plt.text(x+1.5, y+0.5, data_gbw.index[i], fontsize = 10 )
    plt.xlim(-5, 155)
    
plt.title('Number of Bad and Good Words')
plt.xlabel('Number of Good Words', fontsize =15)
plt.ylabel('Number of Bad Words', fontsize=15);
plt.show()

# %%
mean_gbw = data_gbw.mean(axis=1)

# %%
data_gbw['mean'] = mean_gbw
# Out:
# C:\Users\Mohammad Reza Jalali\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#status of every companies based on positive and negative wo
data_gbw = data_gbw.sort_values(by ='mean', ascending = False)
data_gbw.head(15)
# Out:
#              good_words  bad_words   mean
#
# ['#وبملت']          191         30  110.5
# ['#فولاد']          162         10   86.0
# ['#وتجارت']         112         57   84.5
# ['#خودرو']           93         73   83.0
# ['#وبصادر']          92         60   76.0
# ['#کچاد']           134         11   72.5
# ['#فملی']           130         12   71.0
# ['#وپارس']           88         54   71.0
# ['#کگل']            114         18   66.0
# ['#خساپا']           75         56   65.5
# ['#چکارن']           79         49   64.0
# ['#شیران']          109         19   64.0
# ['#بترانس']         107         14   60.5
# ['#شتران']          103         13   58.0
# ['#حریل']           104         12   58.0

# %%
data_clean = pd.read_pickle('data_clean.pkl')
data_clean
# Out:
#                  hashtags                                               Post
# 1     ['#NAV', '#تاصیکو']  به روزرسانی nav هر سهم تاصیکو بعد از افزایش سر...
# 2       ['#NAV', '#وسپه']  به روزرسانی nav هر سهم وسپه بعد از ارائه گزارش...
# 3     ['#NAV', '#پارسان']  به روز رسانی nav هر سهم پارسان\nدر حال حاضر نس...
# 4              ['#آ_س_پ']  پیشرفت پروژه ها در آسپآسپ در  به زیان  ریالی ر...
# 5               ['#آبین']  آبین و افزایش سرمایه از محل تجدید ارزیابی   گز...
# ...                   ...                                                ...
# 1029          ['#گوهران']  گوهران را باید  دید ولی در کل سهم در   ریال به...
# 1030           ['#گپارس']  گپارس در    ریال  و در سود اصلی نیز  ریال سود ...
# 1031           ['#گکوثر']  گکوثر صنعتی است که کرونا در ان خود را نشان داد...
# 1032            ['#گکیش']  افزایش سرمایه در گکیش گزارش توجیهی هیئت مدیرة ...
# 1033            ['#گگهر']  افزایش سرمایه  درصدی گگهر از محل آورده نقدی سه...
#
# [1033 rows x 2 columns]

# %%
selected_companies = ["['#شیران']", "['#چکارن']", "['#خساپا']", "['#کگل']", "['#فملی']", "['#وپارس']", "['#کچاد']", 
                      "['#وبصادر']", "['#خودرو']", "['#وتجارت']", "['#فولاد']", "['#وبملت']"]

# %%
selected_companies = data_clean.loc[data_clean['hashtags'].isin(selected_companies)]

# %%
#15 Top companies
selected_companies.head(15)
# Out:
#          hashtags                                               Post
# 205    ['#خساپا']  بررسی وضعیت فروش در خساپاخساپا در فروردین از ن...
# 223    ['#خودرو']  خودرو هم گزارش خود را داد و کرونا در ان بسیار ...
# 495    ['#شیران']  گزارش شیران در فروردین با  فروش   میلیارد ریال...
# 617     ['#فملی']  نگاهی به وضعیت فروش فملیفملی در فروردین با  فر...
# 630    ['#فولاد']  فولاد دستیابی به رکورد  ذوب مداوم در فولاد مبا...
# 749   ['#وبصادر']  شرکت سرمايه گذاري توسعه و اوج سپهر اصفهان از ز...
# 751    ['#وبملت']  افزایش سرمایه  درصدی وبملت از محل تجدید ارزیاب...
# 761   ['#وتجارت']  نگاهی به عملکرد ماهانه در وتجارتسرمايه گذاري ا...
# 879    ['#وپارس']  وپارس هم با سود تسهیلات  میلیارد ریالی و سود س...
# 946    ['#چکارن']  چکارن در فروردین  میلیون تومان فروش داشته و مش...
# 1010    ['#کچاد']  کچاد و نرخ محاسبه حق انتفاعپاسخ به سوالات در ک...
# 1021     ['#کگل']  کگل جلسه مجمع عمومی این شرکت  در ساعت  روز سه ...

# %%
stop_words = ['را', 'با', 'است', 'می', 'که', 'این', 'از', 'به', 'در', 'و', 'های', 'برای', 'آن', 'یک', 'ها',
             'شود', 'شده', 'خود', 'کرد', 'ای', 'کرده', 'داشته', 'بوده', 'بود', 'زده', 'تا', 'هر', 'هم', 'نیز',
             'خواهد', 'شد', 'بر', 'دارد', 'زد', 'آن', 'یا', 'باشد', 'میگردد', 'ای' ]

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv =  CountVectorizer(stop_words = stop_words)
data_cv = cv.fit_transform(selected_companies.Post)
data_dtm = pd.DataFrame(data_cv.toarray(), columns = cv.get_feature_names())
data_dtm.index = selected_companies.hashtags

# %%
data = data_dtm.transpose()
data.head()
# Out:
# hashtags   ['#خساپا']  ['#خودرو']  ['#شیران']  ['#فملی']  ['#فولاد']  \
# accenture           0           0           0          0           0
# api                 0           0           0          0           1
# apiتختال            0           0           0          0           1
# asp                 0           0           0          0           0
# building            0           0           0          0           0
#
# hashtags   ['#وبصادر']  ['#وبملت']  ['#وتجارت']  ['#وپارس']  ['#چکارن']  \
# accenture            0           0            0           0           0
# api                  0           0            0           0           0
# apiتختال             0           0            0           0           0
# asp                  0           0            0           0           1
# building             0           0            0           0           0
#
# hashtags   ['#کچاد']  ['#کگل']
# accenture          1         0
# api                0         0
# apiتختال           0         0
# asp                0         0
# building           1         0

# %%
top_dict = {}

for c in data.columns:
    top = data[c].sort_values(ascending = False).head(30)
    top_dict[c] = list(zip(top.index, top.values))

top_dict
# Out:
# {"['#خساپا']": [('فروش', 182),
#   ('میلیارد', 152),
#   ('ریال', 136),
#   ('هزار', 124),
#   ('دستگاه', 101),
#   ('تولید', 98),
#   ('ماهه', 68),
#   ('خساپا', 60),
#   ('سایپا', 46),
#   ('ریالی', 43),
#   ('زیان', 42),
#   ('نرخ', 39),
#   ('فروخته', 36),
#   ('پراید', 35),
#   ('خوب', 32),
#   ('افزایش', 31),
#   ('سهم', 27),
#   ('شرکت', 27),
#   ('گروه', 25),
#   ('سال', 25),
#   ('عدد', 23),
#   ('حدود', 22),
#   ('گزارش', 22),
#   ('محصولات', 21),
#   ('مواجه', 21),
#   ('مالی', 19),
#   ('رسیده', 18),
#   ('ولی', 18),
#   ('رشد', 18),
#   ('مجموع', 17)],
#  "['#خودرو']": [('خودرو', 232),
#   ('فروش', 159),
#   ('ریال', 155),
#   ('میلیارد', 126),
#   ('ایران', 71),
#   ('ماهه', 63),
#   ('زیان', 62),
#   ('هزار', 53),
#   ('شرکت', 51),
#   ('دستگاه', 50),
#   ('سرمایه', 47),
#   ('سهم', 44),
#   ('افزایش', 43),
#   ('گزارش', 39),
#   ('سال', 31),
#   ('ریالی', 31),
#   ('نرخ', 31),
#   ('رسیده', 31),
#   ('تولید', 31),
#   ('ايران', 29),
#   ('پژو', 27),
#   ('ماه', 26),
#   ('گروه', 25),
#   ('سود', 24),
#   ('توليد', 21),
#   ('دی', 21),
#   ('عدد', 21),
#   ('بازار', 20),
#   ('مجمع', 20),
#   ('ارزیابی', 19)],
#  "['#شیران']": [('ریال', 189),
#   ('میلیارد', 115),
#   ('فروش', 105),
#   ('نرخ', 75),
#   ('شیران', 68),
#   ('سود', 59),
#   ('ماهه', 49),
#   ('بنزن', 39),
#   ('ریالی', 35),
#   ('شرکت', 32),
#   ('خطي', 28),
#   ('الکيل', 28),
#   ('سال', 27),
#   ('خوبی', 27),
#   ('خوب', 24),
#   ('داخلی', 22),
#   ('رشد', 21),
#   ('مواجه', 20),
#   ('افزایش', 19),
#   ('نرمال', 18),
#   ('محقق', 17),
#   ('صادراتی', 16),
#   ('فروردین', 16),
#   ('استشیران', 16),
#   ('افت', 15),
#   ('عملیاتی', 14),
#   ('سرمایه', 14),
#   ('مالی', 14),
#   ('عدد', 14),
#   ('ماه', 14)],
#  "['#فملی']": [('فروش', 265),
#   ('ریال', 248),
#   ('میلیارد', 220),
#   ('تن', 121),
#   ('ماهه', 95),
#   ('مس', 94),
#   ('کاتد', 86),
#   ('نرخ', 84),
#   ('سود', 84),
#   ('شرکت', 72),
#   ('هزار', 63),
#   ('مبلغ', 62),
#   ('فملی', 58),
#   ('ریالی', 58),
#   ('ريال', 49),
#   ('ميليون', 47),
#   ('ماه', 45),
#   ('ملی', 42),
#   ('سال', 42),
#   ('عملیاتی', 38),
#   ('گزارش', 38),
#   ('تومان', 31),
#   ('سهم', 31),
#   ('مي', 30),
#   ('فروخته', 30),
#   ('خوب', 30),
#   ('کنسانتره', 29),
#   ('تولید', 28),
#   ('بورس', 28),
#   ('معادل', 28)],
#  "['#فولاد']": [('ریال', 278),
#   ('فروش', 221),
#   ('فولاد', 204),
#   ('میلیارد', 200),
#   ('ورق', 162),
#   ('گرم', 101),
#   ('نرخ', 99),
#   ('ماهه', 97),
#   ('سود', 93),
#   ('شرکت', 79),
#   ('مبارکه', 70),
#   ('سرد', 67),
#   ('سال', 58),
#   ('ریالی', 53),
#   ('تن', 52),
#   ('بورس', 51),
#   ('ماه', 49),
#   ('سرمایه', 48),
#   ('افزایش', 45),
#   ('گزارش', 44),
#   ('خوب', 38),
#   ('مواجه', 37),
#   ('کالا', 35),
#   ('تولید', 31),
#   ('عرضه', 30),
#   ('سهم', 30),
#   ('قیمت', 29),
#   ('هزار', 27),
#   ('محصولات', 26),
#   ('تومان', 26)],
#  "['#وبصادر']": [('ریال', 95),
#   ('میلیارد', 86),
#   ('سود', 55),
#   ('وبصادر', 50),
#   ('منفی', 38),
#   ('ماهه', 37),
#   ('بانک', 32),
#   ('تراز', 32),
#   ('سال', 31),
#   ('صادرات', 24),
#   ('زیان', 19),
#   ('سهم', 18),
#   ('قبل', 18),
#   ('سرمایه', 18),
#   ('رسیده', 17),
#   ('پرداختی', 17),
#   ('استوبصادر', 16),
#   ('ایران', 15),
#   ('درامد', 15),
#   ('ریالی', 14),
#   ('گزارش', 14),
#   ('مدت', 14),
#   ('محقق', 13),
#   ('افزایش', 13),
#   ('مشابه', 13),
#   ('تسهیلات', 13),
#   ('ولی', 12),
#   ('عدد', 12),
#   ('مالی', 11),
#   ('رشد', 11)],
#  "['#وبملت']": [('بانک', 126),
#   ('ریال', 125),
#   ('میلیارد', 115),
#   ('سود', 87),
#   ('وبملت', 87),
#   ('ملت', 80),
#   ('تراز', 60),
#   ('ماهه', 58),
#   ('سال', 55),
#   ('مثبت', 53),
#   ('گزارش', 47),
#   ('سرمایه', 45),
#   ('افزایش', 37),
#   ('مبلغ', 32),
#   ('قبل', 31),
#   ('سهم', 29),
#   ('محل', 27),
#   ('نماد', 26),
#   ('تسعیر', 25),
#   ('ارز', 25),
#   ('خوبی', 24),
#   ('مورد', 22),
#   ('نرخ', 22),
#   ('ريال', 22),
#   ('دارایی', 20),
#   ('سازمان', 19),
#   ('مالی', 19),
#   ('درامد', 19),
#   ('ميليارد', 19),
#   ('نظر', 18)],
#  "['#وتجارت']": [('ریال', 98),
#   ('میلیارد', 79),
#   ('سود', 50),
#   ('وتجارت', 48),
#   ('بانک', 45),
#   ('ماهه', 45),
#   ('تراز', 39),
#   ('مثبت', 35),
#   ('سال', 29),
#   ('منفی', 24),
#   ('تجارت', 24),
#   ('زیان', 24),
#   ('قبل', 19),
#   ('میلیون', 18),
#   ('فروش', 18),
#   ('سرمایه', 17),
#   ('سهم', 15),
#   ('شرکت', 14),
#   ('درامد', 14),
#   ('گزارش', 13),
#   ('رسیده', 13),
#   ('مدت', 13),
#   ('مجموعه', 12),
#   ('خوبی', 12),
#   ('پرداختی', 12),
#   ('مجمع', 12),
#   ('زیر', 12),
#   ('افزایش', 12),
#   ('عدد', 11),
#   ('تسهیلات', 11)],
#  "['#وپارس']": [('ریال', 87),
#   ('میلیارد', 71),
#   ('بانک', 66),
#   ('سود', 55),
#   ('پارسیان', 49),
#   ('سرمایه', 48),
#   ('وپارس', 45),
#   ('سال', 39),
#   ('منفی', 33),
#   ('افزایش', 28),
#   ('تراز', 28),
#   ('فروش', 25),
#   ('شرکت', 24),
#   ('ماهه', 24),
#   ('سهم', 18),
#   ('سهام', 18),
#   ('گزارش', 18),
#   ('گذاری', 18),
#   ('محل', 18),
#   ('مجموعه', 18),
#   ('دارایی', 18),
#   ('زیر', 17),
#   ('زیان', 17),
#   ('عدد', 16),
#   ('تجدید', 16),
#   ('پرداختی', 16),
#   ('مالی', 16),
#   ('گروه', 15),
#   ('ارزیابی', 14),
#   ('استوپارس', 14)],
#  "['#چکارن']": [('ریال', 165),
#   ('میلیارد', 120),
#   ('فروش', 96),
#   ('شرکت', 39),
#   ('ماهه', 38),
#   ('سود', 36),
#   ('نرخ', 34),
#   ('ریالی', 33),
#   ('چکارن', 30),
#   ('رشد', 26),
#   ('عملیاتی', 22),
#   ('افت', 21),
#   ('عدد', 20),
#   ('مواجه', 19),
#   ('زیان', 19),
#   ('انجام', 18),
#   ('زمین', 17),
#   ('سرمایه', 17),
#   ('سهم', 16),
#   ('جهت', 15),
#   ('هزینه', 15),
#   ('فروردین', 15),
#   ('مدت', 14),
#   ('ماه', 14),
#   ('مهر', 14),
#   ('دی', 14),
#   ('پروژه', 14),
#   ('ولی', 14),
#   ('محقق', 13),
#   ('توجه', 13)],
#  "['#کچاد']": [('ریال', 233),
#   ('فروش', 200),
#   ('میلیارد', 157),
#   ('نرخ', 152),
#   ('شرکت', 96),
#   ('شمش', 80),
#   ('ماهه', 76),
#   ('گندله', 75),
#   ('سود', 73),
#   ('کنسانتره', 66),
#   ('تن', 60),
#   ('ریالی', 43),
#   ('فولاد', 41),
#   ('کچاد', 40),
#   ('آهن', 39),
#   ('میلیون', 39),
#   ('سرمایه', 38),
#   ('افزایش', 35),
#   ('هزار', 33),
#   ('سال', 32),
#   ('تولید', 31),
#   ('گزارش', 31),
#   ('خوبی', 29),
#   ('فروخته', 29),
#   ('مبلغ', 27),
#   ('عملیاتی', 25),
#   ('مواجه', 25),
#   ('سهم', 24),
#   ('ماه', 23),
#   ('رشد', 23)],
#  "['#کگل']": [('ریال', 241),
#   ('میلیارد', 189),
#   ('فروش', 158),
#   ('ماهه', 98),
#   ('شرکت', 87),
#   ('سال', 75),
#   ('سود', 68),
#   ('گندله', 59),
#   ('کگل', 47),
#   ('ریالی', 46),
#   ('میلیون', 46),
#   ('فولاد', 44),
#   ('نرخ', 44),
#   ('گهر', 42),
#   ('تن', 40),
#   ('گل', 40),
#   ('تولید', 37),
#   ('گزارش', 33),
#   ('مبلغ', 28),
#   ('عدد', 27),
#   ('سرمایه', 27),
#   ('خوبی', 23),
#   ('بینی', 23),
#   ('توسعه', 23),
#   ('پیش', 23),
#   ('کنسانتره', 23),
#   ('رشد', 23),
#   ('ماه', 22),
#   ('آهن', 22),
#   ('عملیاتی', 21)]}

# %%
# Look at the most common top words --> add them to the stop word list
from collections import Counter

# Let's first pull out the top 30 words for each companies
words = []
for companies in data.columns:
    top = [word for (word, count) in top_dict[companies]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['فروش',
#  'میلیارد',
#  'ریال',
#  'هزار',
#  'دستگاه',
#  'تولید',
#  'ماهه',
#  'خساپا',
#  'سایپا',
#  'ریالی',
#  'زیان',
#  'نرخ',
#  'فروخته',
#  'پراید',
#  'خوب',
#  'افزایش',
#  'سهم',
#  'شرکت',
#  'گروه',
#  'سال',
#  'عدد',
#  'حدود',
#  'گزارش',
#  'محصولات',
#  'مواجه',
#  'مالی',
#  'رسیده',
#  'ولی',
#  'رشد',
#  'مجموع',
#  'خودرو',
#  'فروش',
#  'ریال',
#  'میلیارد',
#  'ایران',
#  'ماهه',
#  'زیان',
#  'هزار',
#  'شرکت',
#  'دستگاه',
#  'سرمایه',
#  'سهم',
#  'افزایش',
#  'گزارش',
#  'سال',
#  'ریالی',
#  'نرخ',
#  'رسیده',
#  'تولید',
#  'ايران',
#  'پژو',
#  'ماه',
#  'گروه',
#  'سود',
#  'توليد',
#  'دی',
#  'عدد',
#  'بازار',
#  'مجمع',
#  'ارزیابی',
#  'ریال',
#  'میلیارد',
#  'فروش',
#  'نرخ',
#  'شیران',
#  'سود',
#  'ماهه',
#  'بنزن',
#  'ریالی',
#  'شرکت',
#  'خطي',
#  'الکيل',
#  'سال',
#  'خوبی',
#  'خوب',
#  'داخلی',
#  'رشد',
#  'مواجه',
#  'افزایش',
#  'نرمال',
#  'محقق',
#  'صادراتی',
#  'فروردین',
#  'استشیران',
#  'افت',
#  'عملیاتی',
#  'سرمایه',
#  'مالی',
#  'عدد',
#  'ماه',
#  'فروش',
#  'ریال',
#  'میلیارد',
#  'تن',
#  'ماهه',
#  'مس',
#  'کاتد',
#  'نرخ',
#  'سود',
#  'شرکت',
#  'هزار',
#  'مبلغ',
#  'فملی',
#  'ریالی',
#  'ريال',
#  'ميليون',
#  'ماه',
#  'ملی',
#  'سال',
#  'عملیاتی',
#  'گزارش',
#  'تومان',
#  'سهم',
#  'مي',
#  'فروخته',
#  'خوب',
#  'کنسانتره',
#  'تولید',
#  'بورس',
#  'معادل',
#  'ریال',
#  'فروش',
#  'فولاد',
#  'میلیارد',
#  'ورق',
#  'گرم',
#  'نرخ',
#  'ماهه',
#  'سود',
#  'شرکت',
#  'مبارکه',
#  'سرد',
#  'سال',
#  'ریالی',
#  'تن',
#  'بورس',
#  'ماه',
#  'سرمایه',
#  'افزایش',
#  'گزارش',
#  'خوب',
#  'مواجه',
#  'کالا',
#  'تولید',
#  'عرضه',
#  'سهم',
#  'قیمت',
#  'هزار',
#  'محصولات',
#  'تومان',
#  'ریال',
#  'میلیارد',
#  'سود',
#  'وبصادر',
#  'منفی',
#  'ماهه',
#  'بانک',
#  'تراز',
#  'سال',
#  'صادرات',
#  'زیان',
#  'سهم',
#  'قبل',
#  'سرمایه',
#  'رسیده',
#  'پرداختی',
#  'استوبصادر',
#  'ایران',
#  'درامد',
#  'ریالی',
#  'گزارش',
#  'مدت',
#  'محقق',
#  'افزایش',
#  'مشابه',
#  'تسهیلات',
#  'ولی',
#  'عدد',
#  'مالی',
#  'رشد',
#  'بانک',
#  'ریال',
#  'میلیارد',
#  'سود',
#  'وبملت',
#  'ملت',
#  'تراز',
#  'ماهه',
#  'سال',
#  'مثبت',
#  'گزارش',
#  'سرمایه',
#  'افزایش',
#  'مبلغ',
#  'قبل',
#  'سهم',
#  'محل',
#  'نماد',
#  'تسعیر',
#  'ارز',
#  'خوبی',
#  'مورد',
#  'نرخ',
#  'ريال',
#  'دارایی',
#  'سازمان',
#  'مالی',
#  'درامد',
#  'ميليارد',
#  'نظر',
#  'ریال',
#  'میلیارد',
#  'سود',
#  'وتجارت',
#  'بانک',
#  'ماهه',
#  'تراز',
#  'مثبت',
#  'سال',
#  'منفی',
#  'تجارت',
#  'زیان',
#  'قبل',
#  'میلیون',
#  'فروش',
#  'سرمایه',
#  'سهم',
#  'شرکت',
#  'درامد',
#  'گزارش',
#  'رسیده',
#  'مدت',
#  'مجموعه',
#  'خوبی',
#  'پرداختی',
#  'مجمع',
#  'زیر',
#  'افزایش',
#  'عدد',
#  'تسهیلات',
#  'ریال',
#  'میلیارد',
#  'بانک',
#  'سود',
#  'پارسیان',
#  'سرمایه',
#  'وپارس',
#  'سال',
#  'منفی',
#  'افزایش',
#  'تراز',
#  'فروش',
#  'شرکت',
#  'ماهه',
#  'سهم',
#  'سهام',
#  'گزارش',
#  'گذاری',
#  'محل',
#  'مجموعه',
#  'دارایی',
#  'زیر',
#  'زیان',
#  'عدد',
#  'تجدید',
#  'پرداختی',
#  'مالی',
#  'گروه',
#  'ارزیابی',
#  'استوپارس',
#  'ریال',
#  'میلیارد',
#  'فروش',
#  'شرکت',
#  'ماهه',
#  'سود',
#  'نرخ',
#  'ریالی',
#  'چکارن',
#  'رشد',
#  'عملیاتی',
#  'افت',
#  'عدد',
#  'مواجه',
#  'زیان',
#  'انجام',
#  'زمین',
#  'سرمایه',
#  'سهم',
#  'جهت',
#  'هزینه',
#  'فروردین',
#  'مدت',
#  'ماه',
#  'مهر',
#  'دی',
#  'پروژه',
#  'ولی',
#  'محقق',
#  'توجه',
#  'ریال',
#  'فروش',
#  'میلیارد',
#  'نرخ',
#  'شرکت',
#  'شمش',
#  'ماهه',
#  'گندله',
#  'سود',
#  'کنسانتره',
#  'تن',
#  'ریالی',
#  'فولاد',
#  'کچاد',
#  'آهن',
#  'میلیون',
#  'سرمایه',
#  'افزایش',
#  'هزار',
#  'سال',
#  'تولید',
#  'گزارش',
#  'خوبی',
#  'فروخته',
#  'مبلغ',
#  'عملیاتی',
#  'مواجه',
#  'سهم',
#  'ماه',
#  'رشد',
#  'ریال',
#  'میلیارد',
#  'فروش',
#  'ماهه',
#  'شرکت',
#  'سال',
#  'سود',
#  'گندله',
#  'کگل',
#  'ریالی',
#  'میلیون',
#  'فولاد',
#  'نرخ',
#  'گهر',
#  'تن',
#  'گل',
#  'تولید',
#  'گزارش',
#  'مبلغ',
#  'عدد',
#  'سرمایه',
#  'خوبی',
#  'بینی',
#  'توسعه',
#  'پیش',
#  'کنسانتره',
#  'رشد',
#  'ماه',
#  'آهن',
#  'عملیاتی']

# %%
# Let's aggregate this list and identify the most common words
Counter(words).most_common()
# Out:
# [('میلیارد', 12),
#  ('ریال', 12),
#  ('ماهه', 12),
#  ('سال', 11),
#  ('سود', 11),
#  ('فروش', 10),
#  ('سهم', 10),
#  ('شرکت', 10),
#  ('گزارش', 10),
#  ('سرمایه', 10),
#  ('ریالی', 9),
#  ('نرخ', 9),
#  ('افزایش', 9),
#  ('عدد', 8),
#  ('ماه', 7),
#  ('تولید', 6),
#  ('زیان', 6),
#  ('رشد', 6),
#  ('هزار', 5),
#  ('مواجه', 5),
#  ('مالی', 5),
#  ('خوبی', 5),
#  ('عملیاتی', 5),
#  ('خوب', 4),
#  ('رسیده', 4),
#  ('تن', 4),
#  ('مبلغ', 4),
#  ('بانک', 4),
#  ('تراز', 4),
#  ('فروخته', 3),
#  ('گروه', 3),
#  ('ولی', 3),
#  ('محقق', 3),
#  ('کنسانتره', 3),
#  ('فولاد', 3),
#  ('منفی', 3),
#  ('قبل', 3),
#  ('پرداختی', 3),
#  ('درامد', 3),
#  ('مدت', 3),
#  ('میلیون', 3),
#  ('دستگاه', 2),
#  ('محصولات', 2),
#  ('ایران', 2),
#  ('دی', 2),
#  ('مجمع', 2),
#  ('ارزیابی', 2),
#  ('فروردین', 2),
#  ('افت', 2),
#  ('ريال', 2),
#  ('تومان', 2),
#  ('بورس', 2),
#  ('تسهیلات', 2),
#  ('مثبت', 2),
#  ('محل', 2),
#  ('دارایی', 2),
#  ('مجموعه', 2),
#  ('زیر', 2),
#  ('گندله', 2),
#  ('آهن', 2),
#  ('خساپا', 1),
#  ('سایپا', 1),
#  ('پراید', 1),
#  ('حدود', 1),
#  ('مجموع', 1),
#  ('خودرو', 1),
#  ('ايران', 1),
#  ('پژو', 1),
#  ('توليد', 1),
#  ('بازار', 1),
#  ('شیران', 1),
#  ('بنزن', 1),
#  ('خطي', 1),
#  ('الکيل', 1),
#  ('داخلی', 1),
#  ('نرمال', 1),
#  ('صادراتی', 1),
#  ('استشیران', 1),
#  ('مس', 1),
#  ('کاتد', 1),
#  ('فملی', 1),
#  ('ميليون', 1),
#  ('ملی', 1),
#  ('مي', 1),
#  ('معادل', 1),
#  ('ورق', 1),
#  ('گرم', 1),
#  ('مبارکه', 1),
#  ('سرد', 1),
#  ('کالا', 1),
#  ('عرضه', 1),
#  ('قیمت', 1),
#  ('وبصادر', 1),
#  ('صادرات', 1),
#  ('استوبصادر', 1),
#  ('مشابه', 1),
#  ('وبملت', 1),
#  ('ملت', 1),
#  ('نماد', 1),
#  ('تسعیر', 1),
#  ('ارز', 1),
#  ('مورد', 1),
#  ('سازمان', 1),
#  ('ميليارد', 1),
#  ('نظر', 1),
#  ('وتجارت', 1),
#  ('تجارت', 1),
#  ('پارسیان', 1),
#  ('وپارس', 1),
#  ('سهام', 1),
#  ('گذاری', 1),
#  ('تجدید', 1),
#  ('استوپارس', 1),
#  ('چکارن', 1),
#  ('انجام', 1),
#  ('زمین', 1),
#  ('جهت', 1),
#  ('هزینه', 1),
#  ('مهر', 1),
#  ('پروژه', 1),
#  ('توجه', 1),
#  ('شمش', 1),
#  ('کچاد', 1),
#  ('کگل', 1),
#  ('گهر', 1),
#  ('گل', 1),
#  ('بینی', 1),
#  ('توسعه', 1),
#  ('پیش', 1)]

# %%
# If more than half of the comedians have it as a top word, exclude it from the list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 6]
add_stop_words
# Out:
# ['میلیارد',
#  'ریال',
#  'ماهه',
#  'سال',
#  'سود',
#  'فروش',
#  'سهم',
#  'شرکت',
#  'گزارش',
#  'سرمایه',
#  'ریالی',
#  'نرخ',
#  'افزایش',
#  'عدد',
#  'ماه']

# %%
stop_words = ['را', 'با', 'است', 'می', 'که', 'این', 'از', 'به', 'در', 'و', 'های', 'برای', 'آن', 'یک', 'ها',
             'شود', 'شده', 'خود', 'کرد', 'ای', 'کرده', 'داشته', 'بوده', 'بود', 'زده', 'تا', 'هر', 'هم', 'نیز',
             'خواهد', 'شد', 'بر', 'دارد', 'زد', 'آن', 'یا', 'باشد', 'میگردد', 'ای' ]

# %%
# Let's update our document-term matrix with the new list of stop words
from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer


# Add new stop words
stop_words = add_stop_words + stop_words

# Recreate document-term matrix
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(selected_companies.Post)
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_stop.index = selected_companies.hashtags

# Pickle it for later use
import pickle
pickle.dump(cv, open("cvs_stop.pkl", "wb"))
data_stop.to_pickle("dtms_stop.pkl")

# %%
# Let's make some word clouds!
# Terminal / Anaconda Prompt: conda install -c conda-forge wordcloud
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
# Reset the output dimensions
from __future__ import unicode_literals
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 6]

company_names = ["['#خساپا']", "['#خودرو]]", "['#شیران']", "['#فملی']", "['#فولاد']", "['#وبصادر']", "['#وبملت']", "['#وتجارت']",
                 "['#وپارس']" ,"['#چکارن']" ,"['#کچاد,']", "['#کگل']"]

# Create subplots for each companies
for index, companies in enumerate(data.columns):
    wc.generate(str(selected_companies.Post))
    
    plt.subplot(3, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(company_names[index])
    
plt.show()

# %% [markdown]
# # reference
# https://github.com/adashofdata/nlp-in-python-tutorial
